# %%
import os
os.chdir('/content')  # Change to the default Colab directory
# !git clone --branch Alphas_INF_07_10 --single-branch https://github.com/PavelSlobodianskii/VAEAC_Thesis.git
os.chdir("/content/VAEAC_Thesis")
# Out:
# Cloning into 'VAEAC_Thesis'...
# remote: Enumerating objects: 481, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 481 (delta 30), reused 45 (delta 25), pack-reused 412 (from 1)
# Receiving objects: 100% (481/481), 54.27 MiB | 34.18 MiB/s, done.
# Resolving deltas: 100% (90/90), done.

# %%
# %cd /content/VAEAC_Thesis/
# !git fetch
# !git checkout Alphas_INF_07_10
# Out:
# /content
# Already on 'Alphas_INF_07_10'
# Your branch is up to date with 'origin/Alphas_INF_07_10'.

# %%
# !rm -r /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba
# Out:
# rm: cannot remove '/content/VAEAC_Thesis/data/vaeac_project/img_align_celeba': No such file or directory

# %%
# !ls /content/VAEAC_Thesis
# Out:
# 'Alpha_5 (4).ipynb'		     evaluate_FID.py	       nn_utils.py
# 'Alpha_INF (5).ipynb'		     FID.py		       prob_utils.py
#  Alphas_0_5_10_09.ipynb		     imputation_networks.py    README.md
# 'Alphas_learnable_19_09 (3).ipynb'   impute.py		       requirements.txt
# 'Alphas_learnable_19_09 (5).ipynb'   __init__.py	       train.py
#  Alphas_learnable_19_09.ipynb	     inpaint.py		       train_utils.py
#  celeba_model			     LICENSE		       VAEAC.py
#  data				     masked_metrics_plot.png   viz.py
#  datasets.py			     mask_generators.py
#  evaluate_alphas.py		     metrics.py

# %%
# %cd VAEAC_Thesis/
# Out:
# [Errno 2] No such file or directory: 'VAEAC_Thesis/'
# /content

# %%
# !ls /content/VAEAC_Thesis/data/
# Out:
# evaluate_results.py  original_data    vaeac_project
# fetch_data.sh	     prepare_data.py

# %%
# !pip install torch torchvision pytorch-lightning pandas numpy matplotlib tqdm Pillow tensorflow
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.5.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning) (6.0.3)
# Collecting torchmetrics>0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning) (25.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.12.15)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading pytorch_lightning-2.5.5-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 27.9 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 46.8 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning
# Successfully installed lightning-utilities-0.15.2 pytorch-lightning-2.5.5 torchmetrics-1.8.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# List files in the 'Celeba' folder to see the exact file name
# !ls /content/VAEAC_Thesis
# Out:
# celeba_model		impute.py	    metrics.py	      train.py
# data			__init__.py	    nn_utils.py       train_utils.py
# datasets.py		inpaint.py	    prob_utils.py     untitled
# evaluate_alphas.py	LICENSE		    README.md	      VAEAC.py
# imputation_networks.py	mask_generators.py  requirements.txt  viz.py

# %%
# Check the exact path of files in Google Drive
import os
print(os.listdir('/content/drive/MyDrive/'))  # Look for the exact file path here

# Define the path to the .zip file
zip_file_path = '/content/drive/MyDrive/archive (1).zip'  # Ensure this matches the correct file name

# Define the unzip destination
unzip_dir = '/content/VAEAC_Thesis/data/vaeac_project'

# Create the destination directory
# !mkdir -p {unzip_dir}

# Unzip the .zip file to the target directory
# !unzip '{zip_file_path}' -d {unzip_dir}

# Now, set the paths to your dataset
celeba_root_dir = '/content/VAEAC_Thesis/data/vaeac_project'
celeba_img_dir = os.path.join(celeba_root_dir, 'img_align_celeba')
celeba_partition = os.path.join(celeba_root_dir, 'list_eval_partition.txt')

# Check if the dataset has been unzipped successfully
print("Image directory exists:", os.path.exists(celeba_img_dir))
print("Partition file exists:", os.path.exists(celeba_partition))
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197610.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197611.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197612.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197613.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197614.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197615.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197616.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197617.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197618.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197619.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197620.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197621.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197622.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197623.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197624.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197625.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197626.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197627.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197628.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197629.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197630.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197631.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197632.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197633.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197634.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197635.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197636.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197637.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197638.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197639.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197640.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197641.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197642.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197643.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197644.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197645.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197646.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197647.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197648.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197649.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197650.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197651.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197652.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197653.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197654.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197655.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197656.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197657.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197658.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197659.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197660.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197661.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197662.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197663.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197664.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197665.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197666.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197667.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197668.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197669.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197670.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197671.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197672.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197673.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197674.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197675.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197676.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197677.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197678.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197679.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197680.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197681.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197682.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197683.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197684.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197685.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197686.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197687.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197688.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197689.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197690.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197691.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197692.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197693.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197694.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197695.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197696.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197697.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197698.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197699.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197700.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197701.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197702.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197703.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197704.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197705.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197706.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197707.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197708.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197709.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197710.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197711.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197712.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197713.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197714.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197715.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197716.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197717.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197718.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197719.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197720.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197721.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197722.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197723.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197724.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197725.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197726.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197727.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197728.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197729.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197730.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197731.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197732.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197733.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197734.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197735.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197736.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197737.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197738.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197739.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197740.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197741.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197742.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197743.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197744.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197745.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197746.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197747.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197748.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197749.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197750.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197751.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197752.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197753.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197754.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197755.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197756.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197757.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197758.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197759.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197760.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197761.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197762.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197763.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197764.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197765.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197766.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197767.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197768.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197769.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197770.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197771.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197772.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197773.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197774.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197775.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197776.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197777.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197778.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197779.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197780.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197781.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197782.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197783.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197784.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197785.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197786.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197787.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197788.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197789.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197790.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197791.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197792.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197793.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197794.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197795.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197796.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197797.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197798.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197799.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197800.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197801.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197802.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197803.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197804.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197805.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197806.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197807.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197808.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197809.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197810.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197811.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197812.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197813.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197814.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197815.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197816.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197817.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197818.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197819.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197820.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197821.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197822.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197823.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197824.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197825.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197826.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197827.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197828.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197829.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197830.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197831.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197832.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197833.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197834.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197835.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197836.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197837.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197838.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197839.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197840.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197841.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197842.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197843.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197844.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197845.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197846.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197847.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197848.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197849.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197850.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197851.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197852.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197853.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197854.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197855.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197856.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197857.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197858.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197859.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197860.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197861.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197862.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197863.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197864.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197865.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197866.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197867.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197868.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197869.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197870.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197871.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197872.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197873.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197874.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197875.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197876.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197877.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197878.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197879.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197880.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197881.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197882.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197883.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197884.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197885.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197886.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197887.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197888.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197889.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197890.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197891.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197892.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197893.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197894.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197895.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197896.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197897.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197898.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197899.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197900.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197901.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197902.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197903.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197904.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197905.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197906.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197907.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197908.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197909.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197910.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197911.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197912.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197913.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197914.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197915.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197916.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197917.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197918.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197919.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197920.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197921.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197922.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197923.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197924.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197925.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197926.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197927.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197928.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197929.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197930.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197931.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197932.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197933.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197934.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197935.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197936.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197937.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197938.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197939.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197940.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197941.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197942.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197943.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197944.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197945.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197946.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197947.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197948.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197949.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197950.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197951.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197952.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197953.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197954.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197955.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197956.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197957.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197958.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197959.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197960.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197961.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197962.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197963.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197964.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197965.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197966.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197967.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197968.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197969.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197970.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197971.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197972.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197973.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197974.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197975.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197976.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197977.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197978.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197979.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197980.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197981.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197982.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197983.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197984.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197985.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197986.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197987.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197988.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197989.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197990.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197991.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197992.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197993.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197994.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197995.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197996.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197997.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197998.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/197999.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198000.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198001.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198002.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198003.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198004.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198005.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198006.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198007.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198008.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198009.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198010.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198011.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198012.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198013.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198014.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198015.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198016.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198017.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198018.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198019.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198020.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198021.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198022.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198023.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198024.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198025.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198026.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198027.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198028.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198029.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198030.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198031.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198032.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198033.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198034.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198035.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198036.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198037.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198038.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198039.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198040.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198041.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198042.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198043.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198044.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198045.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198046.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198047.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198048.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198049.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198050.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198051.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198052.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198053.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198054.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198055.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198056.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198057.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198058.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198059.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198060.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198061.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198062.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198063.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198064.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198065.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198066.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198067.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198068.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198069.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198070.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198071.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198072.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198073.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198074.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198075.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198076.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198077.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198078.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198079.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198080.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198081.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198082.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/198083.jpg
# ...
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202450.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202451.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202452.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202453.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202454.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202455.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202456.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202457.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202458.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202459.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202460.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202461.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202462.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202463.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202464.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202465.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202466.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202467.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202468.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202469.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202470.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202471.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202472.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202473.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202474.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202475.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202476.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202477.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202478.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202479.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202480.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202481.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202482.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202483.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202484.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202485.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202486.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202487.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202488.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202489.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202490.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202491.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202492.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202493.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202494.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202495.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202496.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202497.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202498.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202499.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202500.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202501.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202502.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202503.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202504.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202505.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202506.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202507.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202508.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202509.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202510.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202511.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202512.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202513.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202514.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202515.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202516.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202517.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202518.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202519.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202520.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202521.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202522.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202523.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202524.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202525.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202526.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202527.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202528.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202529.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202530.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202531.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202532.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202533.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202534.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202535.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202536.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202537.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202538.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202539.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202540.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202541.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202542.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202543.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202544.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202545.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202546.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202547.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202548.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202549.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202550.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202551.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202552.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202553.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202554.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202555.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202556.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202557.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202558.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202559.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202560.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202561.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202562.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202563.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202564.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202565.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202566.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202567.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202568.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202569.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202570.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202571.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202572.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202573.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202574.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202575.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202576.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202577.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202578.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202579.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202580.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202581.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202582.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202583.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202584.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202585.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202586.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202587.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202588.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202589.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202590.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202591.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202592.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202593.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202594.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202595.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202596.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202597.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202598.jpg
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/202599.jpg
# replace /content/VAEAC_Thesis/data/vaeac_project/list_attr_celeba.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: yes
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/list_attr_celeba.csv
# replace /content/VAEAC_Thesis/data/vaeac_project/list_bbox_celeba.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: yes
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/list_bbox_celeba.csv
# replace /content/VAEAC_Thesis/data/vaeac_project/list_eval_partition.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: yes
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/list_eval_partition.csv
# replace /content/VAEAC_Thesis/data/vaeac_project/list_landmarks_align_celeba.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: yes
#   inflating: /content/VAEAC_Thesis/data/vaeac_project/list_landmarks_align_celeba.csv
# Image directory exists: True
# Partition file exists: True

# %%
import os

# List files in the extracted directory to verify
extracted_files = os.listdir('/content/VAEAC_Thesis/data/vaeac_project')
print(extracted_files)
# Out:
# ['list_eval_partition.txt', 'list_bbox_celeba.csv', 'list_attr_celeba.csv', 'img_align_celeba', 'list_eval_partition.csv', 'list_landmarks_align_celeba.csv']

# %%
import os

celeba_root_dir = "/content/VAEAC_Thesis/data/vaeac_project"
celeba_img_dir = os.path.join(celeba_root_dir, "img_align_celeba/img_align_celeba")  # Adjusted path
celeba_partition = os.path.join(celeba_root_dir, "list_eval_partition.txt")

print("Image directory exists:", os.path.exists(celeba_img_dir))
print("Partition file exists:", os.path.exists(celeba_partition))

# List some images
print("Some images:", os.listdir(celeba_img_dir)[:5])
# Out:
# Image directory exists: True
# Partition file exists: True
# Some images: ['088461.jpg', '139048.jpg', '194180.jpg', '011405.jpg', '136959.jpg']

# %%
# !ls /content/VAEAC_Thesis/data/vaeac_project
# Out:
# img_align_celeba      list_bbox_celeba.csv     list_eval_partition.txt
# list_attr_celeba.csv  list_eval_partition.csv  list_landmarks_align_celeba.csv

# %%
file_path = "/content/VAEAC_Thesis/data/vaeac_project/list_eval_partition.txt"

# Read the file and replace commas with spaces
with open(file_path, "r") as file:
    content = file.read().replace(",", " ")

# Write the modified content back to the file
with open(file_path, "w") as file:
    file.write(content)

print("✅ Commas replaced with spaces in list_eval_partition.txt")
# Out:
# ✅ Commas replaced with spaces in list_eval_partition.txt

# %%
# Open the file in write mode
file_path = "/content/VAEAC_Thesis/datasets.py"

# Read the content and update the dataset path
with open(file_path, "r") as file:
    content = file.read()

content = content.replace("/dbstore/datasets/celebA", "/content/VAEAC_Thesis/data/vaeac_project")

# Save the updated file
with open(file_path, "w") as file:
    file.write(content)

print("✅ Updated datasets.py with new dataset path!")
# Out:
# ✅ Updated datasets.py with new dataset path!

# %%
# !pip install torch torchvision pytorch-lightning pandas numpy matplotlib tqdm Pillow tensorflow
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (2.5.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: torchmetrics>0.7.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning) (25.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning) (0.15.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.75.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.12.15)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import sys
sys.path.append('/content/VAEAC_Thesis/data/vaeac_project')

# %%
# !ls //content/VAEAC_Thesis/data/vaeac_project
# Out:
# img_align_celeba      list_bbox_celeba.csv     list_eval_partition.txt
# list_attr_celeba.csv  list_eval_partition.csv  list_landmarks_align_celeba.csv

# %%
# !cat /content/VAEAC_Thesis/datasets.py | grep -A 10 "def load_dataset"
# Out:
# def load_dataset(name):
#     """
#     Returns dataset for image inpainting.
#     Now returns only CelebA dataset (train, validation and test parts of it)
#     and generated masks for the test part.
#     """
#     celeba_transforms = Compose([
#         CenterCrop(128),
#         ToTensor(),
#         Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#     ])

# %%
# !ls /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba
# Out:
# img_align_celeba

# %%
import os
print(os.listdir('/content/VAEAC_Thesis/data/vaeac_project/img_align_celeba'))
# Out:
# ['img_align_celeba']

# %%
with open("/content/VAEAC_Thesis/data/vaeac_project/list_eval_partition.txt", "r") as file:
    lines = file.readlines()

# Print first few lines to check formatting
for line in lines[:10]:
    print(repr(line))  # Use repr() to reveal hidden characters like extra spaces
# Out:
# '000008.jpg 0\n'
# '000009.jpg 0\n'
# '000010.jpg 0\n'
# '000011.jpg 0\n'
# '000012.jpg 0\n'
# '000013.jpg 0\n'
# '000014.jpg 0\n'
# '000015.jpg 0\n'
# '000016.jpg 0\n'
# '000017.jpg 0\n'

# %%
file_path = "/content/VAEAC_Thesis/data/vaeac_project/list_eval_partition.txt"
# Read the file, skipping the first line (header)
with open(file_path, "r") as file:
    lines = file.readlines()[1:]  # Skip the header

# Save the cleaned file
with open(file_path, "w") as file:
    file.writelines(lines)

print("✅ Header removed from list_eval_partition.txt")
# Out:
# ✅ Header removed from list_eval_partition.txt

# %%
# !rsync -av --remove-source-files /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba/ /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# 197603.jpg
# 197604.jpg
# 197605.jpg
# 197606.jpg
# 197607.jpg
# 197608.jpg
# 197609.jpg
# 197610.jpg
# 197611.jpg
# 197612.jpg
# 197613.jpg
# 197614.jpg
# 197615.jpg
# 197616.jpg
# 197617.jpg
# 197618.jpg
# 197619.jpg
# 197620.jpg
# 197621.jpg
# 197622.jpg
# 197623.jpg
# 197624.jpg
# 197625.jpg
# 197626.jpg
# 197627.jpg
# 197628.jpg
# 197629.jpg
# 197630.jpg
# 197631.jpg
# 197632.jpg
# 197633.jpg
# 197634.jpg
# 197635.jpg
# 197636.jpg
# 197637.jpg
# 197638.jpg
# 197639.jpg
# 197640.jpg
# 197641.jpg
# 197642.jpg
# 197643.jpg
# 197644.jpg
# 197645.jpg
# 197646.jpg
# 197647.jpg
# 197648.jpg
# 197649.jpg
# 197650.jpg
# 197651.jpg
# 197652.jpg
# 197653.jpg
# 197654.jpg
# 197655.jpg
# 197656.jpg
# 197657.jpg
# 197658.jpg
# 197659.jpg
# 197660.jpg
# 197661.jpg
# 197662.jpg
# 197663.jpg
# 197664.jpg
# 197665.jpg
# 197666.jpg
# 197667.jpg
# 197668.jpg
# 197669.jpg
# 197670.jpg
# 197671.jpg
# 197672.jpg
# 197673.jpg
# 197674.jpg
# 197675.jpg
# 197676.jpg
# 197677.jpg
# 197678.jpg
# 197679.jpg
# 197680.jpg
# 197681.jpg
# 197682.jpg
# 197683.jpg
# 197684.jpg
# 197685.jpg
# 197686.jpg
# 197687.jpg
# 197688.jpg
# 197689.jpg
# 197690.jpg
# 197691.jpg
# 197692.jpg
# 197693.jpg
# 197694.jpg
# 197695.jpg
# 197696.jpg
# 197697.jpg
# 197698.jpg
# 197699.jpg
# 197700.jpg
# 197701.jpg
# 197702.jpg
# 197703.jpg
# 197704.jpg
# 197705.jpg
# 197706.jpg
# 197707.jpg
# 197708.jpg
# 197709.jpg
# 197710.jpg
# 197711.jpg
# 197712.jpg
# 197713.jpg
# 197714.jpg
# 197715.jpg
# 197716.jpg
# 197717.jpg
# 197718.jpg
# 197719.jpg
# 197720.jpg
# 197721.jpg
# 197722.jpg
# 197723.jpg
# 197724.jpg
# 197725.jpg
# 197726.jpg
# 197727.jpg
# 197728.jpg
# 197729.jpg
# 197730.jpg
# 197731.jpg
# 197732.jpg
# 197733.jpg
# 197734.jpg
# 197735.jpg
# 197736.jpg
# 197737.jpg
# 197738.jpg
# 197739.jpg
# 197740.jpg
# 197741.jpg
# 197742.jpg
# 197743.jpg
# 197744.jpg
# 197745.jpg
# 197746.jpg
# 197747.jpg
# 197748.jpg
# 197749.jpg
# 197750.jpg
# 197751.jpg
# 197752.jpg
# 197753.jpg
# 197754.jpg
# 197755.jpg
# 197756.jpg
# 197757.jpg
# 197758.jpg
# 197759.jpg
# 197760.jpg
# 197761.jpg
# 197762.jpg
# 197763.jpg
# 197764.jpg
# 197765.jpg
# 197766.jpg
# 197767.jpg
# 197768.jpg
# 197769.jpg
# 197770.jpg
# 197771.jpg
# 197772.jpg
# 197773.jpg
# 197774.jpg
# 197775.jpg
# 197776.jpg
# 197777.jpg
# 197778.jpg
# 197779.jpg
# 197780.jpg
# 197781.jpg
# 197782.jpg
# 197783.jpg
# 197784.jpg
# 197785.jpg
# 197786.jpg
# 197787.jpg
# 197788.jpg
# 197789.jpg
# 197790.jpg
# 197791.jpg
# 197792.jpg
# 197793.jpg
# 197794.jpg
# 197795.jpg
# 197796.jpg
# 197797.jpg
# 197798.jpg
# 197799.jpg
# 197800.jpg
# 197801.jpg
# 197802.jpg
# 197803.jpg
# 197804.jpg
# 197805.jpg
# 197806.jpg
# 197807.jpg
# 197808.jpg
# 197809.jpg
# 197810.jpg
# 197811.jpg
# 197812.jpg
# 197813.jpg
# 197814.jpg
# 197815.jpg
# 197816.jpg
# 197817.jpg
# 197818.jpg
# 197819.jpg
# 197820.jpg
# 197821.jpg
# 197822.jpg
# 197823.jpg
# 197824.jpg
# 197825.jpg
# 197826.jpg
# 197827.jpg
# 197828.jpg
# 197829.jpg
# 197830.jpg
# 197831.jpg
# 197832.jpg
# 197833.jpg
# 197834.jpg
# 197835.jpg
# 197836.jpg
# 197837.jpg
# 197838.jpg
# 197839.jpg
# 197840.jpg
# 197841.jpg
# 197842.jpg
# 197843.jpg
# 197844.jpg
# 197845.jpg
# 197846.jpg
# 197847.jpg
# 197848.jpg
# 197849.jpg
# 197850.jpg
# 197851.jpg
# 197852.jpg
# 197853.jpg
# 197854.jpg
# 197855.jpg
# 197856.jpg
# 197857.jpg
# 197858.jpg
# 197859.jpg
# 197860.jpg
# 197861.jpg
# 197862.jpg
# 197863.jpg
# 197864.jpg
# 197865.jpg
# 197866.jpg
# 197867.jpg
# 197868.jpg
# 197869.jpg
# 197870.jpg
# 197871.jpg
# 197872.jpg
# 197873.jpg
# 197874.jpg
# 197875.jpg
# 197876.jpg
# 197877.jpg
# 197878.jpg
# 197879.jpg
# 197880.jpg
# 197881.jpg
# 197882.jpg
# 197883.jpg
# 197884.jpg
# 197885.jpg
# 197886.jpg
# 197887.jpg
# 197888.jpg
# 197889.jpg
# 197890.jpg
# 197891.jpg
# 197892.jpg
# 197893.jpg
# 197894.jpg
# 197895.jpg
# 197896.jpg
# 197897.jpg
# 197898.jpg
# 197899.jpg
# 197900.jpg
# 197901.jpg
# 197902.jpg
# 197903.jpg
# 197904.jpg
# 197905.jpg
# 197906.jpg
# 197907.jpg
# 197908.jpg
# 197909.jpg
# 197910.jpg
# 197911.jpg
# 197912.jpg
# 197913.jpg
# 197914.jpg
# 197915.jpg
# 197916.jpg
# 197917.jpg
# 197918.jpg
# 197919.jpg
# 197920.jpg
# 197921.jpg
# 197922.jpg
# 197923.jpg
# 197924.jpg
# 197925.jpg
# 197926.jpg
# 197927.jpg
# 197928.jpg
# 197929.jpg
# 197930.jpg
# 197931.jpg
# 197932.jpg
# 197933.jpg
# 197934.jpg
# 197935.jpg
# 197936.jpg
# 197937.jpg
# 197938.jpg
# 197939.jpg
# 197940.jpg
# 197941.jpg
# 197942.jpg
# 197943.jpg
# 197944.jpg
# 197945.jpg
# 197946.jpg
# 197947.jpg
# 197948.jpg
# 197949.jpg
# 197950.jpg
# 197951.jpg
# 197952.jpg
# 197953.jpg
# 197954.jpg
# 197955.jpg
# 197956.jpg
# 197957.jpg
# 197958.jpg
# 197959.jpg
# 197960.jpg
# 197961.jpg
# 197962.jpg
# 197963.jpg
# 197964.jpg
# 197965.jpg
# 197966.jpg
# 197967.jpg
# 197968.jpg
# 197969.jpg
# 197970.jpg
# 197971.jpg
# 197972.jpg
# 197973.jpg
# 197974.jpg
# 197975.jpg
# 197976.jpg
# 197977.jpg
# 197978.jpg
# 197979.jpg
# 197980.jpg
# 197981.jpg
# 197982.jpg
# 197983.jpg
# 197984.jpg
# 197985.jpg
# 197986.jpg
# 197987.jpg
# 197988.jpg
# 197989.jpg
# 197990.jpg
# 197991.jpg
# 197992.jpg
# 197993.jpg
# 197994.jpg
# 197995.jpg
# 197996.jpg
# 197997.jpg
# 197998.jpg
# 197999.jpg
# 198000.jpg
# 198001.jpg
# 198002.jpg
# 198003.jpg
# 198004.jpg
# 198005.jpg
# 198006.jpg
# 198007.jpg
# 198008.jpg
# 198009.jpg
# 198010.jpg
# 198011.jpg
# 198012.jpg
# 198013.jpg
# 198014.jpg
# 198015.jpg
# 198016.jpg
# 198017.jpg
# 198018.jpg
# 198019.jpg
# 198020.jpg
# 198021.jpg
# 198022.jpg
# 198023.jpg
# 198024.jpg
# 198025.jpg
# 198026.jpg
# 198027.jpg
# 198028.jpg
# 198029.jpg
# 198030.jpg
# 198031.jpg
# 198032.jpg
# 198033.jpg
# 198034.jpg
# 198035.jpg
# 198036.jpg
# 198037.jpg
# 198038.jpg
# 198039.jpg
# 198040.jpg
# 198041.jpg
# 198042.jpg
# 198043.jpg
# 198044.jpg
# 198045.jpg
# 198046.jpg
# 198047.jpg
# 198048.jpg
# 198049.jpg
# 198050.jpg
# 198051.jpg
# 198052.jpg
# 198053.jpg
# 198054.jpg
# 198055.jpg
# 198056.jpg
# 198057.jpg
# 198058.jpg
# 198059.jpg
# 198060.jpg
# 198061.jpg
# 198062.jpg
# 198063.jpg
# 198064.jpg
# 198065.jpg
# 198066.jpg
# 198067.jpg
# 198068.jpg
# 198069.jpg
# 198070.jpg
# 198071.jpg
# 198072.jpg
# 198073.jpg
# 198074.jpg
# 198075.jpg
# 198076.jpg
# 198077.jpg
# 198078.jpg
# 198079.jpg
# 198080.jpg
# 198081.jpg
# 198082.jpg
# 198083.jpg
# 198084.jpg
# 198085.jpg
# 198086.jpg
# 198087.jpg
# 198088.jpg
# 198089.jpg
# 198090.jpg
# 198091.jpg
# 198092.jpg
# 198093.jpg
# 198094.jpg
# 198095.jpg
# 198096.jpg
# 198097.jpg
# 198098.jpg
# 198099.jpg
# 198100.jpg
# 198101.jpg
# 198102.jpg
# 198103.jpg
# 198104.jpg
# 198105.jpg
# 198106.jpg
# 198107.jpg
# 198108.jpg
# 198109.jpg
# 198110.jpg
# 198111.jpg
# 198112.jpg
# 198113.jpg
# 198114.jpg
# 198115.jpg
# 198116.jpg
# 198117.jpg
# 198118.jpg
# 198119.jpg
# 198120.jpg
# 198121.jpg
# 198122.jpg
# 198123.jpg
# 198124.jpg
# 198125.jpg
# 198126.jpg
# 198127.jpg
# 198128.jpg
# 198129.jpg
# 198130.jpg
# 198131.jpg
# 198132.jpg
# 198133.jpg
# 198134.jpg
# 198135.jpg
# 198136.jpg
# 198137.jpg
# 198138.jpg
# 198139.jpg
# 198140.jpg
# 198141.jpg
# 198142.jpg
# 198143.jpg
# 198144.jpg
# 198145.jpg
# 198146.jpg
# 198147.jpg
# 198148.jpg
# 198149.jpg
# 198150.jpg
# 198151.jpg
# 198152.jpg
# 198153.jpg
# 198154.jpg
# 198155.jpg
# 198156.jpg
# 198157.jpg
# 198158.jpg
# 198159.jpg
# 198160.jpg
# 198161.jpg
# 198162.jpg
# 198163.jpg
# 198164.jpg
# 198165.jpg
# 198166.jpg
# 198167.jpg
# 198168.jpg
# 198169.jpg
# 198170.jpg
# 198171.jpg
# 198172.jpg
# 198173.jpg
# 198174.jpg
# 198175.jpg
# 198176.jpg
# 198177.jpg
# 198178.jpg
# 198179.jpg
# 198180.jpg
# 198181.jpg
# 198182.jpg
# 198183.jpg
# 198184.jpg
# 198185.jpg
# 198186.jpg
# 198187.jpg
# 198188.jpg
# 198189.jpg
# 198190.jpg
# 198191.jpg
# 198192.jpg
# 198193.jpg
# 198194.jpg
# 198195.jpg
# 198196.jpg
# 198197.jpg
# 198198.jpg
# 198199.jpg
# 198200.jpg
# 198201.jpg
# 198202.jpg
# 198203.jpg
# 198204.jpg
# 198205.jpg
# 198206.jpg
# 198207.jpg
# 198208.jpg
# 198209.jpg
# 198210.jpg
# 198211.jpg
# 198212.jpg
# 198213.jpg
# 198214.jpg
# 198215.jpg
# 198216.jpg
# 198217.jpg
# 198218.jpg
# 198219.jpg
# 198220.jpg
# 198221.jpg
# 198222.jpg
# 198223.jpg
# 198224.jpg
# 198225.jpg
# 198226.jpg
# 198227.jpg
# 198228.jpg
# 198229.jpg
# 198230.jpg
# 198231.jpg
# 198232.jpg
# 198233.jpg
# 198234.jpg
# 198235.jpg
# 198236.jpg
# 198237.jpg
# 198238.jpg
# 198239.jpg
# 198240.jpg
# 198241.jpg
# 198242.jpg
# 198243.jpg
# 198244.jpg
# 198245.jpg
# 198246.jpg
# 198247.jpg
# 198248.jpg
# 198249.jpg
# 198250.jpg
# 198251.jpg
# 198252.jpg
# 198253.jpg
# 198254.jpg
# 198255.jpg
# 198256.jpg
# 198257.jpg
# 198258.jpg
# 198259.jpg
# 198260.jpg
# 198261.jpg
# 198262.jpg
# 198263.jpg
# 198264.jpg
# 198265.jpg
# 198266.jpg
# 198267.jpg
# 198268.jpg
# 198269.jpg
# 198270.jpg
# 198271.jpg
# 198272.jpg
# 198273.jpg
# 198274.jpg
# 198275.jpg
# 198276.jpg
# 198277.jpg
# 198278.jpg
# 198279.jpg
# 198280.jpg
# 198281.jpg
# 198282.jpg
# 198283.jpg
# 198284.jpg
# 198285.jpg
# 198286.jpg
# 198287.jpg
# 198288.jpg
# 198289.jpg
# 198290.jpg
# 198291.jpg
# 198292.jpg
# 198293.jpg
# 198294.jpg
# 198295.jpg
# 198296.jpg
# 198297.jpg
# 198298.jpg
# 198299.jpg
# 198300.jpg
# 198301.jpg
# 198302.jpg
# 198303.jpg
# 198304.jpg
# 198305.jpg
# 198306.jpg
# 198307.jpg
# 198308.jpg
# 198309.jpg
# 198310.jpg
# 198311.jpg
# 198312.jpg
# 198313.jpg
# 198314.jpg
# 198315.jpg
# 198316.jpg
# 198317.jpg
# 198318.jpg
# 198319.jpg
# 198320.jpg
# 198321.jpg
# 198322.jpg
# 198323.jpg
# 198324.jpg
# 198325.jpg
# 198326.jpg
# 198327.jpg
# 198328.jpg
# 198329.jpg
# 198330.jpg
# 198331.jpg
# 198332.jpg
# 198333.jpg
# 198334.jpg
# 198335.jpg
# 198336.jpg
# 198337.jpg
# 198338.jpg
# 198339.jpg
# 198340.jpg
# 198341.jpg
# 198342.jpg
# 198343.jpg
# 198344.jpg
# 198345.jpg
# 198346.jpg
# 198347.jpg
# 198348.jpg
# 198349.jpg
# 198350.jpg
# 198351.jpg
# 198352.jpg
# 198353.jpg
# 198354.jpg
# 198355.jpg
# 198356.jpg
# 198357.jpg
# 198358.jpg
# 198359.jpg
# 198360.jpg
# 198361.jpg
# 198362.jpg
# 198363.jpg
# 198364.jpg
# 198365.jpg
# 198366.jpg
# 198367.jpg
# 198368.jpg
# 198369.jpg
# 198370.jpg
# 198371.jpg
# 198372.jpg
# 198373.jpg
# 198374.jpg
# 198375.jpg
# 198376.jpg
# 198377.jpg
# 198378.jpg
# 198379.jpg
# 198380.jpg
# 198381.jpg
# 198382.jpg
# 198383.jpg
# 198384.jpg
# 198385.jpg
# 198386.jpg
# 198387.jpg
# 198388.jpg
# 198389.jpg
# 198390.jpg
# 198391.jpg
# 198392.jpg
# 198393.jpg
# 198394.jpg
# 198395.jpg
# 198396.jpg
# 198397.jpg
# 198398.jpg
# 198399.jpg
# 198400.jpg
# 198401.jpg
# 198402.jpg
# 198403.jpg
# 198404.jpg
# 198405.jpg
# 198406.jpg
# 198407.jpg
# 198408.jpg
# 198409.jpg
# 198410.jpg
# 198411.jpg
# 198412.jpg
# 198413.jpg
# 198414.jpg
# 198415.jpg
# 198416.jpg
# 198417.jpg
# 198418.jpg
# 198419.jpg
# 198420.jpg
# 198421.jpg
# 198422.jpg
# 198423.jpg
# 198424.jpg
# 198425.jpg
# 198426.jpg
# 198427.jpg
# 198428.jpg
# 198429.jpg
# 198430.jpg
# 198431.jpg
# 198432.jpg
# 198433.jpg
# 198434.jpg
# 198435.jpg
# 198436.jpg
# 198437.jpg
# 198438.jpg
# 198439.jpg
# 198440.jpg
# 198441.jpg
# 198442.jpg
# 198443.jpg
# 198444.jpg
# 198445.jpg
# 198446.jpg
# 198447.jpg
# 198448.jpg
# 198449.jpg
# 198450.jpg
# 198451.jpg
# 198452.jpg
# 198453.jpg
# 198454.jpg
# 198455.jpg
# 198456.jpg
# 198457.jpg
# 198458.jpg
# 198459.jpg
# 198460.jpg
# 198461.jpg
# 198462.jpg
# 198463.jpg
# 198464.jpg
# 198465.jpg
# 198466.jpg
# 198467.jpg
# 198468.jpg
# 198469.jpg
# 198470.jpg
# 198471.jpg
# 198472.jpg
# 198473.jpg
# 198474.jpg
# 198475.jpg
# 198476.jpg
# 198477.jpg
# 198478.jpg
# 198479.jpg
# 198480.jpg
# 198481.jpg
# 198482.jpg
# 198483.jpg
# 198484.jpg
# 198485.jpg
# 198486.jpg
# 198487.jpg
# 198488.jpg
# 198489.jpg
# 198490.jpg
# 198491.jpg
# 198492.jpg
# 198493.jpg
# 198494.jpg
# 198495.jpg
# 198496.jpg
# 198497.jpg
# 198498.jpg
# 198499.jpg
# 198500.jpg
# 198501.jpg
# 198502.jpg
# 198503.jpg
# 198504.jpg
# 198505.jpg
# 198506.jpg
# 198507.jpg
# 198508.jpg
# 198509.jpg
# 198510.jpg
# 198511.jpg
# 198512.jpg
# 198513.jpg
# 198514.jpg
# 198515.jpg
# 198516.jpg
# 198517.jpg
# 198518.jpg
# 198519.jpg
# 198520.jpg
# 198521.jpg
# 198522.jpg
# 198523.jpg
# 198524.jpg
# 198525.jpg
# 198526.jpg
# 198527.jpg
# 198528.jpg
# 198529.jpg
# 198530.jpg
# 198531.jpg
# 198532.jpg
# 198533.jpg
# 198534.jpg
# 198535.jpg
# 198536.jpg
# 198537.jpg
# 198538.jpg
# 198539.jpg
# 198540.jpg
# 198541.jpg
# 198542.jpg
# 198543.jpg
# 198544.jpg
# 198545.jpg
# 198546.jpg
# 198547.jpg
# 198548.jpg
# 198549.jpg
# 198550.jpg
# 198551.jpg
# 198552.jpg
# 198553.jpg
# 198554.jpg
# 198555.jpg
# 198556.jpg
# 198557.jpg
# 198558.jpg
# 198559.jpg
# 198560.jpg
# 198561.jpg
# 198562.jpg
# 198563.jpg
# 198564.jpg
# 198565.jpg
# 198566.jpg
# 198567.jpg
# 198568.jpg
# 198569.jpg
# 198570.jpg
# 198571.jpg
# 198572.jpg
# 198573.jpg
# 198574.jpg
# 198575.jpg
# 198576.jpg
# 198577.jpg
# 198578.jpg
# 198579.jpg
# 198580.jpg
# 198581.jpg
# 198582.jpg
# 198583.jpg
# 198584.jpg
# 198585.jpg
# 198586.jpg
# 198587.jpg
# 198588.jpg
# 198589.jpg
# 198590.jpg
# 198591.jpg
# 198592.jpg
# 198593.jpg
# 198594.jpg
# 198595.jpg
# 198596.jpg
# 198597.jpg
# 198598.jpg
# 198599.jpg
# 198600.jpg
# 198601.jpg
# 198602.jpg
# 198603.jpg
# 198604.jpg
# 198605.jpg
# 198606.jpg
# 198607.jpg
# 198608.jpg
# 198609.jpg
# 198610.jpg
# 198611.jpg
# 198612.jpg
# 198613.jpg
# 198614.jpg
# 198615.jpg
# 198616.jpg
# 198617.jpg
# 198618.jpg
# 198619.jpg
# 198620.jpg
# 198621.jpg
# 198622.jpg
# 198623.jpg
# 198624.jpg
# 198625.jpg
# 198626.jpg
# 198627.jpg
# 198628.jpg
# 198629.jpg
# 198630.jpg
# 198631.jpg
# 198632.jpg
# 198633.jpg
# 198634.jpg
# 198635.jpg
# 198636.jpg
# 198637.jpg
# 198638.jpg
# 198639.jpg
# 198640.jpg
# 198641.jpg
# 198642.jpg
# 198643.jpg
# 198644.jpg
# 198645.jpg
# 198646.jpg
# 198647.jpg
# 198648.jpg
# 198649.jpg
# 198650.jpg
# 198651.jpg
# 198652.jpg
# 198653.jpg
# 198654.jpg
# 198655.jpg
# 198656.jpg
# 198657.jpg
# 198658.jpg
# 198659.jpg
# 198660.jpg
# 198661.jpg
# 198662.jpg
# 198663.jpg
# 198664.jpg
# 198665.jpg
# 198666.jpg
# 198667.jpg
# 198668.jpg
# 198669.jpg
# 198670.jpg
# 198671.jpg
# 198672.jpg
# 198673.jpg
# 198674.jpg
# 198675.jpg
# 198676.jpg
# 198677.jpg
# 198678.jpg
# 198679.jpg
# 198680.jpg
# 198681.jpg
# 198682.jpg
# 198683.jpg
# 198684.jpg
# 198685.jpg
# 198686.jpg
# 198687.jpg
# 198688.jpg
# 198689.jpg
# 198690.jpg
# 198691.jpg
# 198692.jpg
# 198693.jpg
# 198694.jpg
# 198695.jpg
# 198696.jpg
# 198697.jpg
# 198698.jpg
# 198699.jpg
# 198700.jpg
# 198701.jpg
# 198702.jpg
# 198703.jpg
# 198704.jpg
# 198705.jpg
# 198706.jpg
# 198707.jpg
# 198708.jpg
# 198709.jpg
# 198710.jpg
# 198711.jpg
# 198712.jpg
# 198713.jpg
# 198714.jpg
# 198715.jpg
# 198716.jpg
# 198717.jpg
# 198718.jpg
# 198719.jpg
# 198720.jpg
# 198721.jpg
# 198722.jpg
# 198723.jpg
# 198724.jpg
# 198725.jpg
# 198726.jpg
# 198727.jpg
# 198728.jpg
# 198729.jpg
# 198730.jpg
# 198731.jpg
# 198732.jpg
# 198733.jpg
# 198734.jpg
# 198735.jpg
# 198736.jpg
# 198737.jpg
# 198738.jpg
# 198739.jpg
# 198740.jpg
# 198741.jpg
# 198742.jpg
# 198743.jpg
# 198744.jpg
# 198745.jpg
# 198746.jpg
# 198747.jpg
# 198748.jpg
# 198749.jpg
# 198750.jpg
# 198751.jpg
# 198752.jpg
# 198753.jpg
# 198754.jpg
# 198755.jpg
# 198756.jpg
# 198757.jpg
# 198758.jpg
# 198759.jpg
# 198760.jpg
# 198761.jpg
# 198762.jpg
# 198763.jpg
# 198764.jpg
# 198765.jpg
# 198766.jpg
# 198767.jpg
# 198768.jpg
# 198769.jpg
# 198770.jpg
# 198771.jpg
# 198772.jpg
# 198773.jpg
# 198774.jpg
# 198775.jpg
# 198776.jpg
# 198777.jpg
# 198778.jpg
# 198779.jpg
# 198780.jpg
# 198781.jpg
# 198782.jpg
# 198783.jpg
# 198784.jpg
# 198785.jpg
# 198786.jpg
# 198787.jpg
# 198788.jpg
# 198789.jpg
# 198790.jpg
# 198791.jpg
# 198792.jpg
# 198793.jpg
# 198794.jpg
# 198795.jpg
# 198796.jpg
# 198797.jpg
# 198798.jpg
# 198799.jpg
# 198800.jpg
# 198801.jpg
# 198802.jpg
# 198803.jpg
# 198804.jpg
# 198805.jpg
# 198806.jpg
# 198807.jpg
# 198808.jpg
# 198809.jpg
# 198810.jpg
# 198811.jpg
# 198812.jpg
# 198813.jpg
# 198814.jpg
# 198815.jpg
# 198816.jpg
# 198817.jpg
# 198818.jpg
# 198819.jpg
# 198820.jpg
# 198821.jpg
# 198822.jpg
# 198823.jpg
# 198824.jpg
# 198825.jpg
# 198826.jpg
# 198827.jpg
# 198828.jpg
# 198829.jpg
# 198830.jpg
# 198831.jpg
# 198832.jpg
# 198833.jpg
# 198834.jpg
# 198835.jpg
# 198836.jpg
# 198837.jpg
# 198838.jpg
# 198839.jpg
# 198840.jpg
# 198841.jpg
# 198842.jpg
# 198843.jpg
# 198844.jpg
# 198845.jpg
# 198846.jpg
# 198847.jpg
# 198848.jpg
# 198849.jpg
# 198850.jpg
# 198851.jpg
# 198852.jpg
# 198853.jpg
# 198854.jpg
# 198855.jpg
# 198856.jpg
# 198857.jpg
# 198858.jpg
# 198859.jpg
# 198860.jpg
# 198861.jpg
# 198862.jpg
# 198863.jpg
# 198864.jpg
# 198865.jpg
# 198866.jpg
# 198867.jpg
# 198868.jpg
# 198869.jpg
# 198870.jpg
# 198871.jpg
# 198872.jpg
# 198873.jpg
# 198874.jpg
# 198875.jpg
# 198876.jpg
# 198877.jpg
# 198878.jpg
# 198879.jpg
# 198880.jpg
# 198881.jpg
# 198882.jpg
# 198883.jpg
# 198884.jpg
# 198885.jpg
# 198886.jpg
# 198887.jpg
# 198888.jpg
# 198889.jpg
# 198890.jpg
# 198891.jpg
# 198892.jpg
# 198893.jpg
# 198894.jpg
# 198895.jpg
# 198896.jpg
# 198897.jpg
# 198898.jpg
# 198899.jpg
# 198900.jpg
# 198901.jpg
# 198902.jpg
# 198903.jpg
# 198904.jpg
# 198905.jpg
# 198906.jpg
# 198907.jpg
# 198908.jpg
# 198909.jpg
# 198910.jpg
# 198911.jpg
# 198912.jpg
# 198913.jpg
# 198914.jpg
# 198915.jpg
# 198916.jpg
# 198917.jpg
# 198918.jpg
# 198919.jpg
# 198920.jpg
# 198921.jpg
# 198922.jpg
# 198923.jpg
# 198924.jpg
# 198925.jpg
# 198926.jpg
# 198927.jpg
# 198928.jpg
# 198929.jpg
# 198930.jpg
# 198931.jpg
# 198932.jpg
# 198933.jpg
# 198934.jpg
# 198935.jpg
# 198936.jpg
# 198937.jpg
# 198938.jpg
# 198939.jpg
# 198940.jpg
# 198941.jpg
# 198942.jpg
# 198943.jpg
# 198944.jpg
# 198945.jpg
# 198946.jpg
# 198947.jpg
# 198948.jpg
# 198949.jpg
# 198950.jpg
# 198951.jpg
# 198952.jpg
# 198953.jpg
# 198954.jpg
# 198955.jpg
# 198956.jpg
# 198957.jpg
# 198958.jpg
# 198959.jpg
# 198960.jpg
# 198961.jpg
# 198962.jpg
# 198963.jpg
# 198964.jpg
# 198965.jpg
# 198966.jpg
# 198967.jpg
# 198968.jpg
# 198969.jpg
# 198970.jpg
# 198971.jpg
# 198972.jpg
# 198973.jpg
# 198974.jpg
# 198975.jpg
# 198976.jpg
# 198977.jpg
# 198978.jpg
# 198979.jpg
# 198980.jpg
# 198981.jpg
# 198982.jpg
# 198983.jpg
# 198984.jpg
# 198985.jpg
# 198986.jpg
# 198987.jpg
# 198988.jpg
# 198989.jpg
# 198990.jpg
# 198991.jpg
# 198992.jpg
# 198993.jpg
# 198994.jpg
# 198995.jpg
# 198996.jpg
# 198997.jpg
# 198998.jpg
# 198999.jpg
# 199000.jpg
# 199001.jpg
# 199002.jpg
# 199003.jpg
# 199004.jpg
# 199005.jpg
# 199006.jpg
# 199007.jpg
# 199008.jpg
# 199009.jpg
# 199010.jpg
# 199011.jpg
# 199012.jpg
# 199013.jpg
# 199014.jpg
# 199015.jpg
# 199016.jpg
# 199017.jpg
# 199018.jpg
# 199019.jpg
# 199020.jpg
# 199021.jpg
# 199022.jpg
# 199023.jpg
# 199024.jpg
# 199025.jpg
# 199026.jpg
# 199027.jpg
# 199028.jpg
# 199029.jpg
# 199030.jpg
# 199031.jpg
# 199032.jpg
# 199033.jpg
# 199034.jpg
# 199035.jpg
# 199036.jpg
# 199037.jpg
# 199038.jpg
# 199039.jpg
# 199040.jpg
# 199041.jpg
# 199042.jpg
# 199043.jpg
# 199044.jpg
# 199045.jpg
# 199046.jpg
# 199047.jpg
# 199048.jpg
# 199049.jpg
# 199050.jpg
# 199051.jpg
# 199052.jpg
# 199053.jpg
# 199054.jpg
# 199055.jpg
# 199056.jpg
# 199057.jpg
# 199058.jpg
# 199059.jpg
# 199060.jpg
# 199061.jpg
# 199062.jpg
# 199063.jpg
# 199064.jpg
# 199065.jpg
# 199066.jpg
# 199067.jpg
# 199068.jpg
# 199069.jpg
# 199070.jpg
# 199071.jpg
# 199072.jpg
# 199073.jpg
# 199074.jpg
# 199075.jpg
# 199076.jpg
# 199077.jpg
# 199078.jpg
# 199079.jpg
# 199080.jpg
# 199081.jpg
# 199082.jpg
# 199083.jpg
# 199084.jpg
# 199085.jpg
# 199086.jpg
# 199087.jpg
# 199088.jpg
# 199089.jpg
# 199090.jpg
# 199091.jpg
# 199092.jpg
# 199093.jpg
# 199094.jpg
# 199095.jpg
# 199096.jpg
# 199097.jpg
# 199098.jpg
# 199099.jpg
# 199100.jpg
# 199101.jpg
# 199102.jpg
# 199103.jpg
# 199104.jpg
# 199105.jpg
# 199106.jpg
# 199107.jpg
# 199108.jpg
# 199109.jpg
# 199110.jpg
# 199111.jpg
# 199112.jpg
# 199113.jpg
# 199114.jpg
# 199115.jpg
# 199116.jpg
# 199117.jpg
# 199118.jpg
# 199119.jpg
# 199120.jpg
# 199121.jpg
# 199122.jpg
# 199123.jpg
# 199124.jpg
# 199125.jpg
# 199126.jpg
# 199127.jpg
# 199128.jpg
# 199129.jpg
# 199130.jpg
# 199131.jpg
# 199132.jpg
# 199133.jpg
# 199134.jpg
# 199135.jpg
# 199136.jpg
# 199137.jpg
# 199138.jpg
# 199139.jpg
# 199140.jpg
# 199141.jpg
# 199142.jpg
# 199143.jpg
# 199144.jpg
# 199145.jpg
# 199146.jpg
# 199147.jpg
# 199148.jpg
# 199149.jpg
# 199150.jpg
# 199151.jpg
# 199152.jpg
# 199153.jpg
# 199154.jpg
# 199155.jpg
# 199156.jpg
# 199157.jpg
# 199158.jpg
# 199159.jpg
# 199160.jpg
# 199161.jpg
# 199162.jpg
# 199163.jpg
# 199164.jpg
# 199165.jpg
# 199166.jpg
# 199167.jpg
# 199168.jpg
# 199169.jpg
# 199170.jpg
# 199171.jpg
# 199172.jpg
# 199173.jpg
# 199174.jpg
# 199175.jpg
# 199176.jpg
# 199177.jpg
# 199178.jpg
# 199179.jpg
# 199180.jpg
# 199181.jpg
# 199182.jpg
# 199183.jpg
# 199184.jpg
# 199185.jpg
# 199186.jpg
# 199187.jpg
# 199188.jpg
# 199189.jpg
# 199190.jpg
# 199191.jpg
# 199192.jpg
# 199193.jpg
# 199194.jpg
# 199195.jpg
# 199196.jpg
# 199197.jpg
# 199198.jpg
# 199199.jpg
# 199200.jpg
# 199201.jpg
# 199202.jpg
# 199203.jpg
# 199204.jpg
# 199205.jpg
# 199206.jpg
# 199207.jpg
# 199208.jpg
# 199209.jpg
# 199210.jpg
# 199211.jpg
# 199212.jpg
# 199213.jpg
# 199214.jpg
# 199215.jpg
# 199216.jpg
# 199217.jpg
# 199218.jpg
# 199219.jpg
# 199220.jpg
# 199221.jpg
# 199222.jpg
# 199223.jpg
# 199224.jpg
# 199225.jpg
# 199226.jpg
# 199227.jpg
# 199228.jpg
# 199229.jpg
# 199230.jpg
# 199231.jpg
# 199232.jpg
# 199233.jpg
# 199234.jpg
# 199235.jpg
# 199236.jpg
# 199237.jpg
# 199238.jpg
# 199239.jpg
# 199240.jpg
# 199241.jpg
# 199242.jpg
# 199243.jpg
# 199244.jpg
# 199245.jpg
# 199246.jpg
# 199247.jpg
# 199248.jpg
# 199249.jpg
# 199250.jpg
# 199251.jpg
# 199252.jpg
# 199253.jpg
# 199254.jpg
# 199255.jpg
# 199256.jpg
# 199257.jpg
# 199258.jpg
# 199259.jpg
# 199260.jpg
# 199261.jpg
# 199262.jpg
# 199263.jpg
# 199264.jpg
# 199265.jpg
# 199266.jpg
# 199267.jpg
# 199268.jpg
# 199269.jpg
# 199270.jpg
# 199271.jpg
# 199272.jpg
# 199273.jpg
# 199274.jpg
# 199275.jpg
# 199276.jpg
# 199277.jpg
# 199278.jpg
# 199279.jpg
# 199280.jpg
# 199281.jpg
# 199282.jpg
# 199283.jpg
# 199284.jpg
# 199285.jpg
# 199286.jpg
# 199287.jpg
# 199288.jpg
# 199289.jpg
# 199290.jpg
# 199291.jpg
# 199292.jpg
# 199293.jpg
# 199294.jpg
# 199295.jpg
# 199296.jpg
# 199297.jpg
# 199298.jpg
# 199299.jpg
# 199300.jpg
# 199301.jpg
# 199302.jpg
# 199303.jpg
# 199304.jpg
# 199305.jpg
# 199306.jpg
# 199307.jpg
# 199308.jpg
# 199309.jpg
# 199310.jpg
# 199311.jpg
# 199312.jpg
# 199313.jpg
# 199314.jpg
# 199315.jpg
# 199316.jpg
# 199317.jpg
# 199318.jpg
# 199319.jpg
# 199320.jpg
# 199321.jpg
# 199322.jpg
# 199323.jpg
# 199324.jpg
# 199325.jpg
# 199326.jpg
# 199327.jpg
# 199328.jpg
# 199329.jpg
# 199330.jpg
# 199331.jpg
# 199332.jpg
# 199333.jpg
# 199334.jpg
# 199335.jpg
# 199336.jpg
# 199337.jpg
# 199338.jpg
# 199339.jpg
# 199340.jpg
# 199341.jpg
# 199342.jpg
# 199343.jpg
# 199344.jpg
# 199345.jpg
# 199346.jpg
# 199347.jpg
# 199348.jpg
# 199349.jpg
# 199350.jpg
# 199351.jpg
# 199352.jpg
# 199353.jpg
# 199354.jpg
# 199355.jpg
# 199356.jpg
# 199357.jpg
# 199358.jpg
# 199359.jpg
# 199360.jpg
# 199361.jpg
# 199362.jpg
# 199363.jpg
# 199364.jpg
# 199365.jpg
# 199366.jpg
# 199367.jpg
# 199368.jpg
# 199369.jpg
# 199370.jpg
# 199371.jpg
# 199372.jpg
# 199373.jpg
# 199374.jpg
# 199375.jpg
# 199376.jpg
# 199377.jpg
# 199378.jpg
# 199379.jpg
# 199380.jpg
# 199381.jpg
# 199382.jpg
# 199383.jpg
# 199384.jpg
# 199385.jpg
# 199386.jpg
# 199387.jpg
# 199388.jpg
# 199389.jpg
# 199390.jpg
# 199391.jpg
# 199392.jpg
# 199393.jpg
# 199394.jpg
# 199395.jpg
# 199396.jpg
# 199397.jpg
# 199398.jpg
# 199399.jpg
# 199400.jpg
# 199401.jpg
# 199402.jpg
# 199403.jpg
# 199404.jpg
# 199405.jpg
# 199406.jpg
# 199407.jpg
# 199408.jpg
# 199409.jpg
# 199410.jpg
# 199411.jpg
# 199412.jpg
# 199413.jpg
# 199414.jpg
# 199415.jpg
# 199416.jpg
# 199417.jpg
# 199418.jpg
# 199419.jpg
# 199420.jpg
# 199421.jpg
# 199422.jpg
# 199423.jpg
# 199424.jpg
# 199425.jpg
# 199426.jpg
# 199427.jpg
# 199428.jpg
# 199429.jpg
# 199430.jpg
# 199431.jpg
# 199432.jpg
# 199433.jpg
# 199434.jpg
# 199435.jpg
# 199436.jpg
# 199437.jpg
# 199438.jpg
# 199439.jpg
# 199440.jpg
# 199441.jpg
# 199442.jpg
# 199443.jpg
# 199444.jpg
# 199445.jpg
# 199446.jpg
# 199447.jpg
# 199448.jpg
# 199449.jpg
# 199450.jpg
# 199451.jpg
# 199452.jpg
# 199453.jpg
# 199454.jpg
# 199455.jpg
# 199456.jpg
# 199457.jpg
# 199458.jpg
# 199459.jpg
# 199460.jpg
# 199461.jpg
# 199462.jpg
# 199463.jpg
# 199464.jpg
# 199465.jpg
# 199466.jpg
# 199467.jpg
# 199468.jpg
# 199469.jpg
# 199470.jpg
# 199471.jpg
# 199472.jpg
# 199473.jpg
# 199474.jpg
# 199475.jpg
# 199476.jpg
# 199477.jpg
# 199478.jpg
# 199479.jpg
# 199480.jpg
# 199481.jpg
# 199482.jpg
# 199483.jpg
# 199484.jpg
# 199485.jpg
# 199486.jpg
# 199487.jpg
# 199488.jpg
# 199489.jpg
# 199490.jpg
# 199491.jpg
# 199492.jpg
# 199493.jpg
# 199494.jpg
# 199495.jpg
# 199496.jpg
# 199497.jpg
# 199498.jpg
# 199499.jpg
# 199500.jpg
# 199501.jpg
# 199502.jpg
# 199503.jpg
# 199504.jpg
# 199505.jpg
# 199506.jpg
# 199507.jpg
# 199508.jpg
# 199509.jpg
# 199510.jpg
# 199511.jpg
# 199512.jpg
# 199513.jpg
# 199514.jpg
# 199515.jpg
# 199516.jpg
# 199517.jpg
# 199518.jpg
# 199519.jpg
# 199520.jpg
# 199521.jpg
# 199522.jpg
# 199523.jpg
# 199524.jpg
# 199525.jpg
# 199526.jpg
# 199527.jpg
# 199528.jpg
# 199529.jpg
# 199530.jpg
# 199531.jpg
# 199532.jpg
# 199533.jpg
# 199534.jpg
# 199535.jpg
# 199536.jpg
# 199537.jpg
# 199538.jpg
# 199539.jpg
# 199540.jpg
# 199541.jpg
# 199542.jpg
# 199543.jpg
# 199544.jpg
# 199545.jpg
# 199546.jpg
# 199547.jpg
# 199548.jpg
# 199549.jpg
# 199550.jpg
# 199551.jpg
# 199552.jpg
# 199553.jpg
# 199554.jpg
# 199555.jpg
# 199556.jpg
# 199557.jpg
# 199558.jpg
# 199559.jpg
# 199560.jpg
# 199561.jpg
# 199562.jpg
# 199563.jpg
# 199564.jpg
# 199565.jpg
# 199566.jpg
# 199567.jpg
# 199568.jpg
# 199569.jpg
# 199570.jpg
# 199571.jpg
# 199572.jpg
# 199573.jpg
# 199574.jpg
# 199575.jpg
# 199576.jpg
# 199577.jpg
# 199578.jpg
# 199579.jpg
# 199580.jpg
# 199581.jpg
# 199582.jpg
# 199583.jpg
# 199584.jpg
# 199585.jpg
# 199586.jpg
# 199587.jpg
# 199588.jpg
# 199589.jpg
# 199590.jpg
# 199591.jpg
# 199592.jpg
# 199593.jpg
# 199594.jpg
# 199595.jpg
# 199596.jpg
# 199597.jpg
# 199598.jpg
# 199599.jpg
# 199600.jpg
# 199601.jpg
# 199602.jpg
# 199603.jpg
# 199604.jpg
# 199605.jpg
# 199606.jpg
# 199607.jpg
# 199608.jpg
# 199609.jpg
# 199610.jpg
# 199611.jpg
# 199612.jpg
# 199613.jpg
# 199614.jpg
# 199615.jpg
# 199616.jpg
# 199617.jpg
# 199618.jpg
# 199619.jpg
# 199620.jpg
# 199621.jpg
# 199622.jpg
# 199623.jpg
# 199624.jpg
# 199625.jpg
# 199626.jpg
# 199627.jpg
# 199628.jpg
# 199629.jpg
# 199630.jpg
# 199631.jpg
# 199632.jpg
# 199633.jpg
# 199634.jpg
# 199635.jpg
# 199636.jpg
# 199637.jpg
# 199638.jpg
# 199639.jpg
# 199640.jpg
# 199641.jpg
# 199642.jpg
# 199643.jpg
# 199644.jpg
# 199645.jpg
# 199646.jpg
# 199647.jpg
# 199648.jpg
# 199649.jpg
# 199650.jpg
# 199651.jpg
# 199652.jpg
# 199653.jpg
# 199654.jpg
# 199655.jpg
# 199656.jpg
# 199657.jpg
# 199658.jpg
# 199659.jpg
# 199660.jpg
# 199661.jpg
# 199662.jpg
# 199663.jpg
# 199664.jpg
# 199665.jpg
# 199666.jpg
# 199667.jpg
# 199668.jpg
# 199669.jpg
# 199670.jpg
# 199671.jpg
# 199672.jpg
# 199673.jpg
# 199674.jpg
# 199675.jpg
# 199676.jpg
# 199677.jpg
# 199678.jpg
# 199679.jpg
# 199680.jpg
# 199681.jpg
# 199682.jpg
# 199683.jpg
# 199684.jpg
# 199685.jpg
# 199686.jpg
# 199687.jpg
# 199688.jpg
# 199689.jpg
# 199690.jpg
# 199691.jpg
# 199692.jpg
# 199693.jpg
# 199694.jpg
# 199695.jpg
# 199696.jpg
# 199697.jpg
# 199698.jpg
# 199699.jpg
# 199700.jpg
# 199701.jpg
# 199702.jpg
# 199703.jpg
# 199704.jpg
# 199705.jpg
# 199706.jpg
# 199707.jpg
# 199708.jpg
# 199709.jpg
# 199710.jpg
# 199711.jpg
# 199712.jpg
# 199713.jpg
# 199714.jpg
# 199715.jpg
# 199716.jpg
# 199717.jpg
# 199718.jpg
# 199719.jpg
# 199720.jpg
# 199721.jpg
# 199722.jpg
# 199723.jpg
# 199724.jpg
# 199725.jpg
# 199726.jpg
# 199727.jpg
# 199728.jpg
# 199729.jpg
# 199730.jpg
# 199731.jpg
# 199732.jpg
# 199733.jpg
# 199734.jpg
# 199735.jpg
# 199736.jpg
# 199737.jpg
# 199738.jpg
# 199739.jpg
# 199740.jpg
# 199741.jpg
# 199742.jpg
# 199743.jpg
# 199744.jpg
# 199745.jpg
# 199746.jpg
# 199747.jpg
# 199748.jpg
# 199749.jpg
# 199750.jpg
# 199751.jpg
# 199752.jpg
# 199753.jpg
# 199754.jpg
# 199755.jpg
# 199756.jpg
# 199757.jpg
# 199758.jpg
# 199759.jpg
# 199760.jpg
# 199761.jpg
# 199762.jpg
# 199763.jpg
# 199764.jpg
# 199765.jpg
# 199766.jpg
# 199767.jpg
# 199768.jpg
# 199769.jpg
# 199770.jpg
# 199771.jpg
# 199772.jpg
# 199773.jpg
# 199774.jpg
# 199775.jpg
# 199776.jpg
# 199777.jpg
# 199778.jpg
# 199779.jpg
# 199780.jpg
# 199781.jpg
# 199782.jpg
# 199783.jpg
# 199784.jpg
# 199785.jpg
# 199786.jpg
# 199787.jpg
# 199788.jpg
# 199789.jpg
# 199790.jpg
# 199791.jpg
# 199792.jpg
# 199793.jpg
# 199794.jpg
# 199795.jpg
# 199796.jpg
# 199797.jpg
# 199798.jpg
# 199799.jpg
# 199800.jpg
# 199801.jpg
# 199802.jpg
# 199803.jpg
# 199804.jpg
# 199805.jpg
# 199806.jpg
# 199807.jpg
# 199808.jpg
# 199809.jpg
# 199810.jpg
# 199811.jpg
# 199812.jpg
# 199813.jpg
# 199814.jpg
# 199815.jpg
# 199816.jpg
# 199817.jpg
# 199818.jpg
# 199819.jpg
# 199820.jpg
# 199821.jpg
# 199822.jpg
# 199823.jpg
# 199824.jpg
# 199825.jpg
# 199826.jpg
# 199827.jpg
# 199828.jpg
# 199829.jpg
# 199830.jpg
# 199831.jpg
# 199832.jpg
# 199833.jpg
# 199834.jpg
# 199835.jpg
# 199836.jpg
# 199837.jpg
# 199838.jpg
# 199839.jpg
# 199840.jpg
# 199841.jpg
# 199842.jpg
# 199843.jpg
# 199844.jpg
# 199845.jpg
# 199846.jpg
# 199847.jpg
# 199848.jpg
# 199849.jpg
# 199850.jpg
# 199851.jpg
# 199852.jpg
# 199853.jpg
# 199854.jpg
# 199855.jpg
# 199856.jpg
# 199857.jpg
# 199858.jpg
# 199859.jpg
# 199860.jpg
# 199861.jpg
# 199862.jpg
# 199863.jpg
# 199864.jpg
# 199865.jpg
# 199866.jpg
# 199867.jpg
# 199868.jpg
# 199869.jpg
# 199870.jpg
# 199871.jpg
# 199872.jpg
# 199873.jpg
# 199874.jpg
# 199875.jpg
# 199876.jpg
# 199877.jpg
# 199878.jpg
# 199879.jpg
# 199880.jpg
# 199881.jpg
# 199882.jpg
# 199883.jpg
# 199884.jpg
# 199885.jpg
# 199886.jpg
# 199887.jpg
# 199888.jpg
# 199889.jpg
# 199890.jpg
# 199891.jpg
# 199892.jpg
# 199893.jpg
# 199894.jpg
# 199895.jpg
# 199896.jpg
# 199897.jpg
# 199898.jpg
# 199899.jpg
# 199900.jpg
# 199901.jpg
# 199902.jpg
# 199903.jpg
# 199904.jpg
# 199905.jpg
# 199906.jpg
# 199907.jpg
# 199908.jpg
# 199909.jpg
# 199910.jpg
# 199911.jpg
# 199912.jpg
# 199913.jpg
# 199914.jpg
# 199915.jpg
# 199916.jpg
# 199917.jpg
# 199918.jpg
# 199919.jpg
# 199920.jpg
# 199921.jpg
# 199922.jpg
# 199923.jpg
# 199924.jpg
# 199925.jpg
# 199926.jpg
# 199927.jpg
# 199928.jpg
# 199929.jpg
# 199930.jpg
# 199931.jpg
# 199932.jpg
# 199933.jpg
# 199934.jpg
# 199935.jpg
# 199936.jpg
# 199937.jpg
# 199938.jpg
# 199939.jpg
# 199940.jpg
# 199941.jpg
# 199942.jpg
# 199943.jpg
# 199944.jpg
# 199945.jpg
# 199946.jpg
# 199947.jpg
# 199948.jpg
# 199949.jpg
# 199950.jpg
# 199951.jpg
# 199952.jpg
# 199953.jpg
# 199954.jpg
# 199955.jpg
# 199956.jpg
# 199957.jpg
# 199958.jpg
# 199959.jpg
# 199960.jpg
# 199961.jpg
# 199962.jpg
# 199963.jpg
# 199964.jpg
# 199965.jpg
# 199966.jpg
# 199967.jpg
# 199968.jpg
# 199969.jpg
# 199970.jpg
# 199971.jpg
# 199972.jpg
# 199973.jpg
# 199974.jpg
# 199975.jpg
# 199976.jpg
# 199977.jpg
# 199978.jpg
# 199979.jpg
# 199980.jpg
# 199981.jpg
# 199982.jpg
# 199983.jpg
# 199984.jpg
# 199985.jpg
# 199986.jpg
# 199987.jpg
# 199988.jpg
# 199989.jpg
# 199990.jpg
# 199991.jpg
# 199992.jpg
# 199993.jpg
# 199994.jpg
# 199995.jpg
# 199996.jpg
# 199997.jpg
# 199998.jpg
# 199999.jpg
# 200000.jpg
# 200001.jpg
# 200002.jpg
# 200003.jpg
# 200004.jpg
# 200005.jpg
# 200006.jpg
# 200007.jpg
# 200008.jpg
# 200009.jpg
# 200010.jpg
# 200011.jpg
# 200012.jpg
# 200013.jpg
# 200014.jpg
# 200015.jpg
# 200016.jpg
# 200017.jpg
# 200018.jpg
# 200019.jpg
# 200020.jpg
# 200021.jpg
# 200022.jpg
# 200023.jpg
# 200024.jpg
# 200025.jpg
# 200026.jpg
# 200027.jpg
# 200028.jpg
# 200029.jpg
# 200030.jpg
# 200031.jpg
# 200032.jpg
# 200033.jpg
# 200034.jpg
# 200035.jpg
# 200036.jpg
# 200037.jpg
# 200038.jpg
# 200039.jpg
# 200040.jpg
# 200041.jpg
# 200042.jpg
# 200043.jpg
# 200044.jpg
# 200045.jpg
# 200046.jpg
# 200047.jpg
# 200048.jpg
# 200049.jpg
# 200050.jpg
# 200051.jpg
# 200052.jpg
# 200053.jpg
# 200054.jpg
# 200055.jpg
# 200056.jpg
# 200057.jpg
# 200058.jpg
# 200059.jpg
# 200060.jpg
# 200061.jpg
# 200062.jpg
# 200063.jpg
# 200064.jpg
# 200065.jpg
# 200066.jpg
# 200067.jpg
# 200068.jpg
# 200069.jpg
# 200070.jpg
# 200071.jpg
# 200072.jpg
# 200073.jpg
# 200074.jpg
# 200075.jpg
# 200076.jpg
# 200077.jpg
# 200078.jpg
# 200079.jpg
# 200080.jpg
# 200081.jpg
# 200082.jpg
# 200083.jpg
# 200084.jpg
# 200085.jpg
# 200086.jpg
# 200087.jpg
# 200088.jpg
# 200089.jpg
# 200090.jpg
# 200091.jpg
# 200092.jpg
# 200093.jpg
# 200094.jpg
# 200095.jpg
# 200096.jpg
# 200097.jpg
# 200098.jpg
# 200099.jpg
# 200100.jpg
# 200101.jpg
# 200102.jpg
# 200103.jpg
# 200104.jpg
# 200105.jpg
# 200106.jpg
# 200107.jpg
# 200108.jpg
# 200109.jpg
# 200110.jpg
# 200111.jpg
# 200112.jpg
# 200113.jpg
# 200114.jpg
# 200115.jpg
# 200116.jpg
# 200117.jpg
# 200118.jpg
# 200119.jpg
# 200120.jpg
# 200121.jpg
# 200122.jpg
# 200123.jpg
# 200124.jpg
# 200125.jpg
# 200126.jpg
# 200127.jpg
# 200128.jpg
# 200129.jpg
# 200130.jpg
# 200131.jpg
# 200132.jpg
# 200133.jpg
# 200134.jpg
# 200135.jpg
# 200136.jpg
# 200137.jpg
# 200138.jpg
# 200139.jpg
# 200140.jpg
# 200141.jpg
# 200142.jpg
# 200143.jpg
# 200144.jpg
# 200145.jpg
# 200146.jpg
# 200147.jpg
# 200148.jpg
# 200149.jpg
# 200150.jpg
# 200151.jpg
# 200152.jpg
# 200153.jpg
# 200154.jpg
# 200155.jpg
# 200156.jpg
# 200157.jpg
# 200158.jpg
# 200159.jpg
# 200160.jpg
# 200161.jpg
# 200162.jpg
# 200163.jpg
# 200164.jpg
# 200165.jpg
# 200166.jpg
# 200167.jpg
# 200168.jpg
# 200169.jpg
# 200170.jpg
# 200171.jpg
# 200172.jpg
# 200173.jpg
# 200174.jpg
# 200175.jpg
# 200176.jpg
# 200177.jpg
# 200178.jpg
# 200179.jpg
# 200180.jpg
# 200181.jpg
# 200182.jpg
# 200183.jpg
# 200184.jpg
# 200185.jpg
# 200186.jpg
# 200187.jpg
# 200188.jpg
# 200189.jpg
# 200190.jpg
# 200191.jpg
# 200192.jpg
# 200193.jpg
# 200194.jpg
# 200195.jpg
# 200196.jpg
# 200197.jpg
# 200198.jpg
# 200199.jpg
# 200200.jpg
# 200201.jpg
# 200202.jpg
# 200203.jpg
# 200204.jpg
# 200205.jpg
# 200206.jpg
# 200207.jpg
# 200208.jpg
# 200209.jpg
# 200210.jpg
# 200211.jpg
# 200212.jpg
# 200213.jpg
# 200214.jpg
# 200215.jpg
# 200216.jpg
# 200217.jpg
# 200218.jpg
# 200219.jpg
# 200220.jpg
# 200221.jpg
# 200222.jpg
# 200223.jpg
# 200224.jpg
# 200225.jpg
# 200226.jpg
# 200227.jpg
# 200228.jpg
# 200229.jpg
# 200230.jpg
# 200231.jpg
# 200232.jpg
# 200233.jpg
# 200234.jpg
# 200235.jpg
# 200236.jpg
# 200237.jpg
# 200238.jpg
# 200239.jpg
# 200240.jpg
# 200241.jpg
# 200242.jpg
# 200243.jpg
# 200244.jpg
# 200245.jpg
# 200246.jpg
# 200247.jpg
# 200248.jpg
# 200249.jpg
# 200250.jpg
# 200251.jpg
# 200252.jpg
# 200253.jpg
# 200254.jpg
# 200255.jpg
# 200256.jpg
# 200257.jpg
# 200258.jpg
# 200259.jpg
# 200260.jpg
# 200261.jpg
# 200262.jpg
# 200263.jpg
# 200264.jpg
# 200265.jpg
# 200266.jpg
# 200267.jpg
# 200268.jpg
# 200269.jpg
# 200270.jpg
# 200271.jpg
# 200272.jpg
# 200273.jpg
# 200274.jpg
# 200275.jpg
# 200276.jpg
# 200277.jpg
# 200278.jpg
# 200279.jpg
# 200280.jpg
# 200281.jpg
# 200282.jpg
# 200283.jpg
# 200284.jpg
# 200285.jpg
# 200286.jpg
# 200287.jpg
# 200288.jpg
# 200289.jpg
# 200290.jpg
# 200291.jpg
# 200292.jpg
# 200293.jpg
# 200294.jpg
# 200295.jpg
# 200296.jpg
# 200297.jpg
# 200298.jpg
# 200299.jpg
# 200300.jpg
# 200301.jpg
# 200302.jpg
# 200303.jpg
# 200304.jpg
# 200305.jpg
# 200306.jpg
# 200307.jpg
# 200308.jpg
# 200309.jpg
# 200310.jpg
# 200311.jpg
# 200312.jpg
# 200313.jpg
# 200314.jpg
# 200315.jpg
# 200316.jpg
# 200317.jpg
# 200318.jpg
# 200319.jpg
# 200320.jpg
# 200321.jpg
# 200322.jpg
# 200323.jpg
# 200324.jpg
# 200325.jpg
# 200326.jpg
# 200327.jpg
# 200328.jpg
# 200329.jpg
# 200330.jpg
# 200331.jpg
# 200332.jpg
# 200333.jpg
# 200334.jpg
# 200335.jpg
# 200336.jpg
# 200337.jpg
# 200338.jpg
# 200339.jpg
# 200340.jpg
# 200341.jpg
# 200342.jpg
# 200343.jpg
# 200344.jpg
# 200345.jpg
# 200346.jpg
# 200347.jpg
# 200348.jpg
# 200349.jpg
# 200350.jpg
# 200351.jpg
# 200352.jpg
# 200353.jpg
# 200354.jpg
# 200355.jpg
# 200356.jpg
# 200357.jpg
# 200358.jpg
# 200359.jpg
# 200360.jpg
# 200361.jpg
# 200362.jpg
# 200363.jpg
# 200364.jpg
# 200365.jpg
# 200366.jpg
# 200367.jpg
# 200368.jpg
# 200369.jpg
# 200370.jpg
# 200371.jpg
# 200372.jpg
# 200373.jpg
# 200374.jpg
# 200375.jpg
# 200376.jpg
# 200377.jpg
# 200378.jpg
# 200379.jpg
# 200380.jpg
# 200381.jpg
# 200382.jpg
# 200383.jpg
# 200384.jpg
# 200385.jpg
# 200386.jpg
# 200387.jpg
# 200388.jpg
# 200389.jpg
# 200390.jpg
# 200391.jpg
# 200392.jpg
# 200393.jpg
# 200394.jpg
# 200395.jpg
# 200396.jpg
# 200397.jpg
# 200398.jpg
# 200399.jpg
# 200400.jpg
# 200401.jpg
# 200402.jpg
# 200403.jpg
# 200404.jpg
# 200405.jpg
# 200406.jpg
# 200407.jpg
# 200408.jpg
# 200409.jpg
# 200410.jpg
# 200411.jpg
# 200412.jpg
# 200413.jpg
# 200414.jpg
# 200415.jpg
# 200416.jpg
# 200417.jpg
# 200418.jpg
# 200419.jpg
# 200420.jpg
# 200421.jpg
# 200422.jpg
# 200423.jpg
# 200424.jpg
# 200425.jpg
# 200426.jpg
# 200427.jpg
# 200428.jpg
# 200429.jpg
# 200430.jpg
# 200431.jpg
# 200432.jpg
# 200433.jpg
# 200434.jpg
# 200435.jpg
# 200436.jpg
# 200437.jpg
# 200438.jpg
# 200439.jpg
# 200440.jpg
# 200441.jpg
# 200442.jpg
# 200443.jpg
# 200444.jpg
# 200445.jpg
# 200446.jpg
# 200447.jpg
# 200448.jpg
# 200449.jpg
# 200450.jpg
# 200451.jpg
# 200452.jpg
# 200453.jpg
# 200454.jpg
# 200455.jpg
# 200456.jpg
# 200457.jpg
# 200458.jpg
# 200459.jpg
# 200460.jpg
# 200461.jpg
# 200462.jpg
# 200463.jpg
# 200464.jpg
# 200465.jpg
# 200466.jpg
# 200467.jpg
# 200468.jpg
# 200469.jpg
# 200470.jpg
# 200471.jpg
# 200472.jpg
# 200473.jpg
# 200474.jpg
# 200475.jpg
# 200476.jpg
# 200477.jpg
# 200478.jpg
# 200479.jpg
# 200480.jpg
# 200481.jpg
# 200482.jpg
# 200483.jpg
# 200484.jpg
# 200485.jpg
# 200486.jpg
# 200487.jpg
# 200488.jpg
# 200489.jpg
# 200490.jpg
# 200491.jpg
# 200492.jpg
# 200493.jpg
# 200494.jpg
# 200495.jpg
# 200496.jpg
# 200497.jpg
# 200498.jpg
# 200499.jpg
# 200500.jpg
# 200501.jpg
# 200502.jpg
# 200503.jpg
# 200504.jpg
# 200505.jpg
# 200506.jpg
# 200507.jpg
# 200508.jpg
# 200509.jpg
# 200510.jpg
# 200511.jpg
# 200512.jpg
# 200513.jpg
# 200514.jpg
# 200515.jpg
# 200516.jpg
# 200517.jpg
# 200518.jpg
# 200519.jpg
# 200520.jpg
# 200521.jpg
# 200522.jpg
# 200523.jpg
# 200524.jpg
# 200525.jpg
# 200526.jpg
# 200527.jpg
# 200528.jpg
# 200529.jpg
# 200530.jpg
# 200531.jpg
# 200532.jpg
# 200533.jpg
# 200534.jpg
# 200535.jpg
# 200536.jpg
# 200537.jpg
# 200538.jpg
# 200539.jpg
# 200540.jpg
# 200541.jpg
# 200542.jpg
# 200543.jpg
# 200544.jpg
# 200545.jpg
# 200546.jpg
# 200547.jpg
# 200548.jpg
# 200549.jpg
# 200550.jpg
# 200551.jpg
# 200552.jpg
# 200553.jpg
# 200554.jpg
# 200555.jpg
# 200556.jpg
# 200557.jpg
# 200558.jpg
# 200559.jpg
# 200560.jpg
# 200561.jpg
# 200562.jpg
# 200563.jpg
# 200564.jpg
# 200565.jpg
# 200566.jpg
# 200567.jpg
# 200568.jpg
# 200569.jpg
# 200570.jpg
# 200571.jpg
# 200572.jpg
# 200573.jpg
# 200574.jpg
# 200575.jpg
# 200576.jpg
# 200577.jpg
# 200578.jpg
# 200579.jpg
# 200580.jpg
# 200581.jpg
# 200582.jpg
# 200583.jpg
# 200584.jpg
# 200585.jpg
# 200586.jpg
# 200587.jpg
# 200588.jpg
# 200589.jpg
# 200590.jpg
# 200591.jpg
# 200592.jpg
# 200593.jpg
# 200594.jpg
# 200595.jpg
# 200596.jpg
# 200597.jpg
# 200598.jpg
# 200599.jpg
# 200600.jpg
# 200601.jpg
# 200602.jpg
# 200603.jpg
# 200604.jpg
# 200605.jpg
# 200606.jpg
# 200607.jpg
# 200608.jpg
# 200609.jpg
# 200610.jpg
# 200611.jpg
# 200612.jpg
# 200613.jpg
# 200614.jpg
# 200615.jpg
# 200616.jpg
# 200617.jpg
# 200618.jpg
# 200619.jpg
# 200620.jpg
# 200621.jpg
# 200622.jpg
# 200623.jpg
# 200624.jpg
# 200625.jpg
# 200626.jpg
# 200627.jpg
# 200628.jpg
# 200629.jpg
# 200630.jpg
# 200631.jpg
# 200632.jpg
# 200633.jpg
# 200634.jpg
# 200635.jpg
# 200636.jpg
# 200637.jpg
# 200638.jpg
# 200639.jpg
# 200640.jpg
# 200641.jpg
# 200642.jpg
# 200643.jpg
# 200644.jpg
# 200645.jpg
# 200646.jpg
# 200647.jpg
# 200648.jpg
# 200649.jpg
# 200650.jpg
# 200651.jpg
# 200652.jpg
# 200653.jpg
# 200654.jpg
# 200655.jpg
# 200656.jpg
# 200657.jpg
# 200658.jpg
# 200659.jpg
# 200660.jpg
# 200661.jpg
# 200662.jpg
# 200663.jpg
# 200664.jpg
# 200665.jpg
# 200666.jpg
# 200667.jpg
# 200668.jpg
# 200669.jpg
# 200670.jpg
# 200671.jpg
# 200672.jpg
# 200673.jpg
# 200674.jpg
# 200675.jpg
# 200676.jpg
# 200677.jpg
# 200678.jpg
# 200679.jpg
# 200680.jpg
# 200681.jpg
# 200682.jpg
# 200683.jpg
# 200684.jpg
# 200685.jpg
# 200686.jpg
# 200687.jpg
# 200688.jpg
# 200689.jpg
# 200690.jpg
# 200691.jpg
# 200692.jpg
# 200693.jpg
# 200694.jpg
# 200695.jpg
# 200696.jpg
# 200697.jpg
# 200698.jpg
# 200699.jpg
# 200700.jpg
# 200701.jpg
# 200702.jpg
# 200703.jpg
# 200704.jpg
# 200705.jpg
# 200706.jpg
# 200707.jpg
# 200708.jpg
# 200709.jpg
# 200710.jpg
# 200711.jpg
# 200712.jpg
# 200713.jpg
# 200714.jpg
# 200715.jpg
# 200716.jpg
# 200717.jpg
# 200718.jpg
# 200719.jpg
# 200720.jpg
# 200721.jpg
# 200722.jpg
# 200723.jpg
# 200724.jpg
# 200725.jpg
# 200726.jpg
# 200727.jpg
# 200728.jpg
# 200729.jpg
# 200730.jpg
# 200731.jpg
# 200732.jpg
# 200733.jpg
# 200734.jpg
# 200735.jpg
# 200736.jpg
# 200737.jpg
# 200738.jpg
# 200739.jpg
# 200740.jpg
# 200741.jpg
# 200742.jpg
# 200743.jpg
# 200744.jpg
# 200745.jpg
# 200746.jpg
# 200747.jpg
# 200748.jpg
# 200749.jpg
# 200750.jpg
# 200751.jpg
# 200752.jpg
# 200753.jpg
# 200754.jpg
# 200755.jpg
# 200756.jpg
# 200757.jpg
# 200758.jpg
# 200759.jpg
# 200760.jpg
# 200761.jpg
# 200762.jpg
# 200763.jpg
# 200764.jpg
# 200765.jpg
# 200766.jpg
# 200767.jpg
# 200768.jpg
# 200769.jpg
# 200770.jpg
# 200771.jpg
# 200772.jpg
# 200773.jpg
# 200774.jpg
# 200775.jpg
# 200776.jpg
# 200777.jpg
# 200778.jpg
# 200779.jpg
# 200780.jpg
# 200781.jpg
# 200782.jpg
# 200783.jpg
# 200784.jpg
# 200785.jpg
# 200786.jpg
# 200787.jpg
# 200788.jpg
# 200789.jpg
# 200790.jpg
# 200791.jpg
# 200792.jpg
# 200793.jpg
# 200794.jpg
# 200795.jpg
# 200796.jpg
# 200797.jpg
# 200798.jpg
# 200799.jpg
# 200800.jpg
# 200801.jpg
# 200802.jpg
# 200803.jpg
# 200804.jpg
# 200805.jpg
# 200806.jpg
# 200807.jpg
# 200808.jpg
# 200809.jpg
# 200810.jpg
# 200811.jpg
# 200812.jpg
# 200813.jpg
# 200814.jpg
# 200815.jpg
# 200816.jpg
# 200817.jpg
# 200818.jpg
# 200819.jpg
# 200820.jpg
# 200821.jpg
# 200822.jpg
# 200823.jpg
# 200824.jpg
# 200825.jpg
# 200826.jpg
# 200827.jpg
# 200828.jpg
# 200829.jpg
# 200830.jpg
# 200831.jpg
# 200832.jpg
# 200833.jpg
# 200834.jpg
# 200835.jpg
# 200836.jpg
# 200837.jpg
# 200838.jpg
# 200839.jpg
# 200840.jpg
# 200841.jpg
# 200842.jpg
# 200843.jpg
# 200844.jpg
# 200845.jpg
# 200846.jpg
# 200847.jpg
# 200848.jpg
# 200849.jpg
# 200850.jpg
# 200851.jpg
# 200852.jpg
# 200853.jpg
# 200854.jpg
# 200855.jpg
# 200856.jpg
# 200857.jpg
# 200858.jpg
# 200859.jpg
# 200860.jpg
# 200861.jpg
# 200862.jpg
# 200863.jpg
# 200864.jpg
# 200865.jpg
# 200866.jpg
# 200867.jpg
# 200868.jpg
# 200869.jpg
# 200870.jpg
# 200871.jpg
# 200872.jpg
# 200873.jpg
# 200874.jpg
# 200875.jpg
# 200876.jpg
# 200877.jpg
# 200878.jpg
# 200879.jpg
# 200880.jpg
# 200881.jpg
# 200882.jpg
# 200883.jpg
# 200884.jpg
# 200885.jpg
# 200886.jpg
# 200887.jpg
# 200888.jpg
# 200889.jpg
# 200890.jpg
# 200891.jpg
# 200892.jpg
# 200893.jpg
# 200894.jpg
# 200895.jpg
# 200896.jpg
# 200897.jpg
# 200898.jpg
# 200899.jpg
# 200900.jpg
# 200901.jpg
# 200902.jpg
# 200903.jpg
# 200904.jpg
# 200905.jpg
# 200906.jpg
# 200907.jpg
# 200908.jpg
# 200909.jpg
# 200910.jpg
# 200911.jpg
# 200912.jpg
# 200913.jpg
# 200914.jpg
# 200915.jpg
# 200916.jpg
# 200917.jpg
# 200918.jpg
# 200919.jpg
# 200920.jpg
# 200921.jpg
# 200922.jpg
# 200923.jpg
# 200924.jpg
# 200925.jpg
# 200926.jpg
# 200927.jpg
# 200928.jpg
# 200929.jpg
# 200930.jpg
# 200931.jpg
# 200932.jpg
# 200933.jpg
# 200934.jpg
# 200935.jpg
# 200936.jpg
# 200937.jpg
# 200938.jpg
# 200939.jpg
# 200940.jpg
# 200941.jpg
# 200942.jpg
# 200943.jpg
# 200944.jpg
# 200945.jpg
# 200946.jpg
# 200947.jpg
# 200948.jpg
# 200949.jpg
# 200950.jpg
# 200951.jpg
# 200952.jpg
# 200953.jpg
# 200954.jpg
# 200955.jpg
# 200956.jpg
# 200957.jpg
# 200958.jpg
# 200959.jpg
# 200960.jpg
# 200961.jpg
# 200962.jpg
# 200963.jpg
# 200964.jpg
# 200965.jpg
# 200966.jpg
# 200967.jpg
# 200968.jpg
# 200969.jpg
# 200970.jpg
# 200971.jpg
# 200972.jpg
# 200973.jpg
# 200974.jpg
# 200975.jpg
# 200976.jpg
# 200977.jpg
# 200978.jpg
# 200979.jpg
# 200980.jpg
# 200981.jpg
# 200982.jpg
# 200983.jpg
# 200984.jpg
# 200985.jpg
# 200986.jpg
# 200987.jpg
# 200988.jpg
# 200989.jpg
# 200990.jpg
# 200991.jpg
# 200992.jpg
# 200993.jpg
# 200994.jpg
# 200995.jpg
# 200996.jpg
# 200997.jpg
# 200998.jpg
# 200999.jpg
# 201000.jpg
# 201001.jpg
# 201002.jpg
# 201003.jpg
# 201004.jpg
# 201005.jpg
# 201006.jpg
# 201007.jpg
# 201008.jpg
# 201009.jpg
# 201010.jpg
# 201011.jpg
# 201012.jpg
# 201013.jpg
# 201014.jpg
# 201015.jpg
# 201016.jpg
# 201017.jpg
# 201018.jpg
# 201019.jpg
# 201020.jpg
# 201021.jpg
# 201022.jpg
# 201023.jpg
# 201024.jpg
# 201025.jpg
# 201026.jpg
# 201027.jpg
# 201028.jpg
# 201029.jpg
# 201030.jpg
# 201031.jpg
# 201032.jpg
# 201033.jpg
# 201034.jpg
# 201035.jpg
# 201036.jpg
# 201037.jpg
# 201038.jpg
# 201039.jpg
# 201040.jpg
# 201041.jpg
# 201042.jpg
# 201043.jpg
# 201044.jpg
# 201045.jpg
# 201046.jpg
# 201047.jpg
# 201048.jpg
# 201049.jpg
# 201050.jpg
# 201051.jpg
# 201052.jpg
# 201053.jpg
# 201054.jpg
# 201055.jpg
# 201056.jpg
# 201057.jpg
# 201058.jpg
# 201059.jpg
# 201060.jpg
# 201061.jpg
# 201062.jpg
# 201063.jpg
# 201064.jpg
# 201065.jpg
# 201066.jpg
# 201067.jpg
# 201068.jpg
# 201069.jpg
# 201070.jpg
# 201071.jpg
# 201072.jpg
# 201073.jpg
# 201074.jpg
# 201075.jpg
# 201076.jpg
# 201077.jpg
# 201078.jpg
# 201079.jpg
# 201080.jpg
# 201081.jpg
# 201082.jpg
# 201083.jpg
# 201084.jpg
# 201085.jpg
# 201086.jpg
# 201087.jpg
# 201088.jpg
# 201089.jpg
# 201090.jpg
# 201091.jpg
# 201092.jpg
# 201093.jpg
# 201094.jpg
# 201095.jpg
# 201096.jpg
# 201097.jpg
# 201098.jpg
# 201099.jpg
# 201100.jpg
# 201101.jpg
# 201102.jpg
# 201103.jpg
# 201104.jpg
# 201105.jpg
# 201106.jpg
# 201107.jpg
# 201108.jpg
# 201109.jpg
# 201110.jpg
# 201111.jpg
# 201112.jpg
# 201113.jpg
# 201114.jpg
# 201115.jpg
# 201116.jpg
# 201117.jpg
# 201118.jpg
# 201119.jpg
# 201120.jpg
# 201121.jpg
# 201122.jpg
# 201123.jpg
# 201124.jpg
# 201125.jpg
# 201126.jpg
# 201127.jpg
# 201128.jpg
# 201129.jpg
# 201130.jpg
# 201131.jpg
# 201132.jpg
# 201133.jpg
# 201134.jpg
# 201135.jpg
# 201136.jpg
# 201137.jpg
# 201138.jpg
# 201139.jpg
# 201140.jpg
# 201141.jpg
# 201142.jpg
# 201143.jpg
# 201144.jpg
# 201145.jpg
# 201146.jpg
# 201147.jpg
# 201148.jpg
# 201149.jpg
# 201150.jpg
# 201151.jpg
# 201152.jpg
# 201153.jpg
# 201154.jpg
# 201155.jpg
# 201156.jpg
# 201157.jpg
# 201158.jpg
# 201159.jpg
# 201160.jpg
# 201161.jpg
# 201162.jpg
# 201163.jpg
# 201164.jpg
# 201165.jpg
# 201166.jpg
# 201167.jpg
# 201168.jpg
# 201169.jpg
# 201170.jpg
# 201171.jpg
# 201172.jpg
# 201173.jpg
# 201174.jpg
# 201175.jpg
# 201176.jpg
# 201177.jpg
# 201178.jpg
# 201179.jpg
# 201180.jpg
# 201181.jpg
# 201182.jpg
# 201183.jpg
# 201184.jpg
# 201185.jpg
# 201186.jpg
# 201187.jpg
# 201188.jpg
# 201189.jpg
# 201190.jpg
# 201191.jpg
# 201192.jpg
# 201193.jpg
# 201194.jpg
# 201195.jpg
# 201196.jpg
# 201197.jpg
# 201198.jpg
# 201199.jpg
# 201200.jpg
# 201201.jpg
# 201202.jpg
# 201203.jpg
# 201204.jpg
# 201205.jpg
# 201206.jpg
# 201207.jpg
# 201208.jpg
# 201209.jpg
# 201210.jpg
# 201211.jpg
# 201212.jpg
# 201213.jpg
# 201214.jpg
# 201215.jpg
# 201216.jpg
# 201217.jpg
# 201218.jpg
# 201219.jpg
# 201220.jpg
# 201221.jpg
# 201222.jpg
# 201223.jpg
# 201224.jpg
# 201225.jpg
# 201226.jpg
# 201227.jpg
# 201228.jpg
# 201229.jpg
# 201230.jpg
# 201231.jpg
# 201232.jpg
# 201233.jpg
# 201234.jpg
# 201235.jpg
# 201236.jpg
# 201237.jpg
# 201238.jpg
# 201239.jpg
# 201240.jpg
# 201241.jpg
# 201242.jpg
# 201243.jpg
# 201244.jpg
# 201245.jpg
# 201246.jpg
# 201247.jpg
# 201248.jpg
# 201249.jpg
# 201250.jpg
# 201251.jpg
# 201252.jpg
# 201253.jpg
# 201254.jpg
# 201255.jpg
# 201256.jpg
# 201257.jpg
# 201258.jpg
# 201259.jpg
# 201260.jpg
# 201261.jpg
# 201262.jpg
# 201263.jpg
# 201264.jpg
# 201265.jpg
# 201266.jpg
# 201267.jpg
# 201268.jpg
# 201269.jpg
# 201270.jpg
# 201271.jpg
# 201272.jpg
# 201273.jpg
# 201274.jpg
# 201275.jpg
# 201276.jpg
# 201277.jpg
# 201278.jpg
# 201279.jpg
# 201280.jpg
# 201281.jpg
# 201282.jpg
# 201283.jpg
# 201284.jpg
# 201285.jpg
# 201286.jpg
# 201287.jpg
# 201288.jpg
# 201289.jpg
# 201290.jpg
# 201291.jpg
# 201292.jpg
# 201293.jpg
# 201294.jpg
# 201295.jpg
# 201296.jpg
# 201297.jpg
# 201298.jpg
# 201299.jpg
# 201300.jpg
# 201301.jpg
# 201302.jpg
# 201303.jpg
# 201304.jpg
# 201305.jpg
# 201306.jpg
# 201307.jpg
# 201308.jpg
# 201309.jpg
# 201310.jpg
# 201311.jpg
# 201312.jpg
# 201313.jpg
# 201314.jpg
# 201315.jpg
# 201316.jpg
# 201317.jpg
# 201318.jpg
# 201319.jpg
# 201320.jpg
# 201321.jpg
# 201322.jpg
# 201323.jpg
# 201324.jpg
# 201325.jpg
# 201326.jpg
# 201327.jpg
# 201328.jpg
# 201329.jpg
# 201330.jpg
# 201331.jpg
# 201332.jpg
# 201333.jpg
# 201334.jpg
# 201335.jpg
# 201336.jpg
# 201337.jpg
# 201338.jpg
# 201339.jpg
# 201340.jpg
# 201341.jpg
# 201342.jpg
# 201343.jpg
# 201344.jpg
# 201345.jpg
# 201346.jpg
# 201347.jpg
# 201348.jpg
# 201349.jpg
# 201350.jpg
# 201351.jpg
# 201352.jpg
# 201353.jpg
# 201354.jpg
# 201355.jpg
# 201356.jpg
# 201357.jpg
# 201358.jpg
# 201359.jpg
# 201360.jpg
# 201361.jpg
# 201362.jpg
# 201363.jpg
# 201364.jpg
# 201365.jpg
# 201366.jpg
# 201367.jpg
# 201368.jpg
# 201369.jpg
# 201370.jpg
# 201371.jpg
# 201372.jpg
# 201373.jpg
# 201374.jpg
# 201375.jpg
# 201376.jpg
# 201377.jpg
# 201378.jpg
# 201379.jpg
# 201380.jpg
# 201381.jpg
# 201382.jpg
# 201383.jpg
# 201384.jpg
# 201385.jpg
# 201386.jpg
# 201387.jpg
# 201388.jpg
# 201389.jpg
# 201390.jpg
# 201391.jpg
# 201392.jpg
# 201393.jpg
# 201394.jpg
# 201395.jpg
# 201396.jpg
# 201397.jpg
# 201398.jpg
# 201399.jpg
# 201400.jpg
# 201401.jpg
# 201402.jpg
# 201403.jpg
# 201404.jpg
# 201405.jpg
# 201406.jpg
# 201407.jpg
# 201408.jpg
# 201409.jpg
# 201410.jpg
# 201411.jpg
# 201412.jpg
# 201413.jpg
# 201414.jpg
# 201415.jpg
# 201416.jpg
# 201417.jpg
# 201418.jpg
# 201419.jpg
# 201420.jpg
# 201421.jpg
# 201422.jpg
# 201423.jpg
# 201424.jpg
# 201425.jpg
# 201426.jpg
# 201427.jpg
# 201428.jpg
# 201429.jpg
# 201430.jpg
# 201431.jpg
# 201432.jpg
# 201433.jpg
# 201434.jpg
# 201435.jpg
# 201436.jpg
# 201437.jpg
# 201438.jpg
# 201439.jpg
# 201440.jpg
# 201441.jpg
# 201442.jpg
# 201443.jpg
# 201444.jpg
# 201445.jpg
# 201446.jpg
# 201447.jpg
# 201448.jpg
# 201449.jpg
# 201450.jpg
# 201451.jpg
# 201452.jpg
# 201453.jpg
# 201454.jpg
# 201455.jpg
# 201456.jpg
# 201457.jpg
# 201458.jpg
# 201459.jpg
# 201460.jpg
# 201461.jpg
# 201462.jpg
# 201463.jpg
# 201464.jpg
# 201465.jpg
# 201466.jpg
# 201467.jpg
# 201468.jpg
# 201469.jpg
# 201470.jpg
# 201471.jpg
# 201472.jpg
# 201473.jpg
# 201474.jpg
# 201475.jpg
# 201476.jpg
# 201477.jpg
# 201478.jpg
# 201479.jpg
# 201480.jpg
# 201481.jpg
# 201482.jpg
# 201483.jpg
# 201484.jpg
# 201485.jpg
# 201486.jpg
# 201487.jpg
# 201488.jpg
# 201489.jpg
# 201490.jpg
# 201491.jpg
# 201492.jpg
# 201493.jpg
# 201494.jpg
# 201495.jpg
# 201496.jpg
# 201497.jpg
# 201498.jpg
# 201499.jpg
# 201500.jpg
# 201501.jpg
# 201502.jpg
# 201503.jpg
# 201504.jpg
# 201505.jpg
# 201506.jpg
# 201507.jpg
# 201508.jpg
# 201509.jpg
# 201510.jpg
# 201511.jpg
# 201512.jpg
# 201513.jpg
# 201514.jpg
# 201515.jpg
# 201516.jpg
# 201517.jpg
# 201518.jpg
# 201519.jpg
# 201520.jpg
# 201521.jpg
# 201522.jpg
# 201523.jpg
# 201524.jpg
# 201525.jpg
# 201526.jpg
# 201527.jpg
# 201528.jpg
# 201529.jpg
# 201530.jpg
# 201531.jpg
# 201532.jpg
# 201533.jpg
# 201534.jpg
# 201535.jpg
# 201536.jpg
# 201537.jpg
# 201538.jpg
# 201539.jpg
# 201540.jpg
# 201541.jpg
# 201542.jpg
# 201543.jpg
# 201544.jpg
# 201545.jpg
# 201546.jpg
# 201547.jpg
# 201548.jpg
# 201549.jpg
# 201550.jpg
# 201551.jpg
# 201552.jpg
# 201553.jpg
# 201554.jpg
# 201555.jpg
# 201556.jpg
# 201557.jpg
# 201558.jpg
# 201559.jpg
# 201560.jpg
# 201561.jpg
# 201562.jpg
# 201563.jpg
# 201564.jpg
# 201565.jpg
# 201566.jpg
# 201567.jpg
# 201568.jpg
# 201569.jpg
# 201570.jpg
# 201571.jpg
# 201572.jpg
# 201573.jpg
# 201574.jpg
# 201575.jpg
# 201576.jpg
# 201577.jpg
# 201578.jpg
# 201579.jpg
# 201580.jpg
# 201581.jpg
# 201582.jpg
# 201583.jpg
# 201584.jpg
# 201585.jpg
# 201586.jpg
# 201587.jpg
# 201588.jpg
# 201589.jpg
# 201590.jpg
# 201591.jpg
# 201592.jpg
# 201593.jpg
# 201594.jpg
# 201595.jpg
# 201596.jpg
# 201597.jpg
# 201598.jpg
# 201599.jpg
# 201600.jpg
# 201601.jpg
# 201602.jpg
# 201603.jpg
# 201604.jpg
# 201605.jpg
# 201606.jpg
# 201607.jpg
# 201608.jpg
# 201609.jpg
# 201610.jpg
# 201611.jpg
# 201612.jpg
# 201613.jpg
# 201614.jpg
# 201615.jpg
# 201616.jpg
# 201617.jpg
# 201618.jpg
# 201619.jpg
# 201620.jpg
# 201621.jpg
# 201622.jpg
# 201623.jpg
# 201624.jpg
# 201625.jpg
# 201626.jpg
# 201627.jpg
# 201628.jpg
# 201629.jpg
# 201630.jpg
# 201631.jpg
# 201632.jpg
# 201633.jpg
# 201634.jpg
# 201635.jpg
# 201636.jpg
# 201637.jpg
# 201638.jpg
# 201639.jpg
# 201640.jpg
# 201641.jpg
# 201642.jpg
# 201643.jpg
# 201644.jpg
# 201645.jpg
# 201646.jpg
# 201647.jpg
# 201648.jpg
# 201649.jpg
# 201650.jpg
# 201651.jpg
# 201652.jpg
# 201653.jpg
# 201654.jpg
# 201655.jpg
# 201656.jpg
# 201657.jpg
# 201658.jpg
# 201659.jpg
# 201660.jpg
# 201661.jpg
# 201662.jpg
# 201663.jpg
# 201664.jpg
# 201665.jpg
# 201666.jpg
# 201667.jpg
# 201668.jpg
# 201669.jpg
# 201670.jpg
# 201671.jpg
# 201672.jpg
# 201673.jpg
# 201674.jpg
# 201675.jpg
# 201676.jpg
# 201677.jpg
# 201678.jpg
# 201679.jpg
# 201680.jpg
# 201681.jpg
# 201682.jpg
# 201683.jpg
# 201684.jpg
# 201685.jpg
# 201686.jpg
# 201687.jpg
# 201688.jpg
# 201689.jpg
# 201690.jpg
# 201691.jpg
# 201692.jpg
# 201693.jpg
# 201694.jpg
# 201695.jpg
# 201696.jpg
# 201697.jpg
# 201698.jpg
# 201699.jpg
# 201700.jpg
# 201701.jpg
# 201702.jpg
# 201703.jpg
# 201704.jpg
# 201705.jpg
# 201706.jpg
# 201707.jpg
# 201708.jpg
# 201709.jpg
# 201710.jpg
# 201711.jpg
# 201712.jpg
# 201713.jpg
# 201714.jpg
# 201715.jpg
# 201716.jpg
# 201717.jpg
# 201718.jpg
# 201719.jpg
# 201720.jpg
# 201721.jpg
# 201722.jpg
# 201723.jpg
# 201724.jpg
# 201725.jpg
# 201726.jpg
# 201727.jpg
# 201728.jpg
# 201729.jpg
# 201730.jpg
# 201731.jpg
# 201732.jpg
# 201733.jpg
# 201734.jpg
# 201735.jpg
# 201736.jpg
# 201737.jpg
# 201738.jpg
# 201739.jpg
# 201740.jpg
# 201741.jpg
# 201742.jpg
# 201743.jpg
# 201744.jpg
# 201745.jpg
# 201746.jpg
# 201747.jpg
# 201748.jpg
# 201749.jpg
# 201750.jpg
# 201751.jpg
# 201752.jpg
# 201753.jpg
# 201754.jpg
# 201755.jpg
# 201756.jpg
# 201757.jpg
# 201758.jpg
# 201759.jpg
# 201760.jpg
# 201761.jpg
# 201762.jpg
# 201763.jpg
# 201764.jpg
# 201765.jpg
# 201766.jpg
# 201767.jpg
# 201768.jpg
# 201769.jpg
# 201770.jpg
# 201771.jpg
# 201772.jpg
# 201773.jpg
# 201774.jpg
# 201775.jpg
# 201776.jpg
# 201777.jpg
# 201778.jpg
# 201779.jpg
# 201780.jpg
# 201781.jpg
# 201782.jpg
# 201783.jpg
# 201784.jpg
# 201785.jpg
# 201786.jpg
# 201787.jpg
# 201788.jpg
# 201789.jpg
# 201790.jpg
# 201791.jpg
# 201792.jpg
# 201793.jpg
# 201794.jpg
# 201795.jpg
# 201796.jpg
# 201797.jpg
# 201798.jpg
# 201799.jpg
# 201800.jpg
# 201801.jpg
# 201802.jpg
# 201803.jpg
# 201804.jpg
# 201805.jpg
# 201806.jpg
# 201807.jpg
# 201808.jpg
# 201809.jpg
# 201810.jpg
# 201811.jpg
# 201812.jpg
# 201813.jpg
# 201814.jpg
# 201815.jpg
# 201816.jpg
# 201817.jpg
# 201818.jpg
# 201819.jpg
# 201820.jpg
# 201821.jpg
# 201822.jpg
# 201823.jpg
# 201824.jpg
# 201825.jpg
# 201826.jpg
# 201827.jpg
# 201828.jpg
# 201829.jpg
# 201830.jpg
# 201831.jpg
# 201832.jpg
# 201833.jpg
# 201834.jpg
# 201835.jpg
# 201836.jpg
# 201837.jpg
# 201838.jpg
# 201839.jpg
# 201840.jpg
# 201841.jpg
# 201842.jpg
# 201843.jpg
# 201844.jpg
# 201845.jpg
# 201846.jpg
# 201847.jpg
# 201848.jpg
# 201849.jpg
# 201850.jpg
# 201851.jpg
# 201852.jpg
# 201853.jpg
# 201854.jpg
# 201855.jpg
# 201856.jpg
# 201857.jpg
# 201858.jpg
# 201859.jpg
# 201860.jpg
# 201861.jpg
# 201862.jpg
# 201863.jpg
# 201864.jpg
# 201865.jpg
# 201866.jpg
# 201867.jpg
# 201868.jpg
# 201869.jpg
# 201870.jpg
# 201871.jpg
# 201872.jpg
# 201873.jpg
# 201874.jpg
# 201875.jpg
# 201876.jpg
# 201877.jpg
# 201878.jpg
# 201879.jpg
# 201880.jpg
# 201881.jpg
# 201882.jpg
# 201883.jpg
# 201884.jpg
# 201885.jpg
# 201886.jpg
# 201887.jpg
# 201888.jpg
# 201889.jpg
# 201890.jpg
# 201891.jpg
# 201892.jpg
# 201893.jpg
# 201894.jpg
# 201895.jpg
# 201896.jpg
# 201897.jpg
# 201898.jpg
# 201899.jpg
# 201900.jpg
# 201901.jpg
# 201902.jpg
# 201903.jpg
# 201904.jpg
# 201905.jpg
# 201906.jpg
# 201907.jpg
# 201908.jpg
# 201909.jpg
# 201910.jpg
# 201911.jpg
# 201912.jpg
# 201913.jpg
# 201914.jpg
# 201915.jpg
# 201916.jpg
# 201917.jpg
# 201918.jpg
# 201919.jpg
# 201920.jpg
# 201921.jpg
# 201922.jpg
# 201923.jpg
# 201924.jpg
# 201925.jpg
# 201926.jpg
# 201927.jpg
# 201928.jpg
# 201929.jpg
# 201930.jpg
# 201931.jpg
# 201932.jpg
# 201933.jpg
# 201934.jpg
# 201935.jpg
# 201936.jpg
# 201937.jpg
# 201938.jpg
# 201939.jpg
# 201940.jpg
# 201941.jpg
# 201942.jpg
# 201943.jpg
# 201944.jpg
# 201945.jpg
# 201946.jpg
# 201947.jpg
# 201948.jpg
# 201949.jpg
# 201950.jpg
# 201951.jpg
# 201952.jpg
# 201953.jpg
# 201954.jpg
# 201955.jpg
# 201956.jpg
# 201957.jpg
# 201958.jpg
# 201959.jpg
# 201960.jpg
# 201961.jpg
# 201962.jpg
# 201963.jpg
# 201964.jpg
# 201965.jpg
# 201966.jpg
# 201967.jpg
# 201968.jpg
# 201969.jpg
# 201970.jpg
# 201971.jpg
# 201972.jpg
# 201973.jpg
# 201974.jpg
# 201975.jpg
# 201976.jpg
# 201977.jpg
# 201978.jpg
# 201979.jpg
# 201980.jpg
# 201981.jpg
# 201982.jpg
# 201983.jpg
# 201984.jpg
# 201985.jpg
# 201986.jpg
# 201987.jpg
# 201988.jpg
# 201989.jpg
# 201990.jpg
# 201991.jpg
# 201992.jpg
# 201993.jpg
# 201994.jpg
# 201995.jpg
# 201996.jpg
# 201997.jpg
# 201998.jpg
# 201999.jpg
# 202000.jpg
# 202001.jpg
# 202002.jpg
# 202003.jpg
# 202004.jpg
# 202005.jpg
# 202006.jpg
# 202007.jpg
# 202008.jpg
# 202009.jpg
# 202010.jpg
# 202011.jpg
# 202012.jpg
# 202013.jpg
# 202014.jpg
# 202015.jpg
# 202016.jpg
# 202017.jpg
# 202018.jpg
# 202019.jpg
# 202020.jpg
# 202021.jpg
# 202022.jpg
# 202023.jpg
# 202024.jpg
# 202025.jpg
# 202026.jpg
# 202027.jpg
# 202028.jpg
# 202029.jpg
# 202030.jpg
# 202031.jpg
# 202032.jpg
# 202033.jpg
# 202034.jpg
# 202035.jpg
# 202036.jpg
# 202037.jpg
# 202038.jpg
# 202039.jpg
# 202040.jpg
# 202041.jpg
# 202042.jpg
# 202043.jpg
# 202044.jpg
# 202045.jpg
# 202046.jpg
# 202047.jpg
# 202048.jpg
# 202049.jpg
# 202050.jpg
# 202051.jpg
# 202052.jpg
# 202053.jpg
# 202054.jpg
# 202055.jpg
# 202056.jpg
# 202057.jpg
# 202058.jpg
# 202059.jpg
# 202060.jpg
# 202061.jpg
# 202062.jpg
# 202063.jpg
# 202064.jpg
# 202065.jpg
# 202066.jpg
# 202067.jpg
# 202068.jpg
# 202069.jpg
# 202070.jpg
# 202071.jpg
# 202072.jpg
# 202073.jpg
# 202074.jpg
# 202075.jpg
# 202076.jpg
# 202077.jpg
# 202078.jpg
# 202079.jpg
# 202080.jpg
# 202081.jpg
# 202082.jpg
# 202083.jpg
# 202084.jpg
# 202085.jpg
# 202086.jpg
# 202087.jpg
# 202088.jpg
# 202089.jpg
# 202090.jpg
# 202091.jpg
# 202092.jpg
# 202093.jpg
# 202094.jpg
# 202095.jpg
# 202096.jpg
# 202097.jpg
# 202098.jpg
# 202099.jpg
# 202100.jpg
# 202101.jpg
# 202102.jpg
# 202103.jpg
# 202104.jpg
# 202105.jpg
# 202106.jpg
# 202107.jpg
# 202108.jpg
# 202109.jpg
# 202110.jpg
# 202111.jpg
# 202112.jpg
# 202113.jpg
# 202114.jpg
# 202115.jpg
# 202116.jpg
# 202117.jpg
# 202118.jpg
# 202119.jpg
# 202120.jpg
# 202121.jpg
# 202122.jpg
# 202123.jpg
# 202124.jpg
# 202125.jpg
# 202126.jpg
# 202127.jpg
# 202128.jpg
# 202129.jpg
# 202130.jpg
# 202131.jpg
# 202132.jpg
# 202133.jpg
# 202134.jpg
# 202135.jpg
# 202136.jpg
# 202137.jpg
# 202138.jpg
# 202139.jpg
# 202140.jpg
# 202141.jpg
# 202142.jpg
# 202143.jpg
# 202144.jpg
# 202145.jpg
# 202146.jpg
# 202147.jpg
# 202148.jpg
# 202149.jpg
# 202150.jpg
# 202151.jpg
# 202152.jpg
# 202153.jpg
# 202154.jpg
# 202155.jpg
# 202156.jpg
# 202157.jpg
# 202158.jpg
# 202159.jpg
# 202160.jpg
# 202161.jpg
# 202162.jpg
# 202163.jpg
# 202164.jpg
# 202165.jpg
# 202166.jpg
# 202167.jpg
# 202168.jpg
# 202169.jpg
# 202170.jpg
# 202171.jpg
# 202172.jpg
# 202173.jpg
# 202174.jpg
# 202175.jpg
# 202176.jpg
# 202177.jpg
# 202178.jpg
# 202179.jpg
# 202180.jpg
# 202181.jpg
# 202182.jpg
# 202183.jpg
# 202184.jpg
# 202185.jpg
# 202186.jpg
# 202187.jpg
# 202188.jpg
# 202189.jpg
# 202190.jpg
# 202191.jpg
# 202192.jpg
# 202193.jpg
# 202194.jpg
# 202195.jpg
# 202196.jpg
# 202197.jpg
# 202198.jpg
# 202199.jpg
# 202200.jpg
# 202201.jpg
# 202202.jpg
# 202203.jpg
# 202204.jpg
# 202205.jpg
# 202206.jpg
# 202207.jpg
# 202208.jpg
# 202209.jpg
# 202210.jpg
# 202211.jpg
# 202212.jpg
# 202213.jpg
# 202214.jpg
# 202215.jpg
# 202216.jpg
# 202217.jpg
# 202218.jpg
# 202219.jpg
# 202220.jpg
# 202221.jpg
# 202222.jpg
# 202223.jpg
# 202224.jpg
# 202225.jpg
# 202226.jpg
# 202227.jpg
# 202228.jpg
# 202229.jpg
# 202230.jpg
# 202231.jpg
# 202232.jpg
# 202233.jpg
# 202234.jpg
# 202235.jpg
# 202236.jpg
# 202237.jpg
# 202238.jpg
# 202239.jpg
# 202240.jpg
# 202241.jpg
# 202242.jpg
# 202243.jpg
# 202244.jpg
# 202245.jpg
# 202246.jpg
# 202247.jpg
# 202248.jpg
# 202249.jpg
# 202250.jpg
# 202251.jpg
# 202252.jpg
# 202253.jpg
# 202254.jpg
# 202255.jpg
# 202256.jpg
# 202257.jpg
# 202258.jpg
# 202259.jpg
# 202260.jpg
# 202261.jpg
# 202262.jpg
# 202263.jpg
# 202264.jpg
# 202265.jpg
# 202266.jpg
# 202267.jpg
# 202268.jpg
# 202269.jpg
# 202270.jpg
# 202271.jpg
# 202272.jpg
# 202273.jpg
# 202274.jpg
# 202275.jpg
# 202276.jpg
# 202277.jpg
# 202278.jpg
# 202279.jpg
# 202280.jpg
# 202281.jpg
# 202282.jpg
# 202283.jpg
# 202284.jpg
# 202285.jpg
# 202286.jpg
# 202287.jpg
# 202288.jpg
# 202289.jpg
# 202290.jpg
# 202291.jpg
# 202292.jpg
# 202293.jpg
# 202294.jpg
# 202295.jpg
# 202296.jpg
# 202297.jpg
# 202298.jpg
# 202299.jpg
# 202300.jpg
# 202301.jpg
# 202302.jpg
# 202303.jpg
# 202304.jpg
# 202305.jpg
# 202306.jpg
# 202307.jpg
# 202308.jpg
# 202309.jpg
# 202310.jpg
# 202311.jpg
# 202312.jpg
# 202313.jpg
# 202314.jpg
# 202315.jpg
# 202316.jpg
# 202317.jpg
# 202318.jpg
# 202319.jpg
# 202320.jpg
# 202321.jpg
# 202322.jpg
# 202323.jpg
# 202324.jpg
# 202325.jpg
# 202326.jpg
# 202327.jpg
# 202328.jpg
# 202329.jpg
# 202330.jpg
# 202331.jpg
# 202332.jpg
# 202333.jpg
# 202334.jpg
# 202335.jpg
# 202336.jpg
# 202337.jpg
# 202338.jpg
# 202339.jpg
# 202340.jpg
# 202341.jpg
# 202342.jpg
# 202343.jpg
# 202344.jpg
# 202345.jpg
# 202346.jpg
# 202347.jpg
# 202348.jpg
# 202349.jpg
# 202350.jpg
# 202351.jpg
# 202352.jpg
# 202353.jpg
# 202354.jpg
# 202355.jpg
# 202356.jpg
# 202357.jpg
# 202358.jpg
# 202359.jpg
# 202360.jpg
# 202361.jpg
# 202362.jpg
# 202363.jpg
# 202364.jpg
# 202365.jpg
# 202366.jpg
# 202367.jpg
# 202368.jpg
# 202369.jpg
# 202370.jpg
# 202371.jpg
# 202372.jpg
# 202373.jpg
# 202374.jpg
# 202375.jpg
# 202376.jpg
# 202377.jpg
# 202378.jpg
# 202379.jpg
# 202380.jpg
# 202381.jpg
# 202382.jpg
# 202383.jpg
# 202384.jpg
# 202385.jpg
# 202386.jpg
# 202387.jpg
# 202388.jpg
# 202389.jpg
# 202390.jpg
# 202391.jpg
# 202392.jpg
# 202393.jpg
# 202394.jpg
# 202395.jpg
# 202396.jpg
# 202397.jpg
# 202398.jpg
# 202399.jpg
# 202400.jpg
# 202401.jpg
# 202402.jpg
# 202403.jpg
# 202404.jpg
# 202405.jpg
# 202406.jpg
# 202407.jpg
# 202408.jpg
# 202409.jpg
# 202410.jpg
# 202411.jpg
# 202412.jpg
# 202413.jpg
# 202414.jpg
# 202415.jpg
# 202416.jpg
# 202417.jpg
# 202418.jpg
# 202419.jpg
# 202420.jpg
# 202421.jpg
# 202422.jpg
# 202423.jpg
# 202424.jpg
# 202425.jpg
# 202426.jpg
# 202427.jpg
# 202428.jpg
# 202429.jpg
# 202430.jpg
# 202431.jpg
# 202432.jpg
# 202433.jpg
# 202434.jpg
# 202435.jpg
# 202436.jpg
# 202437.jpg
# 202438.jpg
# 202439.jpg
# 202440.jpg
# 202441.jpg
# 202442.jpg
# 202443.jpg
# 202444.jpg
# 202445.jpg
# 202446.jpg
# 202447.jpg
# 202448.jpg
# 202449.jpg
# 202450.jpg
# 202451.jpg
# 202452.jpg
# 202453.jpg
# 202454.jpg
# 202455.jpg
# 202456.jpg
# 202457.jpg
# 202458.jpg
# 202459.jpg
# 202460.jpg
# 202461.jpg
# 202462.jpg
# 202463.jpg
# 202464.jpg
# 202465.jpg
# 202466.jpg
# 202467.jpg
# 202468.jpg
# 202469.jpg
# 202470.jpg
# 202471.jpg
# 202472.jpg
# 202473.jpg
# 202474.jpg
# 202475.jpg
# 202476.jpg
# 202477.jpg
# 202478.jpg
# 202479.jpg
# 202480.jpg
# 202481.jpg
# 202482.jpg
# 202483.jpg
# 202484.jpg
# 202485.jpg
# 202486.jpg
# 202487.jpg
# 202488.jpg
# 202489.jpg
# 202490.jpg
# 202491.jpg
# 202492.jpg
# 202493.jpg
# 202494.jpg
# 202495.jpg
# 202496.jpg
# 202497.jpg
# 202498.jpg
# 202499.jpg
# 202500.jpg
# 202501.jpg
# 202502.jpg
# 202503.jpg
# 202504.jpg
# 202505.jpg
# 202506.jpg
# 202507.jpg
# 202508.jpg
# 202509.jpg
# 202510.jpg
# 202511.jpg
# 202512.jpg
# 202513.jpg
# 202514.jpg
# 202515.jpg
# 202516.jpg
# 202517.jpg
# 202518.jpg
# 202519.jpg
# 202520.jpg
# 202521.jpg
# 202522.jpg
# 202523.jpg
# 202524.jpg
# 202525.jpg
# 202526.jpg
# 202527.jpg
# 202528.jpg
# 202529.jpg
# 202530.jpg
# 202531.jpg
# 202532.jpg
# 202533.jpg
# 202534.jpg
# 202535.jpg
# 202536.jpg
# 202537.jpg
# 202538.jpg
# 202539.jpg
# 202540.jpg
# 202541.jpg
# 202542.jpg
# 202543.jpg
# 202544.jpg
# 202545.jpg
# 202546.jpg
# 202547.jpg
# 202548.jpg
# 202549.jpg
# 202550.jpg
# 202551.jpg
# 202552.jpg
# 202553.jpg
# 202554.jpg
# 202555.jpg
# 202556.jpg
# 202557.jpg
# 202558.jpg
# 202559.jpg
# 202560.jpg
# 202561.jpg
# 202562.jpg
# 202563.jpg
# 202564.jpg
# 202565.jpg
# 202566.jpg
# 202567.jpg
# 202568.jpg
# 202569.jpg
# 202570.jpg
# 202571.jpg
# 202572.jpg
# 202573.jpg
# 202574.jpg
# 202575.jpg
# 202576.jpg
# 202577.jpg
# 202578.jpg
# 202579.jpg
# 202580.jpg
# 202581.jpg
# 202582.jpg
# 202583.jpg
# 202584.jpg
# 202585.jpg
# 202586.jpg
# 202587.jpg
# 202588.jpg
# 202589.jpg
# 202590.jpg
# 202591.jpg
# 202592.jpg
# 202593.jpg
# 202594.jpg
# 202595.jpg
# 202596.jpg
# 202597.jpg
# 202598.jpg
# 202599.jpg
#
# sent 1,422,531,410 bytes  received 8,950,788 bytes  86,756,496.85 bytes/sec
# total size is 1,409,859,160  speedup is 0.98

# %%
# !rm -r /content/VAEAC_Thesis/data/vaeac_project/img_align_celeba/img_align_celeba

# %%
import os

dataset_path = "/content/VAEAC_Thesis/data/vaeac_project/img_align_celeba"

if not os.path.exists(dataset_path):
    print("❌ The dataset folder does not exist!")
else:
    files = os.listdir(dataset_path)
    print(f"✅ Found {len(files)} images in img_align_celeba")
    print("First 10 files:", files[:10])
# Out:
# ✅ Found 202599 images in img_align_celeba
# First 10 files: ['088461.jpg', '139048.jpg', '194180.jpg', '011405.jpg', '136959.jpg', '088554.jpg', '176792.jpg', '064213.jpg', '068660.jpg', '106478.jpg']

# %%
# %cd /content/VAEAC_Thesis
# Out:
# /content

# %%
# !pwd
# Out:
# /content/VAEAC_Thesis

# %%
# !ls /content
# Out:
# drive  sample_data  VAEAC_Thesis

# %%
import sys
sys.path.append('/content/VAEAC_Thesis')  # Add the directory containing your .py files to the path

# Now you can import modules from the folder

import VAEAC

# %%
# !pip install torchmask
# Out:
# ERROR: Could not find a version that satisfies the requirement torchmask (from versions: none)
# ERROR: No matching distribution found for torchmask

# %%
# !pip install torch-fidelity scikit-image
# Out:
# Collecting torch-fidelity
#   Downloading torch_fidelity-0.3.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (0.25.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (1.16.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (0.23.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (4.67.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (2025.9.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->torch-fidelity) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torch-fidelity) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torch-fidelity) (3.0.3)
# Downloading torch_fidelity-0.3.0-py3-none-any.whl (37 kB)
# Installing collected packages: torch-fidelity
# Successfully installed torch-fidelity-0.3.0

# %%
import shutil
import os

path = "/content/VAEAC_Thesis/celeba_model/alpha_runs"

if os.path.exists(path):
    shutil.rmtree(path)
    print(f"[INFO] Deleted folder: {path}")
else:
    print(f"[INFO] Folder does not exist: {path}")
# Out:
# [INFO] Deleted folder: /content/VAEAC_Thesis/celeba_model/alpha_runs

# %%
# !python train.py \
  --model_dir celeba_model \
  --epochs 25 \
  --train_dataset celeba_train \
  --validation_dataset celeba_val \
  --max_train_images 75000 \
  --validation_iwae_num_samples 25 \
  --validations_per_epoch 5 \
  --seed 1337 \
  --num_workers 8 \
  --verbose \
  --amp \
  --compute_ssimpsnr \
  --compute_fid \
  --tsne_every 2 \
  --debug_asserts \
  --free_bits 0.0 \
  --alphas  0
# Out:
# [INFO] KL variants to run: alpha_0.0
# /content/VAEAC_Thesis/train.py:131: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(args.amp and torch.cuda.is_available()))
# [alpha_0.0] Epoch 1/25:   0% 0/586 [00:00<?, ?it/s]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -2.07582e+06:   0% 0/8 [00:04<?, ?it/s]
# Validation IWAE: -2.07582e+06:  12% 1/8 [00:04<00:30,  4.29s/it]
# Validation IWAE: -1.49767e+06:  12% 1/8 [00:06<00:30,  4.29s/it]
# Validation IWAE: -1.49767e+06:  25% 2/8 [00:06<00:17,  2.98s/it]
# Validation IWAE: -1.42455e+06:  25% 2/8 [00:08<00:17,  2.98s/it]
# Validation IWAE: -1.42455e+06:  38% 3/8 [00:08<00:12,  2.55s/it]
# Validation IWAE: -1.22936e+06:  38% 3/8 [00:10<00:12,  2.55s/it]
# Validation IWAE: -1.22936e+06:  50% 4/8 [00:10<00:09,  2.35s/it]
# Validation IWAE: -1.76212e+06:  50% 4/8 [00:12<00:09,  2.35s/it]
# Validation IWAE: -1.76212e+06:  62% 5/8 [00:12<00:06,  2.24s/it]
# Validation IWAE: -2.29941e+06:  62% 5/8 [00:14<00:06,  2.24s/it]
# Validation IWAE: -2.29941e+06:  75% 6/8 [00:14<00:04,  2.18s/it]
# Validation IWAE: -2.8074e+06:  75% 6/8 [00:16<00:04,  2.18s/it]
# Validation IWAE: -2.8074e+06:  88% 7/8 [00:16<00:02,  2.13s/it]
# Validation IWAE: -3.52747e+06:  88% 7/8 [00:18<00:02,  2.13s/it]
# Validation IWAE: -3.52747e+06: 100% 8/8 [00:18<00:00,  2.33s/it]
#
#
# /content/VAEAC_Thesis/train.py:181: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(args.amp and torch.cuda.is_available())):
# /content/VAEAC_Thesis/train.py:197: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:835.)
#   avg_vlb += (float(vlb) - avg_vlb) / (i + 1)
# [alpha_0.0] Epoch 1/25:  20% 117/586 [01:34<04:57,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-33281.8]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -2.73409e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -2.73409e+06:  12% 1/8 [00:02<00:17,  2.54s/it]
# Validation IWAE: -5.125e+06:  12% 1/8 [00:04<00:17,  2.54s/it]
# Validation IWAE: -5.125e+06:  25% 2/8 [00:04<00:13,  2.25s/it]
# Validation IWAE: -4.64312e+06:  25% 2/8 [00:06<00:13,  2.25s/it]
# Validation IWAE: -4.64312e+06:  38% 3/8 [00:06<00:10,  2.16s/it]
# Validation IWAE: -4.92683e+06:  38% 3/8 [00:08<00:10,  2.16s/it]
# Validation IWAE: -4.92683e+06:  50% 4/8 [00:08<00:08,  2.11s/it]
# Validation IWAE: -4.30683e+06:  50% 4/8 [00:10<00:08,  2.11s/it]
# Validation IWAE: -4.30683e+06:  62% 5/8 [00:10<00:06,  2.09s/it]
# Validation IWAE: -7.50311e+06:  62% 5/8 [00:12<00:06,  2.09s/it]
# Validation IWAE: -7.50311e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -7.85757e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -7.85757e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -7.28929e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -7.28929e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 1/25:  40% 235/586 [03:06<03:42,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-24420.2]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -1.67187e+07:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -1.67187e+07:  12% 1/8 [00:02<00:17,  2.55s/it]
# Validation IWAE: -1.0987e+07:  12% 1/8 [00:04<00:17,  2.55s/it]
# Validation IWAE: -1.0987e+07:  25% 2/8 [00:04<00:13,  2.26s/it]
# Validation IWAE: -7.7751e+06:  25% 2/8 [00:06<00:13,  2.26s/it]
# Validation IWAE: -7.7751e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -8.09132e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -8.09132e+06:  50% 4/8 [00:08<00:08,  2.12s/it]
# Validation IWAE: -7.58469e+06:  50% 4/8 [00:10<00:08,  2.12s/it]
# Validation IWAE: -7.58469e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -7.55792e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -7.55792e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -6.76641e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -6.76641e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -6.78711e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -6.78711e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 1/25:  60% 353/586 [04:39<02:27,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-20828.3]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -3.36786e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -3.36786e+06:  12% 1/8 [00:02<00:17,  2.55s/it]
# Validation IWAE: -5.22248e+06:  12% 1/8 [00:04<00:17,  2.55s/it]
# Validation IWAE: -5.22248e+06:  25% 2/8 [00:04<00:13,  2.26s/it]
# Validation IWAE: -8.32844e+06:  25% 2/8 [00:06<00:13,  2.26s/it]
# Validation IWAE: -8.32844e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -6.60513e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -6.60513e+06:  50% 4/8 [00:08<00:08,  2.12s/it]
# Validation IWAE: -5.76861e+06:  50% 4/8 [00:10<00:08,  2.12s/it]
# Validation IWAE: -5.76861e+06:  62% 5/8 [00:10<00:06,  2.09s/it]
# Validation IWAE: -5.03636e+06:  62% 5/8 [00:12<00:06,  2.09s/it]
# Validation IWAE: -5.03636e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -5.03373e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -5.03373e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -4.70064e+06:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -4.70064e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 1/25:  80% 471/586 [06:11<01:12,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-18958.1]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -6.43798e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -6.43798e+06:  12% 1/8 [00:02<00:17,  2.53s/it]
# Validation IWAE: -7.65393e+06:  12% 1/8 [00:04<00:17,  2.53s/it]
# Validation IWAE: -7.65393e+06:  25% 2/8 [00:04<00:13,  2.25s/it]
# Validation IWAE: -8.47883e+06:  25% 2/8 [00:06<00:13,  2.25s/it]
# Validation IWAE: -8.47883e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -9.93193e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -9.93193e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -1.00967e+07:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -1.00967e+07:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -9.20929e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -9.20929e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -7.95246e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -7.95246e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -7.65707e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -7.65707e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 1/25: 100% 585/586 [07:41<00:00,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-17794.9]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -6.77935e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -6.77935e+06:  12% 1/8 [00:02<00:17,  2.54s/it]
# Validation IWAE: -4.54829e+06:  12% 1/8 [00:04<00:17,  2.54s/it]
# Validation IWAE: -4.54829e+06:  25% 2/8 [00:04<00:13,  2.27s/it]
# Validation IWAE: -4.34039e+06:  25% 2/8 [00:06<00:13,  2.27s/it]
# Validation IWAE: -4.34039e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -3.88303e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -3.88303e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -6.51022e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -6.51022e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -6.77787e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -6.77787e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -5.96848e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -5.96848e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -5.78652e+06:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -5.78652e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 1/25: 100% 586/586 [08:00<00:00,  1.22it/s, alpha=tensor(0., device='cuda:0'), vlb=-17785.3]
# +------------------------------------------------------------------------+
# | Alpha: alpha_0.0            | Epoch: 1/25   | Avg VLB: -17785.251 |
# +------------------------------------------------------------------------+
# | Batch           : (128, 3, 128, 128)
# | Mask            : (128, 3, 128, 128)
# | q.mean          : (128, 256, 1, 1)
# | p.mean          : (128, 256, 1, 1)
# | z               : (128, 256, 1, 1)
# | rec_params      : (128, 6, 128, 128)
# +------------------------------------------------------------------------+
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100% 91.2M/91.2M [00:01<00:00, 76.9MB/s]
# /usr/local/lib/python3.12/dist-packages/torch_fidelity/datasets.py:16: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(img.tobytes())).view(height, width, 3)
# [alpha_0.0] Epoch 2/25:  20% 117/586 [01:14<04:56,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-12847.9]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -1.30702e+07:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -1.30702e+07:  12% 1/8 [00:02<00:17,  2.49s/it]
# Validation IWAE: -1.06858e+07:  12% 1/8 [00:04<00:17,  2.49s/it]
# Validation IWAE: -1.06858e+07:  25% 2/8 [00:04<00:13,  2.24s/it]
# Validation IWAE: -9.01593e+06:  25% 2/8 [00:06<00:13,  2.24s/it]
# Validation IWAE: -9.01593e+06:  38% 3/8 [00:06<00:10,  2.16s/it]
# Validation IWAE: -7.7087e+06:  38% 3/8 [00:08<00:10,  2.16s/it]
# Validation IWAE: -7.7087e+06:  50% 4/8 [00:08<00:08,  2.12s/it]
# Validation IWAE: -7.5033e+06:  50% 4/8 [00:10<00:08,  2.12s/it]
# Validation IWAE: -7.5033e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -6.96136e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -6.96136e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -6.32326e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -6.32326e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -6.45125e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -6.45125e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 2/25:  40% 235/586 [02:47<03:43,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-12844.1]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -2.86262e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -2.86262e+06:  12% 1/8 [00:02<00:17,  2.50s/it]
# Validation IWAE: -4.31174e+06:  12% 1/8 [00:04<00:17,  2.50s/it]
# Validation IWAE: -4.31174e+06:  25% 2/8 [00:04<00:13,  2.25s/it]
# Validation IWAE: -5.33246e+06:  25% 2/8 [00:06<00:13,  2.25s/it]
# Validation IWAE: -5.33246e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -4.37159e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -4.37159e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -5.49356e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -5.49356e+06:  62% 5/8 [00:10<00:06,  2.11s/it]
# Validation IWAE: -6.20797e+06:  62% 5/8 [00:12<00:06,  2.11s/it]
# Validation IWAE: -6.20797e+06:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -5.61923e+06:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -5.61923e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -5.47794e+06:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -5.47794e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 2/25:  60% 353/586 [04:20<02:27,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-12765.6]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -7.64014e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -7.64014e+06:  12% 1/8 [00:02<00:17,  2.56s/it]
# Validation IWAE: -5.69908e+06:  12% 1/8 [00:04<00:17,  2.56s/it]
# Validation IWAE: -5.69908e+06:  25% 2/8 [00:04<00:13,  2.27s/it]
# Validation IWAE: -4.75371e+06:  25% 2/8 [00:06<00:13,  2.27s/it]
# Validation IWAE: -4.75371e+06:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -3.85631e+06:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -3.85631e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -4.72545e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -4.72545e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -5.28462e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -5.28462e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -6.55681e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -6.55681e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -6.2611e+06:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -6.2611e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 2/25:  80% 471/586 [05:53<01:12,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-12694.0]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -1.60223e+07:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -1.60223e+07:  12% 1/8 [00:02<00:17,  2.55s/it]
# Validation IWAE: -9.85282e+06:  12% 1/8 [00:04<00:17,  2.55s/it]
# Validation IWAE: -9.85282e+06:  25% 2/8 [00:04<00:13,  2.26s/it]
# Validation IWAE: -7.01052e+06:  25% 2/8 [00:06<00:13,  2.26s/it]
# Validation IWAE: -7.01052e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -5.86516e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -5.86516e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -5.00111e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -5.00111e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -4.47433e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -4.47433e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -4.89942e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -4.89942e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -5.00807e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -5.00807e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 2/25: 100% 585/586 [07:23<00:00,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-12619.5]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -2.57663e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -2.57663e+06:  12% 1/8 [00:02<00:17,  2.55s/it]
# Validation IWAE: -1.44263e+06:  12% 1/8 [00:04<00:17,  2.55s/it]
# Validation IWAE: -1.44263e+06:  25% 2/8 [00:04<00:13,  2.26s/it]
# Validation IWAE: -2.37325e+06:  25% 2/8 [00:06<00:13,  2.26s/it]
# Validation IWAE: -2.37325e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -1.86129e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -1.86129e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -2.15071e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -2.15071e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -3.29433e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -3.29433e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -3.17825e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -3.17825e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -2.92443e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -2.92443e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 2/25: 100% 586/586 [07:42<00:00,  1.27it/s, alpha=tensor(0., device='cuda:0'), vlb=-12618.8]
# +------------------------------------------------------------------------+
# | Alpha: alpha_0.0            | Epoch: 2/25   | Avg VLB: -12618.836 |
# +------------------------------------------------------------------------+
# | Batch           : (128, 3, 128, 128)
# | Mask            : (128, 3, 128, 128)
# | q.mean          : (128, 256, 1, 1)
# | p.mean          : (128, 256, 1, 1)
# | z               : (128, 256, 1, 1)
# | rec_params      : (128, 6, 128, 128)
# +------------------------------------------------------------------------+
# [alpha_0.0] Epoch 3/25:   0% 0/586 [00:00<?, ?it/s]/content/VAEAC_Thesis/train.py:181: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(args.amp and torch.cuda.is_available())):
# [alpha_0.0] Epoch 3/25:  20% 117/586 [01:15<04:58,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-12128.9]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -3.4622e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -3.4622e+06:  12% 1/8 [00:02<00:18,  2.57s/it]
# Validation IWAE: -4.51752e+06:  12% 1/8 [00:04<00:18,  2.57s/it]
# Validation IWAE: -4.51752e+06:  25% 2/8 [00:04<00:13,  2.27s/it]
# Validation IWAE: -3.60981e+06:  25% 2/8 [00:06<00:13,  2.27s/it]
# Validation IWAE: -3.60981e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -2.99403e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -2.99403e+06:  50% 4/8 [00:08<00:08,  2.12s/it]
# Validation IWAE: -4.00352e+06:  50% 4/8 [00:10<00:08,  2.12s/it]
# Validation IWAE: -4.00352e+06:  62% 5/8 [00:10<00:06,  2.09s/it]
# Validation IWAE: -3.95342e+06:  62% 5/8 [00:12<00:06,  2.09s/it]
# Validation IWAE: -3.95342e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -3.8348e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -3.8348e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -5.32911e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -5.32911e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 3/25:  40% 235/586 [02:48<03:43,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-11944.1]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -966251:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -966251:  12% 1/8 [00:02<00:17,  2.49s/it]
# Validation IWAE: -2.49839e+06:  12% 1/8 [00:04<00:17,  2.49s/it]
# Validation IWAE: -2.49839e+06:  25% 2/8 [00:04<00:13,  2.24s/it]
# Validation IWAE: -4.95743e+06:  25% 2/8 [00:06<00:13,  2.24s/it]
# Validation IWAE: -4.95743e+06:  38% 3/8 [00:06<00:10,  2.15s/it]
# Validation IWAE: -6.1264e+06:  38% 3/8 [00:08<00:10,  2.15s/it]
# Validation IWAE: -6.1264e+06:  50% 4/8 [00:08<00:08,  2.12s/it]
# Validation IWAE: -5.45236e+06:  50% 4/8 [00:10<00:08,  2.12s/it]
# Validation IWAE: -5.45236e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -4.7663e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -4.7663e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -4.66219e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -4.66219e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -4.40706e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -4.40706e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 3/25:  60% 353/586 [04:21<02:28,  1.56it/s, alpha=tensor(0., device='cuda:0'), vlb=-11740.7]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -2.36991e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -2.36991e+06:  12% 1/8 [00:02<00:18,  2.58s/it]
# Validation IWAE: -1.25188e+06:  12% 1/8 [00:04<00:18,  2.58s/it]
# Validation IWAE: -1.25188e+06:  25% 2/8 [00:04<00:13,  2.27s/it]
# Validation IWAE: -1.2863e+06:  25% 2/8 [00:06<00:13,  2.27s/it]
# Validation IWAE: -1.2863e+06:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -2.76236e+06:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -2.76236e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -3.83395e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -3.83395e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -3.62899e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -3.62899e+06:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -3.31639e+06:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -3.31639e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -3.19327e+06:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -3.19327e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 3/25:  80% 471/586 [05:53<01:12,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-11450.5]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -2.90223e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -2.90223e+06:  12% 1/8 [00:02<00:18,  2.57s/it]
# Validation IWAE: -2.44174e+06:  12% 1/8 [00:04<00:18,  2.57s/it]
# Validation IWAE: -2.44174e+06:  25% 2/8 [00:04<00:13,  2.27s/it]
# Validation IWAE: -3.80274e+06:  25% 2/8 [00:06<00:13,  2.27s/it]
# Validation IWAE: -3.80274e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -3.78466e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -3.78466e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -4.86545e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -4.86545e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -4.30166e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -4.30166e+06:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -3.81654e+06:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -3.81654e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -5.3441e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -5.3441e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 3/25: 100% 585/586 [07:23<00:00,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-11124.8]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -1.70651e+07:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -1.70651e+07:  12% 1/8 [00:02<00:18,  2.58s/it]
# Validation IWAE: -8.9467e+06:  12% 1/8 [00:04<00:18,  2.58s/it]
# Validation IWAE: -8.9467e+06:  25% 2/8 [00:04<00:13,  2.28s/it]
# Validation IWAE: -6.09343e+06:  25% 2/8 [00:06<00:13,  2.28s/it]
# Validation IWAE: -6.09343e+06:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -4.65539e+06:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -4.65539e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -5.02445e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -5.02445e+06:  62% 5/8 [00:10<00:06,  2.11s/it]
# Validation IWAE: -4.55862e+06:  62% 5/8 [00:12<00:06,  2.11s/it]
# Validation IWAE: -4.55862e+06:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -4.37632e+06:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -4.37632e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -4.15426e+06:  88% 7/8 [00:17<00:02,  2.08s/it]
# Validation IWAE: -4.15426e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 3/25: 100% 586/586 [07:42<00:00,  1.27it/s, alpha=tensor(0., device='cuda:0'), vlb=-11121.2]
# +------------------------------------------------------------------------+
# | Alpha: alpha_0.0            | Epoch: 3/25   | Avg VLB: -11121.199 |
# +------------------------------------------------------------------------+
# | Batch           : (128, 3, 128, 128)
# | Mask            : (128, 3, 128, 128)
# | q.mean          : (128, 256, 1, 1)
# | p.mean          : (128, 256, 1, 1)
# | z               : (128, 256, 1, 1)
# | rec_params      : (128, 6, 128, 128)
# +------------------------------------------------------------------------+
# [alpha_0.0] Epoch 4/25:  20% 117/586 [01:16<04:56,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-8904.5]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -623373:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -623373:  12% 1/8 [00:02<00:18,  2.58s/it]
# Validation IWAE: -872210:  12% 1/8 [00:04<00:18,  2.58s/it]
# Validation IWAE: -872210:  25% 2/8 [00:04<00:13,  2.28s/it]
# Validation IWAE: -2.52624e+06:  25% 2/8 [00:06<00:13,  2.28s/it]
# Validation IWAE: -2.52624e+06:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -2.18753e+06:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -2.18753e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -1.80926e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -1.80926e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -1.70826e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -1.70826e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -3.24413e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -3.24413e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -3.35887e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -3.35887e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 4/25:  40% 235/586 [02:49<03:44,  1.56it/s, alpha=tensor(0., device='cuda:0'), vlb=-8366.6]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -1.02642e+07:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -1.02642e+07:  12% 1/8 [00:02<00:17,  2.50s/it]
# Validation IWAE: -8.95826e+06:  12% 1/8 [00:04<00:17,  2.50s/it]
# Validation IWAE: -8.95826e+06:  25% 2/8 [00:04<00:13,  2.24s/it]
# Validation IWAE: -8.54743e+06:  25% 2/8 [00:06<00:13,  2.24s/it]
# Validation IWAE: -8.54743e+06:  38% 3/8 [00:06<00:10,  2.15s/it]
# Validation IWAE: -6.65919e+06:  38% 3/8 [00:08<00:10,  2.15s/it]
# Validation IWAE: -6.65919e+06:  50% 4/8 [00:08<00:08,  2.11s/it]
# Validation IWAE: -5.72482e+06:  50% 4/8 [00:10<00:08,  2.11s/it]
# Validation IWAE: -5.72482e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -5.34785e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -5.34785e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -4.63491e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -4.63491e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -4.34927e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -4.34927e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 4/25:  60% 353/586 [04:22<02:28,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-8038.3]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -1.5763e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -1.5763e+06:  12% 1/8 [00:02<00:18,  2.60s/it]
# Validation IWAE: -1.19827e+06:  12% 1/8 [00:04<00:18,  2.60s/it]
# Validation IWAE: -1.19827e+06:  25% 2/8 [00:04<00:13,  2.29s/it]
# Validation IWAE: -2.4581e+06:  25% 2/8 [00:06<00:13,  2.29s/it]
# Validation IWAE: -2.4581e+06:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -2.20483e+06:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -2.20483e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -2.56827e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -2.56827e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -2.2925e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -2.2925e+06:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -2.54173e+06:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -2.54173e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -3.39199e+06:  88% 7/8 [00:17<00:02,  2.08s/it]
# Validation IWAE: -3.39199e+06: 100% 8/8 [00:17<00:00,  2.14s/it]
#
#
# [alpha_0.0] Epoch 4/25:  80% 471/586 [05:54<01:13,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-7672.9]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -592402:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -592402:  12% 1/8 [00:02<00:17,  2.53s/it]
# Validation IWAE: -2.17774e+06:  12% 1/8 [00:04<00:17,  2.53s/it]
# Validation IWAE: -2.17774e+06:  25% 2/8 [00:04<00:13,  2.26s/it]
# Validation IWAE: -1.84597e+06:  25% 2/8 [00:06<00:13,  2.26s/it]
# Validation IWAE: -1.84597e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -1.64981e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -1.64981e+06:  50% 4/8 [00:08<00:08,  2.12s/it]
# Validation IWAE: -2.07532e+06:  50% 4/8 [00:10<00:08,  2.12s/it]
# Validation IWAE: -2.07532e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -1.82437e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -1.82437e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -1.78487e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -1.78487e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -1.92701e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -1.92701e+06: 100% 8/8 [00:16<00:00,  2.12s/it]
#
#
# [alpha_0.0] Epoch 4/25: 100% 585/586 [07:25<00:00,  1.56it/s, alpha=tensor(0., device='cuda:0'), vlb=-7307.9]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -3.09476e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -3.09476e+06:  12% 1/8 [00:02<00:18,  2.58s/it]
# Validation IWAE: -2.92005e+06:  12% 1/8 [00:04<00:18,  2.58s/it]
# Validation IWAE: -2.92005e+06:  25% 2/8 [00:04<00:13,  2.28s/it]
# Validation IWAE: -2.0691e+06:  25% 2/8 [00:06<00:13,  2.28s/it]
# Validation IWAE: -2.0691e+06:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -2.01424e+06:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -2.01424e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -1.81768e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -1.81768e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -1.96058e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -1.96058e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -1.99718e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -1.99718e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -1.84874e+06:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -1.84874e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 4/25: 100% 586/586 [07:44<00:00,  1.26it/s, alpha=tensor(0., device='cuda:0'), vlb=-7303.2]
# +------------------------------------------------------------------------+
# | Alpha: alpha_0.0            | Epoch: 4/25   | Avg VLB:  -7303.163 |
# +------------------------------------------------------------------------+
# | Batch           : (128, 3, 128, 128)
# | Mask            : (128, 3, 128, 128)
# | q.mean          : (128, 256, 1, 1)
# | p.mean          : (128, 256, 1, 1)
# | z               : (128, 256, 1, 1)
# | rec_params      : (128, 6, 128, 128)
# +------------------------------------------------------------------------+
# [alpha_0.0] Epoch 5/25:   0% 0/586 [00:00<?, ?it/s]/content/VAEAC_Thesis/train.py:181: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(args.amp and torch.cuda.is_available())):
# [alpha_0.0] Epoch 5/25:  20% 117/586 [01:15<04:57,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-5183.7]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -1.98889e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -1.98889e+06:  12% 1/8 [00:02<00:18,  2.58s/it]
# Validation IWAE: -1.63791e+06:  12% 1/8 [00:04<00:18,  2.58s/it]
# Validation IWAE: -1.63791e+06:  25% 2/8 [00:04<00:13,  2.28s/it]
# Validation IWAE: -1.50684e+06:  25% 2/8 [00:06<00:13,  2.28s/it]
# Validation IWAE: -1.50684e+06:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -1.43882e+06:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -1.43882e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -1.36554e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -1.36554e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -1.18662e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -1.18662e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -1.32408e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -1.32408e+06:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -1.90014e+06:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -1.90014e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 5/25:  40% 235/586 [02:48<03:43,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-4914.2]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -294974:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -294974:  12% 1/8 [00:02<00:18,  2.60s/it]
# Validation IWAE: -1.22362e+06:  12% 1/8 [00:04<00:18,  2.60s/it]
# Validation IWAE: -1.22362e+06:  25% 2/8 [00:04<00:13,  2.29s/it]
# Validation IWAE: -983098:  25% 2/8 [00:06<00:13,  2.29s/it]
# Validation IWAE: -983098:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -848233:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -848233:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -1.00344e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -1.00344e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -1.15021e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -1.15021e+06:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -1.14022e+06:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -1.14022e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -1.22513e+06:  88% 7/8 [00:17<00:02,  2.08s/it]
# Validation IWAE: -1.22513e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 5/25:  60% 353/586 [04:20<02:27,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-4682.3]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -829744:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -829744:  12% 1/8 [00:02<00:17,  2.54s/it]
# Validation IWAE: -731172:  12% 1/8 [00:04<00:17,  2.54s/it]
# Validation IWAE: -731172:  25% 2/8 [00:04<00:13,  2.27s/it]
# Validation IWAE: -952997:  25% 2/8 [00:06<00:13,  2.27s/it]
# Validation IWAE: -952997:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -796581:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -796581:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -711531:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -711531:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -933060:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -933060:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -936425:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -936425:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -984015:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -984015: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 5/25:  80% 471/586 [05:54<01:13,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-4498.2]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -3.11363e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -3.11363e+06:  12% 1/8 [00:02<00:18,  2.60s/it]
# Validation IWAE: -2.15689e+06:  12% 1/8 [00:04<00:18,  2.60s/it]
# Validation IWAE: -2.15689e+06:  25% 2/8 [00:04<00:13,  2.28s/it]
# Validation IWAE: -1.82845e+06:  25% 2/8 [00:06<00:13,  2.28s/it]
# Validation IWAE: -1.82845e+06:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -1.4412e+06:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -1.4412e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -1.18051e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -1.18051e+06:  62% 5/8 [00:10<00:06,  2.11s/it]
# Validation IWAE: -1.06876e+06:  62% 5/8 [00:12<00:06,  2.11s/it]
# Validation IWAE: -1.06876e+06:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -1.0514e+06:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -1.0514e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -1.12195e+06:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -1.12195e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 5/25: 100% 585/586 [07:24<00:00,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-4340.6]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -1.78358e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -1.78358e+06:  12% 1/8 [00:02<00:17,  2.55s/it]
# Validation IWAE: -1.22415e+06:  12% 1/8 [00:04<00:17,  2.55s/it]
# Validation IWAE: -1.22415e+06:  25% 2/8 [00:04<00:13,  2.26s/it]
# Validation IWAE: -912149:  25% 2/8 [00:06<00:13,  2.26s/it]
# Validation IWAE: -912149:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -1.17246e+06:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -1.17246e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -1.13632e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -1.13632e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -975520:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -975520:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -860829:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -860829:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -785740:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -785740: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 5/25: 100% 586/586 [07:43<00:00,  1.26it/s, alpha=tensor(0., device='cuda:0'), vlb=-4338.6]
# +------------------------------------------------------------------------+
# | Alpha: alpha_0.0            | Epoch: 5/25   | Avg VLB:  -4338.581 |
# +------------------------------------------------------------------------+
# | Batch           : (128, 3, 128, 128)
# | Mask            : (128, 3, 128, 128)
# | q.mean          : (128, 256, 1, 1)
# | p.mean          : (128, 256, 1, 1)
# | z               : (128, 256, 1, 1)
# | rec_params      : (128, 6, 128, 128)
# +------------------------------------------------------------------------+
# [alpha_0.0] Epoch 6/25:  20% 117/586 [01:15<04:57,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-3431.7]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -807136:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -807136:  12% 1/8 [00:02<00:17,  2.56s/it]
# Validation IWAE: -1.79299e+06:  12% 1/8 [00:04<00:17,  2.56s/it]
# Validation IWAE: -1.79299e+06:  25% 2/8 [00:04<00:13,  2.26s/it]
# Validation IWAE: -1.36878e+06:  25% 2/8 [00:06<00:13,  2.26s/it]
# Validation IWAE: -1.36878e+06:  38% 3/8 [00:06<00:10,  2.17s/it]
# Validation IWAE: -1.08842e+06:  38% 3/8 [00:08<00:10,  2.17s/it]
# Validation IWAE: -1.08842e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -1.2787e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -1.2787e+06:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -1.21821e+06:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -1.21821e+06:  75% 6/8 [00:12<00:04,  2.08s/it]
# Validation IWAE: -1.14072e+06:  75% 6/8 [00:14<00:04,  2.08s/it]
# Validation IWAE: -1.14072e+06:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -1.0569e+06:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -1.0569e+06: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 6/25:  40% 235/586 [02:48<03:43,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-3300.5]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -2.05713e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -2.05713e+06:  12% 1/8 [00:02<00:18,  2.60s/it]
# Validation IWAE: -1.42907e+06:  12% 1/8 [00:04<00:18,  2.60s/it]
# Validation IWAE: -1.42907e+06:  25% 2/8 [00:04<00:13,  2.27s/it]
# Validation IWAE: -1.13959e+06:  25% 2/8 [00:06<00:13,  2.27s/it]
# Validation IWAE: -1.13959e+06:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -1.11273e+06:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -1.11273e+06:  50% 4/8 [00:08<00:08,  2.12s/it]
# Validation IWAE: -949358:  50% 4/8 [00:10<00:08,  2.12s/it]
# Validation IWAE: -949358:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -802350:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -802350:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -732437:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -732437:  88% 7/8 [00:14<00:02,  2.07s/it]
# Validation IWAE: -662343:  88% 7/8 [00:16<00:02,  2.07s/it]
# Validation IWAE: -662343: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 6/25:  60% 353/586 [04:21<02:28,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-3175.3]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -916343:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -916343:  12% 1/8 [00:02<00:18,  2.60s/it]
# Validation IWAE: -512174:  12% 1/8 [00:04<00:18,  2.60s/it]
# Validation IWAE: -512174:  25% 2/8 [00:04<00:13,  2.29s/it]
# Validation IWAE: -566574:  25% 2/8 [00:06<00:13,  2.29s/it]
# Validation IWAE: -566574:  38% 3/8 [00:06<00:10,  2.19s/it]
# Validation IWAE: -481614:  38% 3/8 [00:08<00:10,  2.19s/it]
# Validation IWAE: -481614:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -466966:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -466966:  62% 5/8 [00:10<00:06,  2.11s/it]
# Validation IWAE: -437410:  62% 5/8 [00:12<00:06,  2.11s/it]
# Validation IWAE: -437410:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -508403:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -508403:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -590494:  88% 7/8 [00:17<00:02,  2.08s/it]
# Validation IWAE: -590494: 100% 8/8 [00:17<00:00,  2.14s/it]
#
#
# [alpha_0.0] Epoch 6/25:  80% 471/586 [05:54<01:13,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-3081.9]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -239966:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -239966:  12% 1/8 [00:02<00:18,  2.58s/it]
# Validation IWAE: -309192:  12% 1/8 [00:04<00:18,  2.58s/it]
# Validation IWAE: -309192:  25% 2/8 [00:04<00:13,  2.28s/it]
# Validation IWAE: -316644:  25% 2/8 [00:06<00:13,  2.28s/it]
# Validation IWAE: -316644:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -601278:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -601278:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -514266:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -514266:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -525581:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -525581:  75% 6/8 [00:12<00:04,  2.10s/it]
# Validation IWAE: -787316:  75% 6/8 [00:14<00:04,  2.10s/it]
# Validation IWAE: -787316:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -736236:  88% 7/8 [00:17<00:02,  2.08s/it]
# Validation IWAE: -736236: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 6/25: 100% 585/586 [07:25<00:00,  1.56it/s, alpha=tensor(0., device='cuda:0'), vlb=-3001.9]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -599835:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -599835:  12% 1/8 [00:02<00:18,  2.62s/it]
# Validation IWAE: -430470:  12% 1/8 [00:04<00:18,  2.62s/it]
# Validation IWAE: -430470:  25% 2/8 [00:04<00:13,  2.29s/it]
# Validation IWAE: -360056:  25% 2/8 [00:06<00:13,  2.29s/it]
# Validation IWAE: -360056:  38% 3/8 [00:06<00:10,  2.19s/it]
# Validation IWAE: -516485:  38% 3/8 [00:08<00:10,  2.19s/it]
# Validation IWAE: -516485:  50% 4/8 [00:08<00:08,  2.14s/it]
# Validation IWAE: -463955:  50% 4/8 [00:10<00:08,  2.14s/it]
# Validation IWAE: -463955:  62% 5/8 [00:10<00:06,  2.11s/it]
# Validation IWAE: -396562:  62% 5/8 [00:12<00:06,  2.11s/it]
# Validation IWAE: -396562:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -477399:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -477399:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -441390:  88% 7/8 [00:17<00:02,  2.08s/it]
# Validation IWAE: -441390: 100% 8/8 [00:17<00:00,  2.14s/it]
#
#
# [alpha_0.0] Epoch 6/25: 100% 586/586 [07:44<00:00,  1.26it/s, alpha=tensor(0., device='cuda:0'), vlb=-3000.0]
# +------------------------------------------------------------------------+
# | Alpha: alpha_0.0            | Epoch: 6/25   | Avg VLB:  -3000.046 |
# +------------------------------------------------------------------------+
# | Batch           : (128, 3, 128, 128)
# | Mask            : (128, 3, 128, 128)
# | q.mean          : (128, 256, 1, 1)
# | p.mean          : (128, 256, 1, 1)
# | z               : (128, 256, 1, 1)
# | rec_params      : (128, 6, 128, 128)
# +------------------------------------------------------------------------+
# [alpha_0.0] Epoch 7/25:   0% 0/586 [00:00<?, ?it/s]/content/VAEAC_Thesis/train.py:181: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(args.amp and torch.cuda.is_available())):
# [alpha_0.0] Epoch 7/25:  20% 117/586 [01:16<04:59,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-2487.5]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -3.45124e+06:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -3.45124e+06:  12% 1/8 [00:02<00:17,  2.57s/it]
# Validation IWAE: -1.90673e+06:  12% 1/8 [00:04<00:17,  2.57s/it]
# Validation IWAE: -1.90673e+06:  25% 2/8 [00:04<00:13,  2.28s/it]
# Validation IWAE: -1.33559e+06:  25% 2/8 [00:06<00:13,  2.28s/it]
# Validation IWAE: -1.33559e+06:  38% 3/8 [00:06<00:10,  2.19s/it]
# Validation IWAE: -1.03548e+06:  38% 3/8 [00:08<00:10,  2.19s/it]
# Validation IWAE: -1.03548e+06:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -1.10046e+06:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -1.10046e+06:  62% 5/8 [00:10<00:06,  2.11s/it]
# Validation IWAE: -1.06641e+06:  62% 5/8 [00:12<00:06,  2.11s/it]
# Validation IWAE: -1.06641e+06:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -956314:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -956314:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -903052:  88% 7/8 [00:17<00:02,  2.08s/it]
# Validation IWAE: -903052: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 7/25:  40% 235/586 [02:49<03:46,  1.55it/s, alpha=tensor(0., device='cuda:0'), vlb=-2340.6]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -491572:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -491572:  12% 1/8 [00:02<00:18,  2.59s/it]
# Validation IWAE: -1.16895e+06:  12% 1/8 [00:04<00:18,  2.59s/it]
# Validation IWAE: -1.16895e+06:  25% 2/8 [00:04<00:13,  2.28s/it]
# Validation IWAE: -871761:  25% 2/8 [00:06<00:13,  2.28s/it]
# Validation IWAE: -871761:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -714649:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -714649:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -872812:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -872812:  62% 5/8 [00:10<00:06,  2.11s/it]
# Validation IWAE: -839204:  62% 5/8 [00:12<00:06,  2.11s/it]
# Validation IWAE: -839204:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -727873:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -727873:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -679259:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -679259: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 7/25:  60% 353/586 [04:21<02:27,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-2232.1]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -83121.7:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -83121.7:  12% 1/8 [00:02<00:18,  2.63s/it]
# Validation IWAE: -59819:  12% 1/8 [00:04<00:18,  2.63s/it]
# Validation IWAE: -59819:  25% 2/8 [00:04<00:13,  2.31s/it]
# Validation IWAE: -154665:  25% 2/8 [00:06<00:13,  2.31s/it]
# Validation IWAE: -154665:  38% 3/8 [00:06<00:10,  2.20s/it]
# Validation IWAE: -236288:  38% 3/8 [00:08<00:10,  2.20s/it]
# Validation IWAE: -236288:  50% 4/8 [00:08<00:08,  2.14s/it]
# Validation IWAE: -279819:  50% 4/8 [00:10<00:08,  2.14s/it]
# Validation IWAE: -279819:  62% 5/8 [00:10<00:06,  2.11s/it]
# Validation IWAE: -340205:  62% 5/8 [00:12<00:06,  2.11s/it]
# Validation IWAE: -340205:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -393017:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -393017:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -358528:  88% 7/8 [00:17<00:02,  2.08s/it]
# Validation IWAE: -358528: 100% 8/8 [00:17<00:00,  2.14s/it]
#
#
# [alpha_0.0] Epoch 7/25:  80% 471/586 [05:54<01:13,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=-2110.4]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -444334:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -444334:  12% 1/8 [00:02<00:17,  2.57s/it]
# Validation IWAE: -377864:  12% 1/8 [00:04<00:17,  2.57s/it]
# Validation IWAE: -377864:  25% 2/8 [00:04<00:13,  2.28s/it]
# Validation IWAE: -649171:  25% 2/8 [00:06<00:13,  2.28s/it]
# Validation IWAE: -649171:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -575217:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -575217:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -600826:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -600826:  62% 5/8 [00:10<00:06,  2.10s/it]
# Validation IWAE: -664205:  62% 5/8 [00:12<00:06,  2.10s/it]
# Validation IWAE: -664205:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -599448:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -599448:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -558663:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -558663: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 7/25: 100% 585/586 [07:25<00:00,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=-1996.9]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: -660544:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: -660544:  12% 1/8 [00:02<00:18,  2.57s/it]
# Validation IWAE: -409840:  12% 1/8 [00:04<00:18,  2.57s/it]
# Validation IWAE: -409840:  25% 2/8 [00:04<00:13,  2.27s/it]
# Validation IWAE: -501878:  25% 2/8 [00:06<00:13,  2.27s/it]
# Validation IWAE: -501878:  38% 3/8 [00:06<00:10,  2.18s/it]
# Validation IWAE: -402683:  38% 3/8 [00:08<00:10,  2.18s/it]
# Validation IWAE: -402683:  50% 4/8 [00:08<00:08,  2.13s/it]
# Validation IWAE: -425899:  50% 4/8 [00:10<00:08,  2.13s/it]
# Validation IWAE: -425899:  62% 5/8 [00:10<00:06,  2.11s/it]
# Validation IWAE: -364084:  62% 5/8 [00:12<00:06,  2.11s/it]
# Validation IWAE: -364084:  75% 6/8 [00:12<00:04,  2.09s/it]
# Validation IWAE: -350636:  75% 6/8 [00:14<00:04,  2.09s/it]
# Validation IWAE: -350636:  88% 7/8 [00:14<00:02,  2.08s/it]
# Validation IWAE: -410110:  88% 7/8 [00:16<00:02,  2.08s/it]
# Validation IWAE: -410110: 100% 8/8 [00:17<00:00,  2.13s/it]
#
#
# [alpha_0.0] Epoch 7/25: 100% 586/586 [07:44<00:00,  1.26it/s, alpha=tensor(0., device='cuda:0'), vlb=-1997.0]
# +------------------------------------------------------------------------+
# | Alpha: alpha_0.0            | Epoch: 7/25   | Avg VLB:  -1996.952 |
# +------------------------------------------------------------------------+
# | Batch           : (128, 3, 128, 128)
# | Mask            : (128, 3, 128, 128)
# | q.mean          : (128, 256, 1, 1)
# | p.mean          : (128, 256, 1, 1)
# ...
# Validation IWAE: 2444.58:  38% 3/8 [00:06<00:11,  2.23s/it]
# Validation IWAE: 2287.64:  38% 3/8 [00:08<00:11,  2.23s/it]
# Validation IWAE: 2287.64:  50% 4/8 [00:08<00:08,  2.16s/it]
# Validation IWAE: 2207.72:  50% 4/8 [00:11<00:08,  2.16s/it]
# Validation IWAE: 2207.72:  62% 5/8 [00:11<00:06,  2.13s/it]
# Validation IWAE: 2278.16:  62% 5/8 [00:13<00:06,  2.13s/it]
# Validation IWAE: 2278.16:  75% 6/8 [00:13<00:04,  2.11s/it]
# Validation IWAE: 2430.67:  75% 6/8 [00:15<00:04,  2.11s/it]
# Validation IWAE: 2430.67:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 2477.15:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 2477.15: 100% 8/8 [00:17<00:00,  2.16s/it]
#
#
# [alpha_0.0] Epoch 23/25:  80% 471/586 [05:55<01:12,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=5433.3]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 2363.92:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 2363.92:  12% 1/8 [00:02<00:19,  2.81s/it]
# Validation IWAE: 2488.2:  12% 1/8 [00:04<00:19,  2.81s/it]
# Validation IWAE: 2488.2:  25% 2/8 [00:04<00:14,  2.37s/it]
# Validation IWAE: 2545.45:  25% 2/8 [00:06<00:14,  2.37s/it]
# Validation IWAE: 2545.45:  38% 3/8 [00:06<00:11,  2.23s/it]
# Validation IWAE: 2390.83:  38% 3/8 [00:08<00:11,  2.23s/it]
# Validation IWAE: 2390.83:  50% 4/8 [00:08<00:08,  2.16s/it]
# Validation IWAE: 2523.5:  50% 4/8 [00:11<00:08,  2.16s/it]
# Validation IWAE: 2523.5:  62% 5/8 [00:11<00:06,  2.12s/it]
# Validation IWAE: 2550.05:  62% 5/8 [00:13<00:06,  2.12s/it]
# Validation IWAE: 2550.05:  75% 6/8 [00:13<00:04,  2.10s/it]
# Validation IWAE: 2635.22:  75% 6/8 [00:15<00:04,  2.10s/it]
# Validation IWAE: 2635.22:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 2626.94:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 2626.94: 100% 8/8 [00:17<00:00,  2.16s/it]
#
#
# [alpha_0.0] Epoch 23/25: 100% 585/586 [07:27<00:00,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=5418.1]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 2664.21:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 2664.21:  12% 1/8 [00:02<00:19,  2.79s/it]
# Validation IWAE: 2796.2:  12% 1/8 [00:04<00:19,  2.79s/it]
# Validation IWAE: 2796.2:  25% 2/8 [00:04<00:14,  2.36s/it]
# Validation IWAE: 2793.52:  25% 2/8 [00:06<00:14,  2.36s/it]
# Validation IWAE: 2793.52:  38% 3/8 [00:06<00:11,  2.22s/it]
# Validation IWAE: 2415.48:  38% 3/8 [00:08<00:11,  2.22s/it]
# Validation IWAE: 2415.48:  50% 4/8 [00:08<00:08,  2.16s/it]
# Validation IWAE: 2462:  50% 4/8 [00:11<00:08,  2.16s/it]
# Validation IWAE: 2462:  62% 5/8 [00:11<00:06,  2.12s/it]
# Validation IWAE: 2297.68:  62% 5/8 [00:13<00:06,  2.12s/it]
# Validation IWAE: 2297.68:  75% 6/8 [00:13<00:04,  2.11s/it]
# Validation IWAE: 2327.72:  75% 6/8 [00:15<00:04,  2.11s/it]
# Validation IWAE: 2327.72:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 2274.4:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 2274.4: 100% 8/8 [00:17<00:00,  2.17s/it]
#
#
# [alpha_0.0] Epoch 23/25: 100% 586/586 [07:46<00:00,  1.26it/s, alpha=tensor(0., device='cuda:0'), vlb=5417.1]
# +------------------------------------------------------------------------+
# | Alpha: alpha_0.0            | Epoch: 23/25   | Avg VLB:   5417.084 |
# +------------------------------------------------------------------------+
# | Batch           : (128, 3, 128, 128)
# | Mask            : (128, 3, 128, 128)
# | q.mean          : (128, 256, 1, 1)
# | p.mean          : (128, 256, 1, 1)
# | z               : (128, 256, 1, 1)
# | rec_params      : (128, 6, 128, 128)
# +------------------------------------------------------------------------+
# [alpha_0.0] Epoch 24/25:  20% 117/586 [01:16<05:00,  1.56it/s, alpha=tensor(0., device='cuda:0'), vlb=5498.5]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 2362.54:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 2362.54:  12% 1/8 [00:02<00:19,  2.77s/it]
# Validation IWAE: 2756.29:  12% 1/8 [00:04<00:19,  2.77s/it]
# Validation IWAE: 2756.29:  25% 2/8 [00:04<00:14,  2.36s/it]
# Validation IWAE: 2374.75:  25% 2/8 [00:06<00:14,  2.36s/it]
# Validation IWAE: 2374.75:  38% 3/8 [00:06<00:11,  2.23s/it]
# Validation IWAE: 2477.08:  38% 3/8 [00:08<00:11,  2.23s/it]
# Validation IWAE: 2477.08:  50% 4/8 [00:08<00:08,  2.16s/it]
# Validation IWAE: 2430.78:  50% 4/8 [00:11<00:08,  2.16s/it]
# Validation IWAE: 2430.78:  62% 5/8 [00:11<00:06,  2.12s/it]
# Validation IWAE: 2391.63:  62% 5/8 [00:13<00:06,  2.12s/it]
# Validation IWAE: 2391.63:  75% 6/8 [00:13<00:04,  2.10s/it]
# Validation IWAE: 2417.13:  75% 6/8 [00:15<00:04,  2.10s/it]
# Validation IWAE: 2417.13:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 2431.19:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 2431.19: 100% 8/8 [00:17<00:00,  2.16s/it]
#
#
# [alpha_0.0] Epoch 24/25:  40% 235/586 [02:49<03:43,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=5498.0]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 1148.45:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 1148.45:  12% 1/8 [00:02<00:19,  2.83s/it]
# Validation IWAE: 1810.92:  12% 1/8 [00:04<00:19,  2.83s/it]
# Validation IWAE: 1810.92:  25% 2/8 [00:04<00:14,  2.39s/it]
# Validation IWAE: 2397.64:  25% 2/8 [00:06<00:14,  2.39s/it]
# Validation IWAE: 2397.64:  38% 3/8 [00:06<00:11,  2.24s/it]
# Validation IWAE: 2461.05:  38% 3/8 [00:09<00:11,  2.24s/it]
# Validation IWAE: 2461.05:  50% 4/8 [00:09<00:08,  2.17s/it]
# Validation IWAE: 2575.14:  50% 4/8 [00:11<00:08,  2.17s/it]
# Validation IWAE: 2575.14:  62% 5/8 [00:11<00:06,  2.13s/it]
# Validation IWAE: 2582.05:  62% 5/8 [00:13<00:06,  2.13s/it]
# Validation IWAE: 2582.05:  75% 6/8 [00:13<00:04,  2.11s/it]
# Validation IWAE: 2634.23:  75% 6/8 [00:15<00:04,  2.11s/it]
# Validation IWAE: 2634.23:  88% 7/8 [00:15<00:02,  2.10s/it]
# Validation IWAE: 2752.85:  88% 7/8 [00:17<00:02,  2.10s/it]
# Validation IWAE: 2752.85: 100% 8/8 [00:17<00:00,  2.18s/it]
#
#
# [alpha_0.0] Epoch 24/25:  60% 353/586 [04:23<02:28,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=5575.4]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 1929.96:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 1929.96:  12% 1/8 [00:02<00:19,  2.78s/it]
# Validation IWAE: 1714.03:  12% 1/8 [00:04<00:19,  2.78s/it]
# Validation IWAE: 1714.03:  25% 2/8 [00:04<00:14,  2.36s/it]
# Validation IWAE: 1582.42:  25% 2/8 [00:06<00:14,  2.36s/it]
# Validation IWAE: 1582.42:  38% 3/8 [00:06<00:11,  2.23s/it]
# Validation IWAE: 1693.84:  38% 3/8 [00:08<00:11,  2.23s/it]
# Validation IWAE: 1693.84:  50% 4/8 [00:08<00:08,  2.16s/it]
# Validation IWAE: 1785:  50% 4/8 [00:11<00:08,  2.16s/it]
# Validation IWAE: 1785:  62% 5/8 [00:11<00:06,  2.13s/it]
# Validation IWAE: 1800.56:  62% 5/8 [00:13<00:06,  2.13s/it]
# Validation IWAE: 1800.56:  75% 6/8 [00:13<00:04,  2.11s/it]
# Validation IWAE: 1690.8:  75% 6/8 [00:15<00:04,  2.11s/it]
# Validation IWAE: 1690.8:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 1790.99:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 1790.99: 100% 8/8 [00:17<00:00,  2.17s/it]
#
#
# [alpha_0.0] Epoch 24/25:  80% 471/586 [05:56<01:13,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=5578.2]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 2494.79:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 2494.79:  12% 1/8 [00:02<00:19,  2.84s/it]
# Validation IWAE: 2683.06:  12% 1/8 [00:04<00:19,  2.84s/it]
# Validation IWAE: 2683.06:  25% 2/8 [00:04<00:14,  2.38s/it]
# Validation IWAE: 2549.23:  25% 2/8 [00:06<00:14,  2.38s/it]
# Validation IWAE: 2549.23:  38% 3/8 [00:06<00:11,  2.24s/it]
# Validation IWAE: 2698.4:  38% 3/8 [00:09<00:11,  2.24s/it]
# Validation IWAE: 2698.4:  50% 4/8 [00:09<00:08,  2.16s/it]
# Validation IWAE: 2833.5:  50% 4/8 [00:11<00:08,  2.16s/it]
# Validation IWAE: 2833.5:  62% 5/8 [00:11<00:06,  2.12s/it]
# Validation IWAE: 2703.12:  62% 5/8 [00:13<00:06,  2.12s/it]
# Validation IWAE: 2703.12:  75% 6/8 [00:13<00:04,  2.10s/it]
# Validation IWAE: 2850.7:  75% 6/8 [00:15<00:04,  2.10s/it]
# Validation IWAE: 2850.7:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 2834.77:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 2834.77: 100% 8/8 [00:17<00:00,  2.17s/it]
#
#
# [alpha_0.0] Epoch 24/25: 100% 585/586 [07:27<00:00,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=5608.4]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 1742.26:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 1742.26:  12% 1/8 [00:02<00:19,  2.75s/it]
# Validation IWAE: 2266.19:  12% 1/8 [00:04<00:19,  2.75s/it]
# Validation IWAE: 2266.19:  25% 2/8 [00:04<00:14,  2.35s/it]
# Validation IWAE: 2299.96:  25% 2/8 [00:06<00:14,  2.35s/it]
# Validation IWAE: 2299.96:  38% 3/8 [00:06<00:11,  2.21s/it]
# Validation IWAE: 2378.33:  38% 3/8 [00:08<00:11,  2.21s/it]
# Validation IWAE: 2378.33:  50% 4/8 [00:08<00:08,  2.15s/it]
# Validation IWAE: 2369.66:  50% 4/8 [00:10<00:08,  2.15s/it]
# Validation IWAE: 2369.66:  62% 5/8 [00:10<00:06,  2.12s/it]
# Validation IWAE: 2378.36:  62% 5/8 [00:13<00:06,  2.12s/it]
# Validation IWAE: 2378.36:  75% 6/8 [00:13<00:04,  2.10s/it]
# Validation IWAE: 2499.89:  75% 6/8 [00:15<00:04,  2.10s/it]
# Validation IWAE: 2499.89:  88% 7/8 [00:15<00:02,  2.08s/it]
# Validation IWAE: 2521.66:  88% 7/8 [00:17<00:02,  2.08s/it]
# Validation IWAE: 2521.66: 100% 8/8 [00:17<00:00,  2.16s/it]
#
#
# [alpha_0.0] Epoch 24/25: 100% 586/586 [07:47<00:00,  1.25it/s, alpha=tensor(0., device='cuda:0'), vlb=5607.8]
# +------------------------------------------------------------------------+
# | Alpha: alpha_0.0            | Epoch: 24/25   | Avg VLB:   5607.790 |
# +------------------------------------------------------------------------+
# | Batch           : (128, 3, 128, 128)
# | Mask            : (128, 3, 128, 128)
# | q.mean          : (128, 256, 1, 1)
# | p.mean          : (128, 256, 1, 1)
# | z               : (128, 256, 1, 1)
# | rec_params      : (128, 6, 128, 128)
# +------------------------------------------------------------------------+
# [alpha_0.0] Epoch 25/25:   0% 0/586 [00:00<?, ?it/s]/content/VAEAC_Thesis/train.py:181: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(args.amp and torch.cuda.is_available())):
# [alpha_0.0] Epoch 25/25:  20% 117/586 [01:15<05:01,  1.56it/s, alpha=tensor(0., device='cuda:0'), vlb=5610.4]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 2976.81:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 2976.81:  12% 1/8 [00:02<00:20,  2.86s/it]
# Validation IWAE: 2479.37:  12% 1/8 [00:04<00:20,  2.86s/it]
# Validation IWAE: 2479.37:  25% 2/8 [00:04<00:14,  2.39s/it]
# Validation IWAE: 2520.64:  25% 2/8 [00:06<00:14,  2.39s/it]
# Validation IWAE: 2520.64:  38% 3/8 [00:06<00:11,  2.23s/it]
# Validation IWAE: 2453.25:  38% 3/8 [00:09<00:11,  2.23s/it]
# Validation IWAE: 2453.25:  50% 4/8 [00:09<00:08,  2.17s/it]
# Validation IWAE: 2301.21:  50% 4/8 [00:11<00:08,  2.17s/it]
# Validation IWAE: 2301.21:  62% 5/8 [00:11<00:06,  2.13s/it]
# Validation IWAE: 2388.39:  62% 5/8 [00:13<00:06,  2.13s/it]
# Validation IWAE: 2388.39:  75% 6/8 [00:13<00:04,  2.11s/it]
# Validation IWAE: 2499.31:  75% 6/8 [00:15<00:04,  2.11s/it]
# Validation IWAE: 2499.31:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 2538.96:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 2538.96: 100% 8/8 [00:17<00:00,  2.17s/it]
#
#
# [alpha_0.0] Epoch 25/25:  40% 235/586 [02:49<03:42,  1.58it/s, alpha=tensor(0., device='cuda:0'), vlb=5716.6]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 3812.68:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 3812.68:  12% 1/8 [00:02<00:19,  2.86s/it]
# Validation IWAE: 3543.19:  12% 1/8 [00:04<00:19,  2.86s/it]
# Validation IWAE: 3543.19:  25% 2/8 [00:04<00:14,  2.38s/it]
# Validation IWAE: 3565.33:  25% 2/8 [00:06<00:14,  2.38s/it]
# Validation IWAE: 3565.33:  38% 3/8 [00:06<00:11,  2.24s/it]
# Validation IWAE: 3498.95:  38% 3/8 [00:09<00:11,  2.24s/it]
# Validation IWAE: 3498.95:  50% 4/8 [00:09<00:08,  2.17s/it]
# Validation IWAE: 3564.69:  50% 4/8 [00:11<00:08,  2.17s/it]
# Validation IWAE: 3564.69:  62% 5/8 [00:11<00:06,  2.13s/it]
# Validation IWAE: 3170.61:  62% 5/8 [00:13<00:06,  2.13s/it]
# Validation IWAE: 3170.61:  75% 6/8 [00:13<00:04,  2.10s/it]
# Validation IWAE: 3193.48:  75% 6/8 [00:15<00:04,  2.10s/it]
# Validation IWAE: 3193.48:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 3225.91:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 3225.91: 100% 8/8 [00:17<00:00,  2.17s/it]
#
#
# [alpha_0.0] Epoch 25/25:  60% 353/586 [04:23<02:28,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=5743.7]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 2418.65:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 2418.65:  12% 1/8 [00:02<00:19,  2.83s/it]
# Validation IWAE: 2422.09:  12% 1/8 [00:04<00:19,  2.83s/it]
# Validation IWAE: 2422.09:  25% 2/8 [00:04<00:14,  2.38s/it]
# Validation IWAE: 2303.82:  25% 2/8 [00:06<00:14,  2.38s/it]
# Validation IWAE: 2303.82:  38% 3/8 [00:06<00:11,  2.23s/it]
# Validation IWAE: 2528.08:  38% 3/8 [00:09<00:11,  2.23s/it]
# Validation IWAE: 2528.08:  50% 4/8 [00:09<00:08,  2.17s/it]
# Validation IWAE: 2640.58:  50% 4/8 [00:11<00:08,  2.17s/it]
# Validation IWAE: 2640.58:  62% 5/8 [00:11<00:06,  2.12s/it]
# Validation IWAE: 2639.29:  62% 5/8 [00:13<00:06,  2.12s/it]
# Validation IWAE: 2639.29:  75% 6/8 [00:13<00:04,  2.10s/it]
# Validation IWAE: 2576.22:  75% 6/8 [00:15<00:04,  2.10s/it]
# Validation IWAE: 2576.22:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 2541.12:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 2541.12: 100% 8/8 [00:17<00:00,  2.16s/it]
#
#
# [alpha_0.0] Epoch 25/25:  80% 471/586 [05:56<01:13,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=5763.8]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 3409.56:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 3409.56:  12% 1/8 [00:02<00:19,  2.85s/it]
# Validation IWAE: 2457.01:  12% 1/8 [00:04<00:19,  2.85s/it]
# Validation IWAE: 2457.01:  25% 2/8 [00:04<00:14,  2.39s/it]
# Validation IWAE: 2511.7:  25% 2/8 [00:06<00:14,  2.39s/it]
# Validation IWAE: 2511.7:  38% 3/8 [00:06<00:11,  2.24s/it]
# Validation IWAE: 2636.95:  38% 3/8 [00:09<00:11,  2.24s/it]
# Validation IWAE: 2636.95:  50% 4/8 [00:09<00:08,  2.17s/it]
# Validation IWAE: 2620.17:  50% 4/8 [00:11<00:08,  2.17s/it]
# Validation IWAE: 2620.17:  62% 5/8 [00:11<00:06,  2.13s/it]
# Validation IWAE: 2609.95:  62% 5/8 [00:13<00:06,  2.13s/it]
# Validation IWAE: 2609.95:  75% 6/8 [00:13<00:04,  2.10s/it]
# Validation IWAE: 2644.54:  75% 6/8 [00:15<00:04,  2.10s/it]
# Validation IWAE: 2644.54:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 2642.76:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 2642.76: 100% 8/8 [00:17<00:00,  2.17s/it]
#
#
# [alpha_0.0] Epoch 25/25: 100% 585/586 [07:26<00:00,  1.57it/s, alpha=tensor(0., device='cuda:0'), vlb=5781.0]
#   0% 0/8 [00:00<?, ?it/s]
# Validation IWAE: 2650.33:   0% 0/8 [00:02<?, ?it/s]
# Validation IWAE: 2650.33:  12% 1/8 [00:02<00:19,  2.77s/it]
# Validation IWAE: 2210.87:  12% 1/8 [00:04<00:19,  2.77s/it]
# Validation IWAE: 2210.87:  25% 2/8 [00:04<00:14,  2.36s/it]
# Validation IWAE: 2278:  25% 2/8 [00:06<00:14,  2.36s/it]
# Validation IWAE: 2278:  38% 3/8 [00:06<00:11,  2.23s/it]
# Validation IWAE: 2553.41:  38% 3/8 [00:08<00:11,  2.23s/it]
# Validation IWAE: 2553.41:  50% 4/8 [00:08<00:08,  2.17s/it]
# Validation IWAE: 2810.77:  50% 4/8 [00:11<00:08,  2.17s/it]
# Validation IWAE: 2810.77:  62% 5/8 [00:11<00:06,  2.13s/it]
# Validation IWAE: 2780.75:  62% 5/8 [00:13<00:06,  2.13s/it]
# Validation IWAE: 2780.75:  75% 6/8 [00:13<00:04,  2.11s/it]
# Validation IWAE: 2754.59:  75% 6/8 [00:15<00:04,  2.11s/it]
# Validation IWAE: 2754.59:  88% 7/8 [00:15<00:02,  2.09s/it]
# Validation IWAE: 2709.36:  88% 7/8 [00:17<00:02,  2.09s/it]
# Validation IWAE: 2709.36: 100% 8/8 [00:17<00:00,  2.17s/it]
#
#
# [alpha_0.0] Epoch 25/25: 100% 586/586 [07:46<00:00,  1.26it/s, alpha=tensor(0., device='cuda:0'), vlb=5780.2]
# +------------------------------------------------------------------------+
# | Alpha: alpha_0.0            | Epoch: 25/25   | Avg VLB:   5780.158 |
# +------------------------------------------------------------------------+
# | Batch           : (128, 3, 128, 128)
# | Mask            : (128, 3, 128, 128)
# | q.mean          : (128, 256, 1, 1)
# | p.mean          : (128, 256, 1, 1)
# | z               : (128, 256, 1, 1)
# | rec_params      : (128, 6, 128, 128)
# +------------------------------------------------------------------------+
# [INFO] (alpha_0.0) training complete – saving history & plots…

# %%
import torch
import matplotlib.pyplot as plt

# Path to your uploaded checkpoint file
ckpt_path = "/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/best (4) (1).tar"
ckpt = torch.load(ckpt_path, map_location="cpu")

# Keys inside the checkpoint
print("Checkpoint keys:", list(ckpt.keys()))

# 1. Epoch
epoch = ckpt.get("epoch", None)
print(f"\nSaved at epoch: {epoch}")

# 2. Training history
train_vlb = ckpt.get("train_vlb", None)
validation_iwae = ckpt.get("validation_iwae", None)

if train_vlb is not None and validation_iwae is not None:
    print(f"\nNumber of train VLB records: {len(train_vlb)}")
    print(f"Number of validation IWAE records: {len(validation_iwae)}")

    print("\nLast 5 Train VLBs:", train_vlb[-5:])
    print("Last 5 Validation IWAEs:", validation_iwae[-5:])
else:
    print("No training/validation history found.")

# 3. Model state
print("\nModel state dict keys:", list(ckpt["model_state_dict"].keys())[:5], "...")
# 4. Optimizer state
print("Optimizer state dict keys:", list(ckpt["optimizer_state_dict"].keys())[:5], "...")

# --------- PLOT (skip first epoch to avoid extreme values) ----------
if train_vlb and validation_iwae:
    epochs = range(2, len(train_vlb) + 1)  # start from epoch 2
    plt.figure(figsize=(10,5))
    plt.plot(epochs, train_vlb[1:], label='Train VLB', marker="x")
    plt.plot(epochs, validation_iwae[1:], label='Validation IWAE', marker="o")
    plt.xlabel("Epoch")
    plt.ylabel("Value")
    plt.title("Training curves (skipping epoch 1)")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Checkpoint keys: ['epoch', 'model_state_dict', 'optimizer_state_dict', 'validation_iwae', 'train_vlb', 'rec_errors', 'kl_terms']
#
# Saved at epoch: 22
#
# Number of train VLB records: 116
# Number of validation IWAE records: 116
#
# Last 5 Train VLBs: [-1000400.2996794871, -969458.64787234, -955125.786650141, -929838.3861464965, -914952.9583333328]
# Last 5 Validation IWAEs: [-25206.32421875, -24871.009765625, -24633.935546875, -24125.115234375, -23222.498046875]
#
# Model state dict keys: ['proposal_network.0.weight', 'proposal_network.0.bias', 'proposal_network.1.net.0.weight', 'proposal_network.1.net.0.bias', 'proposal_network.1.net.0.running_mean'] ...
# Optimizer state dict keys: ['state', 'param_groups'] ...

# %%
import os
print(os.listdir())
# Out:
# ['impute.py', 'prob_utils.py', 'requirements.txt', '.git', 'README.md', 'mask_generators.py', 'nn_utils.py', '__init__.py', 'train_utils.py', 'data', '.gitignore', 'LICENSE', 'train.py', '__pycache__', 'imputation_networks.py', 'celeba_model', 'VAEAC.py', 'inpaint.py', 'datasets.py']

# %%
# !pwd
# Out:
# /content/vaeac

# %%
from google.colab import files

# download best.tar
files.download('/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_0.0/best.tar')

# download last.tar
files.download('/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_0.0/last.tar')

# %%
cd /content/VAEAC_Thesis
# Out:
# /content

# %%
# !git add celeba_model/alpha_runs/learnable/best.tar
# !git add celeba_model/alpha_runs/learnable/last.tar
# Out:
# The following paths are ignored by one of your .gitignore files:
# celeba_model/alpha_runs/learnable/best.tar
# hint: Use -f if you really want to add them.
# hint: Turn this message off by running
# hint: "git config advice.addIgnoredFile false"
# The following paths are ignored by one of your .gitignore files:
# celeba_model/alpha_runs/learnable/last.tar
# hint: Use -f if you really want to add them.
# hint: Turn this message off by running
# hint: "git config advice.addIgnoredFile false"

# %%
# !python inpaint.py --model_dir celeba_model --checkpoint_dir celeba_model/ \
  --dataset celeba_test --masks celeba_inpainting_masks \
  --out_dir celeba_inpaintings/Alphas_INF_07_10
# Out:
# [INFO] Loading checkpoint: /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/best (4) (1).tar
# 100% 2/2 [00:04<00:00,  2.16s/it]
# [INFO] Inpainting complete. Results saved to celeba_inpaintings/Alphas_INF_07_10

# %%
import os
result_dir = "celeba_inpaintings"  # adjust path if needed
print(sorted(os.listdir(result_dir))[:15])  # show a few files
# Out:
# ['Alphas_INF_07_10']

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

result_dir = "celeba_inpaintings/Alphas_INF_07_10"
n_show = 3  # how many examples to display

for i in range(n_show):
    fig, axs = plt.subplots(1, 5, figsize=(18, 4))
    files = [
        f"{i:05d}_groundtruth.jpg",
        f"{i:05d}_input.jpg",
        f"{i:05d}_sample_000.jpg",
        f"{i:05d}_sample_001.jpg",
        f"{i:05d}_sample_002.jpg"
    ]
    titles = ["Groundtruth", "Masked input", "Inpainted 1", "Inpainted 2", "Inpainted 3"]
    for j, (fname, title) in enumerate(zip(files, titles)):
        img = Image.open(os.path.join(result_dir, fname))
        axs[j].imshow(img)
        axs[j].set_title(title)
        axs[j].axis("off")
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

result_dir = "celeba_inpaintings/Alphas_INF_07_10"
n_show = 3  # how many examples to display

for i in range(n_show):
    fig, axs = plt.subplots(1, 5, figsize=(18, 4))
    files = [
        f"{i:05d}_groundtruth.jpg",
        f"{i:05d}_input.jpg",
        f"{i:05d}_sample_000.jpg",
        f"{i:05d}_sample_001.jpg",
        f"{i:05d}_sample_002.jpg"
    ]
    titles = ["Groundtruth", "Masked input", "Inpainted 1", "Inpainted 2", "Inpainted 3"]
    for j, (fname, title) in enumerate(zip(files, titles)):
        img = Image.open(os.path.join(result_dir, fname))
        axs[j].imshow(img)
        axs[j].set_title(title)
        axs[j].axis("off")
    plt.tight_layout()
    plt.show()

# %%
import os, re, shutil, tempfile
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm
from skimage.metrics import peak_signal_noise_ratio as psnr_metric, structural_similarity as ssim_metric
from torch_fidelity import calculate_metrics

import os
os.chdir("/content/VAEAC_Thesis")  # run once per session


from pathlib import Path
csv_path   = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/metrics_alphas.csv")
inpaint_dir = Path("celeba_inpaintings/Alphas_INF_07_10")
assert inpaint_dir.is_dir(), f"Not found: {inpaint_dir.resolve()}"
   # contains 00000_groundtruth.jpg, 00000_input.jpg, 00000_sample_000.jpg, ...
assert os.path.isdir(inpaint_dir), f"Not found: {inpaint_dir}"

# ---- load CSV ----
df = pd.read_csv(csv_path)

# ---- find paired (GT, sample) by ID inside inpaint_dir ----
id_rx = re.compile(r"^(\d{5})_")
files = sorted([f for f in os.listdir(inpaint_dir) if f.lower().endswith((".jpg",".png"))])

# map id -> groundtruth path / sample path (take the first sample_XXX found)
pairs = {}
for f in files:
    m = id_rx.match(f)
    if not m:
        continue
    idx = m.group(1)
    if f.endswith("groundtruth.jpg") or f.endswith("groundtruth.png"):
        pairs.setdefault(idx, {})["gt"] = os.path.join(inpaint_dir, f)
    elif "_sample_" in f:  # inpainted output
        pairs.setdefault(idx, {}).setdefault("sample", os.path.join(inpaint_dir, f))  # keep first sample found

# keep only ids with both
paired_ids = [i for i,d in pairs.items() if "gt" in d and "sample" in d]
paired_ids.sort()
print(f"[INFO] Found {len(paired_ids)} paired (groundtruth, sample) images.")

# ---- helpers ----
def load_rgb(path, size=(128,128)):
    img = Image.open(path).convert("RGB")
    if size is not None:
        img = img.resize(size, Image.BICUBIC)
    return np.array(img)

# ---- compute SSIM / PSNR with progress bar ----
ssim_vals, psnr_vals = [], []
for idx in tqdm(paired_ids, desc="SSIM/PSNR"):
    gt_img = load_rgb(pairs[idx]["gt"],  size=(128,128))
    ip_img = load_rgb(pairs[idx]["sample"], size=(128,128))
    # skimage >= 0.20 uses channel_axis
    ssim_vals.append(ssim_metric(gt_img, ip_img, channel_axis=2, data_range=255))
    psnr_vals.append(psnr_metric(gt_img, ip_img, data_range=255))

ssim_mean = float(np.mean(ssim_vals)) if ssim_vals else float("nan")
psnr_mean = float(np.mean(psnr_vals)) if psnr_vals else float("nan")

# ---- compute FID on the same paired subset ----
print("[INFO] Computing FID on paired subset…")
tmp_root = tempfile.mkdtemp(prefix="fid_eval_")
tmp_gt   = os.path.join(tmp_root, "gt")
tmp_ip   = os.path.join(tmp_root, "ip")
os.makedirs(tmp_gt, exist_ok=True)
os.makedirs(tmp_ip, exist_ok=True)

for i, idx in enumerate(tqdm(paired_ids, desc="Preparing FID inputs")):
    gt_img = Image.fromarray(load_rgb(pairs[idx]["gt"], size=(128,128)))
    ip_img = Image.fromarray(load_rgb(pairs[idx]["sample"], size=(128,128)))
    gt_img.save(os.path.join(tmp_gt, f"{i:06d}.png"))
    ip_img.save(os.path.join(tmp_ip, f"{i:06d}.png"))

# 🔁 Use CPU instead of GPU for FID
fid_res   = calculate_metrics(input1=tmp_ip, input2=tmp_gt, fid=True, kid=False, verbose=False, cuda=False)
fid_value = float(fid_res["frechet_inception_distance"])


# cleanup temp
shutil.rmtree(tmp_root, ignore_errors=True)

print(f"[RESULT] FID: {fid_value:.2f} | SSIM: {ssim_mean:.3f} | PSNR: {psnr_mean:.2f} dB")

# ---- update CSV at the last epoch row ----
last_epoch = df["epoch"].max()
mask_last  = df["epoch"] == last_epoch
df.loc[mask_last, "fid"]  = fid_value
df.loc[mask_last, "ssim"] = ssim_mean
df.loc[mask_last, "psnr"] = psnr_mean
df.to_csv(csv_path, index=False)
print(f"[INFO] CSV updated for epoch {last_epoch} at {csv_path}")
# Out:
# [INFO] Found 256 paired (groundtruth, sample) images.
# SSIM/PSNR: 100%|██████████| 256/256 [00:01<00:00, 198.03it/s]
# [INFO] Computing FID on paired subset…
# Preparing FID inputs: 100%|██████████| 256/256 [00:02<00:00, 92.94it/s]
# Downloading: "https://github.com/toshas/torch-fidelity/releases/download/v0.2.0/weights-inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/weights-inception-2015-12-05-6726825d.pth
# 100%|██████████| 91.2M/91.2M [00:00<00:00, 272MB/s]
# /usr/local/lib/python3.12/dist-packages/torch_fidelity/datasets.py:16: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(img.tobytes())).view(height, width, 3)
# [RESULT] FID: 178.18 | SSIM: 0.641 | PSNR: 14.40 dB
# [INFO] CSV updated for epoch 25 at /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/metrics_alphas.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# --- paths ---
CSV = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/metrics_alphas.csv")
OUT_PNG = CSV.with_name("metrics_alphas_plots.png")

# --- load & sanitize ---
df = pd.read_csv(CSV)

# Keep only rows that correspond to the end-of-epoch snapshot or otherwise
# take the last record per epoch (so we don’t double-count interim steps)
# We prefer rows where 'step' == 'epoch_end' if present; else take last row per epoch.
if "step" in df.columns and (df["step"] == "epoch_end").any():
    dfe = df[df["step"] == "epoch_end"].copy()
else:
    dfe = df.sort_values(["epoch"]).groupby("epoch", as_index=False).tail(1).copy()

# Ensure numeric columns are numeric (coerce errors to NaN)
for col in ["fid", "ssim", "psnr"]:
    if col in dfe.columns:
        dfe[col] = pd.to_numeric(dfe[col], errors="coerce")

# Sort by epoch and drop epochs with all metrics missing
dfe = dfe.sort_values("epoch")
mask_any = dfe[["fid","ssim","psnr"]].notna().any(axis=1)
dfe = dfe[mask_any].reset_index(drop=True)

if dfe.empty:
    raise RuntimeError("No per-epoch metrics found in the CSV (fid/ssim/psnr all NaN).")

epochs = dfe["epoch"].to_numpy()

# Optional smoothing (moving average); set WINDOW=1 to disable
WINDOW = 1  # e.g., use 3 for light smoothing
def smooth(x, w=WINDOW):
    if w <= 1: return x
    x = np.asarray(x, dtype=float)
    return np.convolve(x, np.ones(w)/w, mode="same")

metrics = {
    "FID (↓ better)":  ("fid",  True),   # lower is better
    "SSIM (↑ better)": ("ssim", False),  # higher is better
    "PSNR (dB, ↑)":    ("psnr", False),
}

# --- plot ---
plt.figure(figsize=(12, 7))
for label, (col, lower_better) in metrics.items():
    if col not in dfe.columns:
        continue
    y = dfe[col].to_numpy()
    if np.all(np.isnan(y)):
        continue
    ys = smooth(y, WINDOW)
    # Plot raw (faint) + smoothed (solid) if smoothing used
    if WINDOW > 1:
        plt.plot(epochs, y, linestyle="--", alpha=0.35, marker="o", label=f"{label} (raw)")
    plt.plot(epochs, ys, marker="o", label=label)

plt.xlabel("Epoch")
plt.ylabel("Metric value")
plt.title("Inpainting Metrics over Epochs ")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.savefig(OUT_PNG, dpi=200)
plt.show()

print(f"[Saved] {OUT_PNG}")
# Out:
# [Saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/metrics_alphas_plots.png

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

CSV = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/metrics_alphas.csv")
OUT_PNG = CSV.with_name("metrics_alphas_plots.png")
OUT_PDF = CSV.with_name("metrics_alphas_plots.pdf")

df = pd.read_csv(CSV)

# keep last per epoch
if "step" in df.columns and (df["step"] == "epoch_end").any():
    dfe = df[df["step"] == "epoch_end"].copy()
else:
    dfe = df.sort_values(["epoch"]).groupby("epoch", as_index=False).tail(1).copy()

epochs = dfe["epoch"].to_numpy()
fid  = pd.to_numeric(dfe["fid"],  errors="coerce")
ssim = pd.to_numeric(dfe["ssim"], errors="coerce")
psnr = pd.to_numeric(dfe["psnr"], errors="coerce")

plt.style.use("seaborn-v0_8-whitegrid")
fig, ax1 = plt.subplots(figsize=(12,7))

# --- FID on left y-axis
ax1.plot(epochs, fid, "o-", color="tab:blue", label="FID (↓)")
ax1.set_ylabel("FID (lower is better)", fontsize=13, color="tab:blue")
ax1.tick_params(axis="y", labelcolor="tab:blue")

# --- SSIM & PSNR on right y-axis
ax2 = ax1.twinx()
ax2.plot(epochs, ssim, "s-", color="tab:orange", label="SSIM (↑)")
ax2.plot(epochs, psnr, "d-", color="tab:green", label="PSNR (dB, ↑)")
ax2.set_ylabel("SSIM / PSNR", fontsize=13, color="black")

# --- shared x-axis
ax1.set_xlabel("Epoch", fontsize=13)
ax1.set_title("Inpainting Metrics over Epochs", fontsize=15)

# --- legends
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1+lines2, labels1+labels2, loc="upper right", fontsize=11)

fig.tight_layout()
plt.savefig(OUT_PNG, dpi=200)
plt.savefig(OUT_PDF)  # vector graphics for papers
plt.show()

print(f"[Saved] {OUT_PNG}")
print(f"[Saved] {OUT_PDF}")
# Out:
# [Saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/metrics_alphas_plots.png
# [Saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/metrics_alphas_plots.pdf

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)

axes[0].plot(epochs, fid, "o-", color="tab:blue")
axes[0].set_ylabel("FID ↓", fontsize=12)
axes[0].grid(alpha=0.3)

axes[1].plot(epochs, ssim, "s-", color="tab:orange")
axes[1].set_ylabel("SSIM ↑", fontsize=12)
axes[1].grid(alpha=0.3)

axes[2].plot(epochs, psnr, "d-", color="tab:green")
axes[2].set_ylabel("PSNR (dB) ↑", fontsize=12)
axes[2].set_xlabel("Epoch", fontsize=12)
axes[2].grid(alpha=0.3)

fig.suptitle("Inpainting Metrics over Epochs (learnable α run)", fontsize=14)
plt.tight_layout()
plt.show()

# %%
from datasets import load_dataset
ds = load_dataset("celeba_test")
print("celeba_test size:", len(ds))

ds = load_dataset("celeba_val")
print("celeba_val size:", len(ds))

ds = load_dataset("celeba_train")
print("celeba_train size:", len(ds))
# Out:
# celeba_test size: 256
# celeba_val size: 1024
# celeba_train size: 162762

# %%
# !pip install lpips torch-fidelity
# Out:
# Collecting lpips
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch-fidelity in /usr/local/lib/python3.12/dist-packages (0.3.0)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.23.0+cu126)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.0.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.2)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (4.67.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from torch-fidelity) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.0->lpips) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: lpips
# Successfully installed lpips-0.1.4

# %%
# !python FID.py \
  --gt_dir celeba_inpaintings/Alphas_INF_07_10 \
  --sample_dir celeba_inpaintings/Alphas_INF_07_10 \
  --mask_dir celeba_inpaintings/Alphas_INF_07_10 \
  --output_csv celeba_model/alpha_runs/alpha_inf/metrics_masked.csv
# Out:
# [INFO] Starting full masked evaluation
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100% 233M/233M [00:01<00:00, 238MB/s]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# [INFO] Evaluating 256 images...
# /usr/local/lib/python3.12/dist-packages/torch_fidelity/datasets.py:16: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   img = torch.ByteTensor(torch.ByteStorage.from_buffer(img.tobytes())).view(height, width, 3)
# [RESULT] Masked FID = 181.18 | LPIPS = 0.4220 | SSIM = 0.6343 | PSNR = 14.43 dB
# [INFO] Plots saved as masked_metrics_plot.png

# %%
import pandas as pd

df = pd.read_csv("celeba_model/alpha_runs/alpha_inf/metrics_masked.csv")
print(df.columns.tolist())
# Out:
# ['Image ID', 'SSIM', 'PSNR', 'LPIPS']

# %%
import seaborn as sns

plt.figure(figsize=(8, 4))
sns.histplot(df["LPIPS"], bins=30, kde=True)
plt.title("Distribution of LPIPS Scores")
plt.xlabel("LPIPS Distance")
plt.ylabel("Frequency")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import os
import re
from pathlib import Path

dir_path = Path("/content/VAEAC_Thesis/celeba_inpaintings/Alphas_INF_07_10")
id_rx = re.compile(r"(\d{5})")

gt_ids     = {id_rx.search(f).group(1) for f in os.listdir(dir_path) if "groundtruth" in f}
sample_ids = {id_rx.search(f).group(1) for f in os.listdir(dir_path) if "sample_000" in f}
mask_ids   = {id_rx.search(f).group(1) for f in os.listdir(dir_path) if "input" in f}

common_ids = gt_ids & sample_ids & mask_ids
print(f"Found {len(common_ids)} matching triplets.")
# Out:
# Found 256 matching triplets.

# %%
import pickle
from pathlib import Path

HIST_PATH = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history.pkl")
with open(HIST_PATH, "rb") as f:
    hist = pickle.load(f)

def explore(obj, prefix=()):
    if isinstance(obj, dict):
        for k,v in obj.items():
            explore(v, prefix+(k,))
    elif isinstance(obj, (list,tuple)):
        if obj and isinstance(obj[0], dict):
            for i,v in enumerate(obj):
                explore(v, prefix+(str(i),))
        else:
            print("/".join(prefix), "→", len(obj))
    else:
        print("/".join(prefix), "→ scalar")

explore(hist)
# Out:
# validation_iwae → 126
# train_vlb → 126
# rec_errors → 14650
# kl_terms → 14650

# %%
# === Parse & visualize history.pkl (robust flatten + skip first epoch) ===
import pickle, numpy as np, pandas as pd, matplotlib.pyplot as plt
from pathlib import Path
from collections.abc import Sequence

HIST_PATH = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history.pkl")
assert HIST_PATH.exists(), f"Not found: {HIST_PATH}"

# ---------- helpers ----------
def is_seq(x):
    return isinstance(x, (list, tuple, np.ndarray)) and not isinstance(x, (str, bytes))

def flatten(obj, prefix=()):
    """
    Recursively flatten nested dict/list structures into a dict:
      {('key','subkey',...): value}
    Lists inside lists are not expanded to rows; we only collect leaf values.
    """
    out = {}
    if isinstance(obj, dict):
        for k, v in obj.items():
            out.update(flatten(v, prefix + (str(k),)))
    elif is_seq(obj) and obj and all(not isinstance(v, dict) for v in obj):
        out[prefix] = list(obj)
    elif is_seq(obj) and obj and all(isinstance(v, dict) for v in obj):
        # list of dicts -> merge by index, prefix with position
        # convert to columns by collecting each key's list
        keys = set().union(*[d.keys() for d in obj])
        for k in keys:
            col = [d.get(k, None) for d in obj]
            out[prefix + (str(k),)] = col
    else:
        # scalar -> keep as single-element list so we can align later if needed
        out[prefix] = [obj]
    return out

with open(HIST_PATH, "rb") as f:
    hist = pickle.load(f)

flat = flatten(hist)

# choose the **dominant length** among list-like leaves
lengths = {}
for k, v in flat.items():
    if is_seq(v): lengths[k] = len(v)
L = max(lengths.values()) if lengths else 0
assert L > 0, "Could not find any list-like data in history.pkl."

# collect columns of length L; expand shorter scalars by padding (NaN)
cols = {}
for path, v in flat.items():
    name = "/".join(path)  # keep path for later heuristics
    if is_seq(v) and len(v) == L:
        cols[name] = v
    elif is_seq(v) and len(v) != L:
        # pad to align for convenience (rare)
        w = list(v) + [np.nan] * (L - len(v))
        cols[name] = w
    elif not is_seq(v):
        cols[name] = [v] * L  # broadcast scalar

df = pd.DataFrame(cols)

# ---------- auto-detect columns ----------
def find_col(substrings, pref_substrings=()):
    """Find a column by substring(s); prefer those that also contain any of pref_substrings."""
    cl = [c for c in df.columns if any(s in c.lower() for s in substrings)]
    if not cl: return None
    pref = [c for c in cl if any(s in c.lower() for s in pref_substrings)]
    return pref[0] if pref else cl[0]

# Try to find step/epoch; they might be named 'step', 'global_step', 'train/step', etc.
epoch_col = find_col(["epoch"])
step_col  = find_col(["step","iter","iteration","batch","global_step"])
# recon/kl: prefer ones that include 'train'
recon_col = find_col(["recon","reconstruction","rec_loss","loss_recon"], pref_substrings=("train",))
kl_col    = find_col(["kl","kld","kl_div","kl_divergence","kl_loss","loss_kl"], pref_substrings=("train",))
# split (optional)
split_col = find_col(["split","phase","mode"])

# coerce numerics where appropriate
for c in [epoch_col, step_col, recon_col, kl_col]:
    if c and c in df.columns:
        df[c] = pd.to_numeric(df[c], errors="coerce")

# if we still lack a step, make a monotonic index
if step_col is None:
    df["__step__"] = np.arange(len(df))
    step_col = "__step__"

# if multiple recon/kl columns existed and we didn't pick the 'train' one,
# show what we found to help adjust:
print("Detected columns:", {"epoch": epoch_col, "step": step_col, "recon": recon_col, "kl": kl_col})

# ---------- filter & exclude epoch 1 ----------
# If there are per-split columns (e.g., 'train/recon' and 'val/recon') the 'train' preference above should have chosen them.
# Otherwise we're plotting whatever best matches 'recon' and 'kl'.
if epoch_col is not None:
    df = df[df[epoch_col] > 1].copy()
else:
    # no epoch info → drop first 5% as warm-up
    df = df.iloc[int(0.05 * len(df)) : ].copy()

# drop rows where metrics are missing
df = df.dropna(subset=[c for c in [recon_col, kl_col] if c]).copy()

# ---------- smoothing ----------
def moving_avg(v, w):
    v = pd.Series(v)
    return v.rolling(window=w, min_periods=max(1, w//4)).mean()

win = max(50, len(df)//100)  # ~1% of length, at least 50
recon_ma = moving_avg(df[recon_col], win) if recon_col else None
kl_ma    = moving_avg(df[kl_col], win)    if kl_col    else None

# ---------- plot ----------
plt.figure(figsize=(12,5))
if recon_col:
    plt.plot(df[step_col], df[recon_col], color="#1f77b4", alpha=0.20, lw=1, label="Reconstruction (raw)")
    plt.plot(df[step_col], recon_ma,      color="#1f77b4", alpha=0.95, lw=2.0, label=f"Reconstruction (MA, w={win})")
if kl_col:
    plt.plot(df[step_col], df[kl_col],    color="#ff7f0e", alpha=0.15, lw=1, label="KL (raw)")
    plt.plot(df[step_col], kl_ma,         color="#ff7f0e", alpha=0.95, lw=2.0, label=f"KL (MA, w={win})")

plt.title("[alpha=inf]  Reconstruction & KL over training (excluding first epoch)")
plt.xlabel((step_col or "step").split("/")[-1].replace("_"," ").title())
plt.ylabel("Loss / Value")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()

out_png = HIST_PATH.with_name("history_recon_kl_no_epoch0.png")
plt.savefig(out_png, dpi=300, bbox_inches="tight")
print(f"[saved] {out_png}")
plt.show()
# Out:
# Detected columns: {'epoch': None, 'step': '__step__', 'recon': None, 'kl': 'kl_terms'}
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history_recon_kl_no_epoch0.png

# %%
# === Plot from history.pkl using rec_errors (recon) and kl_terms (KL) ===
import pickle, numpy as np, pandas as pd, matplotlib.pyplot as plt
from pathlib import Path

HIST_PATH = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history.pkl")
assert HIST_PATH.exists(), f"Not found: {HIST_PATH}"

with open(HIST_PATH, "rb") as f:
    hist = pickle.load(f)

# Extract the two sequences
recon = np.asarray(hist["rec_errors"], dtype=float)
kl    = np.asarray(hist["kl_terms"],   dtype=float)
assert recon.shape == kl.shape and recon.ndim == 1, "Unexpected shapes in history.pkl"

N = len(recon)
steps = np.arange(1, N+1, dtype=int)

# Exclude warm-up since we don't have epoch markers (drop first 5%, cap)
drop_n = max(50, int(0.05 * N))   # at least 50 points
keep_slice = slice(drop_n, None)
steps, recon, kl = steps[keep_slice], recon[keep_slice], kl[keep_slice]

# Moving average window (~1% of retained points, at least 50)
win = max(50, len(steps)//100)

def moving_avg(a, w):
    s = pd.Series(a)
    return s.rolling(window=w, min_periods=max(1, w//4)).mean().to_numpy()

recon_ma = moving_avg(recon, win)
kl_ma    = moving_avg(kl,    win)

# --- Plot ---
plt.figure(figsize=(12,5))
plt.plot(steps, recon,   color="#1f77b4", alpha=0.18, lw=1, label="Reconstruction (raw)")
plt.plot(steps, recon_ma,color="#1f77b4", alpha=0.95, lw=2.2, label=f"Reconstruction (MA, w={win})")
plt.plot(steps, kl,      color="#ff7f0e", alpha=0.15, lw=1, label="KL (raw)")
plt.plot(steps, kl_ma,   color="#ff7f0e", alpha=0.95, lw=2.2, label=f"KL (MA, w={win})")

plt.title("[alpha=inf] Reconstruction & KL over training (excluding warm-up)")
plt.xlabel("Step")
plt.ylabel("Loss / Value")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()

out_png = HIST_PATH.with_name("history_rec_kl_excl_warmup.png")
plt.savefig(out_png, dpi=300, bbox_inches="tight")
print(f"[saved] {out_png}")
plt.show()
# Out:
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history_rec_kl_excl_warmup.png

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# === Load history ===
with open("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history.pkl", "rb") as f:
    history = pickle.load(f)

# Extract values
recon = history["rec_errors"]
kl = history["kl_terms"]
x = np.arange(len(recon))

# === Moving average helper ===
def moving_average(data, window_size=50):
    if len(data) < window_size:
        return np.array([])
    return np.convolve(data, np.ones(window_size) / window_size, mode='valid')

# Apply moving average
recon_ma = moving_average(recon)
kl_ma = moving_average(kl)
x_ma = x[:len(recon_ma)]

# === Plot ===
fig, ax1 = plt.subplots(figsize=(10, 4.8), dpi=120)

color_recon = "tab:blue"
color_kl = "tab:orange"

ax1.set_title("[alpha=inf] Per-batch Reconstruction & KL (MA-smoothed)")
ax1.set_xlabel("Training step (batches)")
ax1.set_ylabel("Reconstruction loss", color=color_recon)
ax1.plot(x_ma, recon_ma, color=color_recon, label="Recon (MA)", lw=2)
ax1.tick_params(axis="y", labelcolor=color_recon)
ax1.grid(alpha=0.3)


ax2 = ax1.twinx()
ax2.set_ylabel("KL divergence", color=color_kl)
ax2.plot(x_ma, kl_ma, color=color_kl, label="KL (MA)", lw=2)
ax2.tick_params(axis="y", labelcolor=color_kl)

# Combine legends
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, frameon=False)
ax1.legend(
    lines1 + lines2, labels1 + labels2,
    frameon=False,
    loc="center right"  # ⬅ change location here
)

plt.tight_layout()
plt.show()

# %%
import pickle
import numpy as np
import pandas as pd
from pathlib import Path
from IPython.display import display

# === Load history ===
history_path = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history.pkl")
with open(history_path, "rb") as f:
    history = pickle.load(f)

# === Extract what is available ===
val_iwae = np.array(history.get("validation_iwae", []), dtype=float)
kl_terms = np.array(history.get("kl_terms", []), dtype=float)
n_epochs = len(val_iwae)
steps_per_epoch = int(len(kl_terms) / n_epochs) if n_epochs > 0 else 1

# === Calculate KL per epoch ===
kl_mean_per_epoch = [
    kl_terms[i * steps_per_epoch : (i + 1) * steps_per_epoch].mean()
    for i in range(n_epochs)
] if steps_per_epoch > 0 else []

# === Build main summary table ===
summary_df = pd.DataFrame({
    "Epoch": np.arange(1, n_epochs + 1),
    "Validation IWAE": val_iwae,
    "KL (avg)": kl_mean_per_epoch,
})

# === Select representative epochs (optional) ===
key_epochs = [1, 2, 5, 10, 20, 40, 60, 80, 100, n_epochs]
key_epochs = sorted(set(e for e in key_epochs if 1 <= e <= n_epochs))
summary_df_filtered = summary_df[summary_df["Epoch"].isin(key_epochs)].copy()

# === Add interpretive notes ===
def interpret_row_rich(row):
    iwae = row["Validation IWAE"]
    kl = row["KL (avg)"]

    if kl > 100_000:
        return "Extreme KL dominance — latent space collapsed, decoder likely ignoring prior"
    elif kl > 5000:
        return "Very high KL — unstable latent usage, likely decoder learns identity function"
    elif kl > 500:
        return "KL shrinking — slight latent usage, α likely too strong"
    elif kl > 100:
        return "KL moderately high — beginning latent activity, but decoder likely still dominant"
    elif kl > 50:
        return "KL stabilizing — decoder and latent space interaction emerging"
    elif kl > 35:
        return "Reasonable KL — informative latent codes start influencing generation"
    elif kl > 25:
        return "KL plateaued — latent variables consistently used, good posterior-prior match"
    elif kl > 10:
        return "Low KL — some risk of posterior collapse or too strong reconstruction focus"
    else:
        return "Very low KL — latent variables likely underutilized, decoder memorization suspected"

summary_df_filtered["Notes"] = summary_df_filtered.apply(interpret_row_rich, axis=1)

# === Display nicely ===
display(summary_df_filtered)
# Out:
#      Epoch  Validation IWAE       KL (avg)  \
# 0        1    -3.527473e+06  886561.935690
# 1        2    -3.322634e+04     265.103355
# 4        5    -2.925212e+04     127.867797
# 9       10    -2.768941e+04      73.718709
# 19      20    -2.621711e+04      41.061336
# 39      40    -2.596113e+04      17.981462
# 59      60    -2.552967e+04       8.443358
# 79      80    -2.462947e+04       3.723376
# 99     100    -2.509444e+04       1.580992
# 125    126    -2.395026e+04       0.491732
#
#                                                  Notes
# 0    Extreme KL dominance — latent space collapsed,...
# 1    KL moderately high — beginning latent activity...
# 4    KL moderately high — beginning latent activity...
# 9    KL stabilizing — decoder and latent space inte...
# 19   Reasonable KL — informative latent codes start...
# 39   Low KL — some risk of posterior collapse or to...
# 59   Very low KL — latent variables likely underuti...
# 79   Very low KL — latent variables likely underuti...
# 99   Very low KL — latent variables likely underuti...
# 125  Very low KL — latent variables likely underuti...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pickle
from pathlib import Path

# --- Load history.pkl ---
hist_path = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history.pkl")
with open(hist_path, "rb") as f:
    hist = pickle.load(f)

# Convert to dataframe
df = pd.DataFrame({
    "step": range(len(hist["rec_errors"])),
    "recon": hist["rec_errors"],
    "kl": hist["kl_terms"],
})

# Exclude first epoch (≈117 steps per epoch)
steps_per_epoch = len(hist["rec_errors"]) // len(hist["validation_iwae"])
df = df[df["step"] >= steps_per_epoch]

# Moving averages
def moving_avg(x, w=139):
    return pd.Series(x).rolling(window=w, min_periods=1).mean()

df["recon_ma"] = moving_avg(df["recon"])
df["kl_ma"] = moving_avg(df["kl"])

# --- Plot ---
fig, axes = plt.subplots(2, 1, figsize=(12, 6), sharex=True)

# Recon panel
axes[0].plot(df["step"], df["recon"], color="skyblue", alpha=0.3, label="Reconstruction (raw)")
axes[0].plot(df["step"], df["recon_ma"], color="blue", label="Reconstruction (MA, w=139)")
axes[0].set_ylabel("Recon Loss")
axes[0].set_title("[alpha=inf]  Reconstruction Loss over training (excl. epoch 0)")
axes[0].legend()

# KL panel
axes[1].plot(df["step"], df["kl"], color="orange", alpha=0.3, label="KL (raw)")
axes[1].plot(df["step"], df["kl_ma"], color="darkorange", label="KL (MA, w=139)")
axes[1].set_ylabel("KL Divergence")
axes[1].set_xlabel("Step")
axes[1].set_title("[alpha=inf]  KL Divergence over training (excl. epoch 0)")
axes[1].legend()

plt.tight_layout()
out = hist_path.parent / "history_recon_kl_split.png"
plt.savefig(out, dpi=150)
plt.show()

print(f"[saved] {out}")
# Out:
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history_recon_kl_split.png

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pickle
from pathlib import Path

# --- Load history.pkl ---
hist_path = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history.pkl")
with open(hist_path, "rb") as f:
    hist = pickle.load(f)

# Convert to dataframe
df = pd.DataFrame({
    "step": range(len(hist["rec_errors"])),
    "recon": hist["rec_errors"],
    "kl": hist["kl_terms"],
})

# Exclude first epoch (≈117 steps per epoch)
steps_per_epoch = len(hist["rec_errors"]) // len(hist["validation_iwae"])
df = df[df["step"] >= steps_per_epoch]

# Moving averages
def moving_avg(x, w=139):
    return pd.Series(x).rolling(window=w, min_periods=1).mean()

df["recon_ma"] = moving_avg(df["recon"])
df["kl_ma"] = moving_avg(df["kl"])

# --- Plot (linear + log scale for Recon) ---
fig, axes = plt.subplots(3, 1, figsize=(12, 9), sharex=True)

# Recon panel (linear)
axes[0].plot(df["step"], df["recon"], color="skyblue", alpha=0.3, label="Reconstruction (raw)")
axes[0].plot(df["step"], df["recon_ma"], color="blue", label="Reconstruction (MA, w=139)")
axes[0].set_ylabel("Recon Loss")
axes[0].set_title("[alpha=inf]  Reconstruction Loss (linear, excl. epoch 0)")
axes[0].legend()

# Recon panel (log)
axes[1].plot(df["step"], df["recon"], color="skyblue", alpha=0.3, label="Reconstruction (raw)")
axes[1].plot(df["step"], df["recon_ma"], color="blue", label="Reconstruction (MA, w=139)")
axes[1].set_ylabel("Recon Loss (log)")
axes[1].set_yscale("log")
axes[1].set_title("[alpha=inf]  Reconstruction Loss (log-scale, excl. epoch 0)")
axes[1].legend()

# KL panel
axes[2].plot(df["step"], df["kl"], color="orange", alpha=0.3, label="KL (raw)")
axes[2].plot(df["step"], df["kl_ma"], color="darkorange", label="KL (MA, w=139)")
axes[2].set_ylabel("KL Divergence")
axes[2].set_xlabel("Step")
axes[2].set_title("[alpha=inf]  KL Divergence (excl. epoch 0)")
axes[2].legend()

plt.tight_layout()
out = hist_path.parent / "history_recon_kl_split_log.png"
plt.savefig(out, dpi=150)
plt.show()

print(f"[saved] {out}")
# Out:
# /tmp/ipython-input-1996648405.py:43: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   axes[1].set_yscale("log")
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history_recon_kl_split_log.png

# %%
# === Pairwise "vs" plots from history.pkl (per-epoch, normalized, excl. epoch 1) ===
import pickle, numpy as np, pandas as pd, matplotlib.pyplot as plt
from pathlib import Path
from matplotlib.ticker import MaxNLocator

PKL = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history.pkl")

with open(PKL, "rb") as f:
    H = pickle.load(f)

# Raw series you told me exist in the pickle
val_iwae = np.asarray(H["validation_iwae"], dtype=float)   # per checkpoint (epoch)
train_vlb = np.asarray(H["train_vlb"], dtype=float)        # per checkpoint (epoch)
recon = np.asarray(H["rec_errors"], dtype=float)           # per batch
kl    = np.asarray(H["kl_terms"],   dtype=float)           # per batch

# ----- convert per-batch (recon/kl) to per-epoch means -----
n_epochs = len(val_iwae)
steps_per_epoch = int(round(len(recon) / n_epochs))
recon_ep = []
kl_ep = []
for e in range(n_epochs):
    s, t = e*steps_per_epoch, (e+1)*steps_per_epoch
    recon_ep.append(np.nanmean(recon[s:t]))
    kl_ep.append(np.nanmean(kl[s:t]))
recon_ep = np.asarray(recon_ep)
kl_ep    = np.asarray(kl_ep)

# ----- exclude first epoch -----
mask = np.arange(n_epochs) > 0
E = np.arange(n_epochs)[mask]
V = {
    "Validation IWAE": val_iwae[mask],
    "Train VLB":       train_vlb[mask],
    "Recon (mean/epoch)": recon_ep[mask],
    "KL (mean/epoch)":    kl_ep[mask],
}

# ----- normalize to comparable units (z-score by default) -----
def zscore(x):
    m, s = np.nanmean(x), np.nanstd(x)
    return (x - m) / (s + 1e-12)

Vz = {k: zscore(v) for k, v in V.items()}

# ----- pairs to plot (you can add more) -----
pairs = [
    ("Train VLB", "Validation IWAE"),
    ("Recon (mean/epoch)", "KL (mean/epoch)"),
    ("Recon (mean/epoch)", "Train VLB"),
    ("KL (mean/epoch)", "Train VLB"),
    ("Recon (mean/epoch)", "Validation IWAE"),
    ("KL (mean/epoch)", "Validation IWAE"),
]

# ----- plot grid -----
ncols = 3
nrows = int(np.ceil(len(pairs)/ncols))
fig, axes = plt.subplots(nrows, ncols, figsize=(15, 10))
axes = axes.ravel()

for ax, (xk, yk) in zip(axes, pairs):
    x, y = Vz[xk], Vz[yk]

    # Regression line
    A = np.vstack([x, np.ones_like(x)]).T
    w, b = np.linalg.lstsq(A, y, rcond=None)[0]  # y ≈ w*x + b
    xr = np.linspace(x.min(), x.max(), 200)
    yr = w*xr + b

    r = np.corrcoef(x, y)[0,1]
    ax.scatter(x, y, s=25, alpha=0.6, edgecolors="none")
    ax.plot(xr, yr, lw=2, alpha=0.8)
    ax.set_title(f"{xk} vs {yk}\n$r$ = {r:.3f}", fontsize=11)
    ax.set_xlabel(f"{xk}  (z-score)")
    ax.set_ylabel(f"{yk}  (z-score)")
    ax.grid(alpha=0.25)

# turn off any leftover empty axes
for i in range(len(pairs), len(axes)):
    axes[i].axis("off")

plt.suptitle("[alpha = inf] Pairwise metric comparisons (per-epoch, z-scored, excluding epoch 1)")
plt.tight_layout()
OUT = PKL.with_name("pairwise_vs_from_pkl_zscore.png")
plt.savefig(OUT, dpi=300, bbox_inches="tight")
plt.show()
print(f"[saved] {OUT}")
# Out:
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/pairwise_vs_from_pkl_zscore.png

# %%
# ========= THESIS PLOTS (RAW VALUES) =========
# Adjust these if your layout differs
from pathlib import Path
import pickle, numpy as np
import matplotlib.pyplot as plt

ROOT    = Path("/content/VAEAC_Thesis")
RUN_DIR = ROOT / "celeba_model/alpha_runs/alpha_inf"
PKL     = RUN_DIR / "history.pkl"

# If your images are 128x128x3, leave as is. Otherwise change.
IMG_DIMS = (3, 128, 128)   # (C, H, W)
D = int(np.prod(IMG_DIMS)) # pixels×channels -> for "per-dimension" scaling

# ---------- helpers ----------
def movavg(x, w):
    if w <= 1: return x
    k = int(w)
    pad = np.r_[np.full(k-1, x[0]), x]
    c = np.convolve(pad, np.ones(k)/k, mode="valid")
    return c[:len(x)]

def savefig(fig, path):
    path.parent.mkdir(parents=True, exist_ok=True)
    fig.savefig(path, dpi=300, bbox_inches="tight")
    print("[saved]", path)

# ---------- load ----------
with open(PKL, "rb") as f:
    H = pickle.load(f)

# Available series we rely on
val_iwae = np.asarray(H["validation_iwae"], dtype=float)     # per epoch
train_vlb = np.asarray(H["train_vlb"],   dtype=float)         # per epoch
rec_errors = np.asarray(H["rec_errors"], dtype=float)         # per batch
kl_terms   = np.asarray(H["kl_terms"],   dtype=float)         # per batch

n_epochs = len(val_iwae)
steps_total = len(rec_errors)
steps_per_epoch = int(round(steps_total / n_epochs))

# Aggregate per-epoch mean for recon & KL from the per-batch traces
recon_ep = []
kl_ep    = []
for e in range(n_epochs):
    s, t = e*steps_per_epoch, min((e+1)*steps_per_epoch, steps_total)
    recon_ep.append(np.nanmean(rec_errors[s:t]))
    kl_ep.append(np.nanmean(kl_terms[s:t]))
recon_ep = np.asarray(recon_ep)
kl_ep    = np.asarray(kl_ep)

# Indices
ep = np.arange(1, n_epochs+1)   # 1..N
mask_excl1 = ep > 1
ep_ex = ep[mask_excl1]

# 1) VLB / IWAE (×1e-3) excluding epoch 1
fig, ax = plt.subplots(figsize=(8.5, 4))
ax.plot(ep_ex, train_vlb[mask_excl1]/1e3, lw=2.0, alpha=.9, label="Train VLB (raw) /1e3")
ax.plot(ep_ex, val_iwae[mask_excl1]/1e3,  lw=2.0, alpha=.9, label="Validation IWAE (raw) /1e3")
ax.set_title("[alpha=inf]  Per-epoch objectives (excluding epoch 1)")
ax.set_xlabel("Checkpoint (epoch)"); ax.set_ylabel("Objective (×1e3)")
ax.grid(alpha=.25); ax.legend(ncol=2, frameon=False)
savefig(fig, RUN_DIR / "loss_curves_objectives_excl_epoch1_thousands.png"); plt.close(fig)

# 2) Same per pixel/channel (divide by D) excluding epoch 1
fig, ax = plt.subplots(figsize=(8.5, 4))
ax.plot(ep_ex, train_vlb[mask_excl1]/D, lw=2.0, alpha=.9, label="Train VLB (raw) / dim")
ax.plot(ep_ex, val_iwae[mask_excl1]/D,  lw=2.0, alpha=.9, label="Validation IWAE (raw) / dim")
ax.set_title("[alpha=inf]  Per-epoch objectives per pixel/channel (excluding epoch 1)")
ax.set_xlabel("Checkpoint (epoch)"); ax.set_ylabel("Objective (nats / dimension)")
ax.grid(alpha=.25); ax.legend(ncol=2, frameon=False)
savefig(fig, RUN_DIR / "loss_curves_objectives_per_dim_excl_epoch1.png"); plt.close(fig)

# 3) Recon vs KL per epoch (raw & per-dim), excluding epoch 1
fig, axs = plt.subplots(2, 1, figsize=(8.5, 7), sharex=True)
axs[0].plot(ep_ex, recon_ep[mask_excl1], lw=2, label="Reconstruction (mean/epoch, raw)")
axs[0].plot(ep_ex, kl_ep[mask_excl1],    lw=2, label="KL (mean/epoch, raw)")
axs[0].set_ylabel("Value (raw)"); axs[0].legend(frameon=False); axs[0].grid(alpha=.25)

axs[1].plot(ep_ex, recon_ep[mask_excl1]/D, lw=2, label="Reconstruction / dim")
axs[1].plot(ep_ex, kl_ep[mask_excl1]/D,    lw=2, label="KL / dim")
axs[1].set_xlabel("Checkpoint (epoch)"); axs[1].set_ylabel("Value (per dimension)")
axs[1].legend(frameon=False); axs[1].grid(alpha=.25)

fig.suptitle("[alpha=inf]  Reconstruction & KL per epoch (excluding epoch 1)")
savefig(fig, RUN_DIR / "recon_kl_per_epoch_excl_epoch1.png"); plt.close(fig)

# 4) Per-batch traces (smoothed), full training; show epoch boundaries
MA_BATCH = 139  # set to your typical steps_per_epoch if you want ~1-epoch smoothing
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(movavg(rec_errors, MA_BATCH), lw=1.8, label=f"Recon (per-batch, MA={MA_BATCH})")
ax.plot(movavg(kl_terms,   MA_BATCH), lw=1.8, label=f"KL (per-batch, MA={MA_BATCH})")
# epoch markers
for e in range(1, n_epochs):
    ax.axvline(e*steps_per_epoch, color='k', alpha=.07, lw=1)
ax.set_title("[alpha=inf]  Per-batch reconstruction & KL (smoothed)")
ax.set_xlabel("Training step (batches)"); ax.set_ylabel("Value")
ax.legend(ncol=2, frameon=False); ax.grid(alpha=.25)
savefig(fig, RUN_DIR / "recon_kl_per_batch_smoothed.png"); plt.close(fig)

# 5) Learnable alpha over epochs (if latents_epoch_*_alphas.npz exist)
alpha_files = sorted(RUN_DIR.glob("latents_epoch_*_alphas.npz"),
                     key=lambda p: int(''.join(filter(str.isdigit, p.stem))))
if alpha_files:
    means, mins, maxs, eidx = [], [], [], []
    for f in alpha_files:
        data = np.load(f)
        # try common keys; fall back to first array
        arr = None
        for k in ["alphas", "alpha", "raw_alpha"]:
            if k in data.files:
                arr = data[k]; break
        if arr is None:
            # take first array in file
            arr = data[list(data.files)[0]]
        arr = np.asarray(arr, dtype=float)
        means.append(np.nanmean(arr))
        mins.append(np.nanmin(arr))
        maxs.append(np.nanmax(arr))
        # epoch index from filename:
        e = int(''.join(filter(str.isdigit, f.stem)))
        eidx.append(e)
    means, mins, maxs, eidx = map(np.asarray, (means, mins, maxs, eidx))

    # exclude epoch 1 if present
    m = eidx > 1
    fig, ax = plt.subplots(figsize=(8.5, 4))
    ax.plot(eidx[m], means[m], lw=2.2, label="mean(α)")
    ax.fill_between(eidx[m], mins[m], maxs[m], alpha=.15, label="min/max(α)")
    ax.set_title("[alpha=inf]  α parameter over epochs (excluding epoch 1)")
    ax.set_xlabel("Checkpoint (epoch)"); ax.set_ylabel("Alpha")
    ax.grid(alpha=.25); ax.legend(frameon=False)
    savefig(fig, RUN_DIR / "alpha_learned_over_epochs.png"); plt.close(fig)
else:
    print("[info] No latents_epoch_*_alphas.npz files found — skipped α plot.")
# Out:
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/loss_curves_objectives_excl_epoch1_thousands.png
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/loss_curves_objectives_per_dim_excl_epoch1.png
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/recon_kl_per_epoch_excl_epoch1.png
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/recon_kl_per_batch_smoothed.png
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/alpha_learned_over_epochs.png

# %%
from pathlib import Path
from PIL import Image
from IPython.display import display

paths = [
    "/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/loss_curves_objectives_excl_epoch1_thousands.png",
    "/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/loss_curves_objectives_per_dim_excl_epoch1.png",
    "/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/recon_kl_per_epoch_excl_epoch1.png",
    "/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/recon_kl_per_batch_smoothed.png",
    "/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/alpha_learned_over_epochs.png",
]

for p in paths:
    p = Path(p)
    if p.exists():
        print(p)
        display(Image.open(p))
    else:
        print(f"[missing] {p}")
# Out:
# /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/loss_curves_objectives_excl_epoch1_thousands.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2155x1156>
# /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/loss_curves_objectives_per_dim_excl_epoch1.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2212x1156>
# /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/recon_kl_per_epoch_excl_epoch1.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2247x1998>
# /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/recon_kl_per_batch_smoothed.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2514x1156>
# /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/alpha_learned_over_epochs.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2178x1156>

# %%
# --- BEAUTIFIED α vs. epochs (labels only on majors, dense unlabeled minor grid) ---
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter, NullFormatter
from pathlib import Path

# assumes epochs, means, mins, maxs already computed as in your previous cell
# (if not, run the loading code we used before, then run this block)

fig, ax = plt.subplots(figsize=(9.5, 5.2), dpi=120)

# main line + band
ax.plot(epochs, means, lw=2.6, color="#1f77b4", label="mean(α)")
ax.fill_between(epochs, mins, maxs, color="#1f77b4", alpha=0.18, label="min/max(α)")

ax.set_title("[alpha=inf]  α parameter over epochs (sigmoid, excluding epoch 1)", pad=10)
ax.set_xlabel("Checkpoint (epoch)")
ax.set_ylabel("Alpha (0–1)")
ax.set_ylim(0, 1)

# --- ticks & grid: clean majors, dense minor grid, no minor labels ---
# Choose one of these depending on how dense you want it:

MAJOR = 0.05   # labeled ticks every 0.05
MINOR = 0.005  # thin, unlabeled gridlines every 0.005 (set to 0.001 if you really want)

ax.yaxis.set_major_locator(MultipleLocator(MAJOR))
ax.yaxis.set_major_formatter(FormatStrFormatter("%.2f"))
ax.yaxis.set_minor_locator(MultipleLocator(MINOR))
ax.yaxis.set_minor_formatter(NullFormatter())        # <-- hide minor tick labels

# grid appearance
ax.grid(True, which="major", axis="both", alpha=0.35, linewidth=1.0)
ax.grid(True, which="minor", axis="y", alpha=0.15, linewidth=0.6)

# x ticks: at most ~10 labels to avoid clutter
xticks = np.linspace(epochs.min(), epochs.max(), num=min(10, len(epochs))).round().astype(int)
ax.set_xticks(sorted(set(xticks)))

# legend & layout
ax.legend(frameon=False)
fig.tight_layout()

out = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/alpha_learned_over_epochs_clean.png")
fig.savefig(out, dpi=300, bbox_inches="tight")
plt.show()
print(f"[saved] {out}")
# Out:
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/alpha_learned_over_epochs_clean.png

# %%
# === Simple α evolution plot: dots connected across epochs ===
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# assumes `epochs` (array of epoch numbers) and `means` (mean alpha per epoch, already sigmoid-scaled)
# from your NPZ loading cell earlier

fig, ax = plt.subplots(figsize=(8, 4.5), dpi=120)

# plot connected dots
ax.plot(epochs, means, marker="o", markersize=5, lw=1.8, color="#1f77b4", label="mean(α)")

# annotate optional: each dot with its value (small, rotated)
for e, m in zip(epochs, means):
    ax.text(e, m + 0.01, f"{m:.3f}", ha="center", va="bottom", fontsize=7, rotation=45)

# labels & limits
ax.set_title("[alpha=inf]  α parameter over epochs (sigmoid, excluding epoch 1)", pad=10)
ax.set_xlabel("Checkpoint (epoch)")
ax.set_ylabel("Alpha (0–1)")
ax.set_ylim(0, 1)

# clean grid
ax.grid(alpha=0.3, linestyle="--", linewidth=0.8)

# ticks: only major ticks, no clutter
ax.set_xticks(epochs[::max(1, len(epochs)//10)])  # ~10 x ticks max

ax.legend(frameon=False)
fig.tight_layout()

out = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/alpha_dots_connected.png")
fig.savefig(out, dpi=300, bbox_inches="tight")
plt.show()
print(f"[saved] {out}")
# Out:
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/alpha_dots_connected.png

# %%
# === Per-batch reconstruction & KL, smoothed, skipping the first batches ===
import pickle, numpy as np, matplotlib.pyplot as plt
from pathlib import Path

PKL = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history.pkl")

# --- config ---
SKIP_FIRST_EPOCHS = 1        # set to 0 to keep everything, or >1 to skip more epochs
SKIP_FIRST_STEPS  = None     # or set an explicit number of batches to skip (overrides epochs if not None)
MA_FRAC_PER_EPOCH = 0.25     # moving-average window as fraction of steps/epoch (e.g., 0.25 → ~1/4 epoch)
SAVE_NAME = "recon_kl_per_batch_smoothed_skip.png"

# --- load ---
with open(PKL, "rb") as f:
    H = pickle.load(f)

recon = np.asarray(H["rec_errors"], dtype=float)   # per batch
kl    = np.asarray(H["kl_terms"],   dtype=float)   # per batch
n_ckp = len(H["validation_iwae"])                  # epochs/checkpoints
steps_per_epoch = int(round(len(recon) / n_ckp))

# --- how many batches to skip? ---
if SKIP_FIRST_STEPS is None:
    start = int(SKIP_FIRST_EPOCHS * steps_per_epoch)
else:
    start = int(SKIP_FIRST_STEPS)
start = max(0, min(start, len(recon)-1))

# --- simple moving average (centered-ish) ---
def moving_average(x, w):
    w = max(1, int(w))
    if w == 1: return x.copy()
    c = np.convolve(x, np.ones(w, dtype=float)/w, mode="valid")
    pad = (w-1)//2
    # pad to original length (keep edges constant)
    return np.pad(c, (pad, len(x)-len(c)-pad), mode="edge")

W = max(5, int(MA_FRAC_PER_EPOCH * steps_per_epoch))

# apply smoothing, then drop the first 'start' steps
recon_ma = moving_average(recon, W)[start:]
kl_ma    = moving_average(kl,    W)[start:]
x        = np.arange(start, start + len(recon_ma))  # batch index

# --- plot ---
plt.figure(figsize=(10, 4.8), dpi=120)
plt.plot(x, recon_ma, label=f"Recon (per-batch, MA={W})", lw=2)
plt.plot(x, kl_ma,    label=f"KL (per-batch, MA={W})",    lw=2)

plt.title("[alpha=inf]  Per-batch reconstruction & KL (smoothed, first batches skipped)")
plt.xlabel("Training step (batches)")
plt.ylabel("Value")
plt.grid(alpha=0.25)
plt.legend(frameon=False)
plt.tight_layout()

out = PKL.with_name(SAVE_NAME)
plt.savefig(out, dpi=300, bbox_inches="tight")
plt.show()
print(f"[saved] {out}")
# Out:
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/recon_kl_per_batch_smoothed_skip.png

# %%
# === Per-epoch objectives (/dimension), skipping early epochs ===
import pickle, numpy as np, matplotlib.pyplot as plt
from pathlib import Path

PKL = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/history.pkl")

# ---- config ----
SKIP_FIRST_EPOCHS = 3        # hide the first N epochs (try 1–5)
DIMS = 3 * 128 * 128         # channels * H * W  (change if your data shape differs)
MA_WINDOW = 5                # moving-average window in epochs (0 or 1 -> no smoothing)
SAVE_NAME = "loss_curves_objectives_per_dim_excl_early.png"

# ---- load ----
with open(PKL, "rb") as f:
    H = pickle.load(f)

val_iwae = np.asarray(H["validation_iwae"], dtype=float)   # per epoch
train_vlb = np.asarray(H["train_vlb"],      dtype=float)   # per epoch

# exclude the first N epochs
start = max(0, min(SKIP_FIRST_EPOCHS, len(val_iwae)-1))
ep = np.arange(len(val_iwae))[start:]
val_iwae = val_iwae[start:]
train_vlb = train_vlb[start:]

# per-pixel/channel (nats / dimension)
val_iwae_dim = val_iwae / float(DIMS)
train_vlb_dim = train_vlb / float(DIMS)

# optional smoothing over epochs
def ma(x, w):
    w = int(w)
    if w <= 1: return x
    c = np.convolve(x, np.ones(w)/w, mode="valid")
    pad = (w-1)//2
    return np.pad(c, (pad, len(x)-len(c)-pad), mode="edge")

val_iwae_dim_sm = ma(val_iwae_dim, MA_WINDOW)
train_vlb_dim_sm = ma(train_vlb_dim, MA_WINDOW)

# ---- plot ----
plt.figure(figsize=(10, 5), dpi=120)
plt.plot(ep, train_vlb_dim_sm, label=f"Train VLB (raw) / dim" + (f" (MA={MA_WINDOW})" if MA_WINDOW>1 else ""), lw=2)
plt.plot(ep, val_iwae_dim_sm, label=f"Validation IWAE (raw) / dim" + (f" (MA={MA_WINDOW})" if MA_WINDOW>1 else ""), lw=2)

plt.title("[alpha=inf]  Per-epoch objectives per pixel/channel (excluding early epochs)")
plt.xlabel("Checkpoint (epoch)")
plt.ylabel("Objective (nats / dimension)")
plt.grid(alpha=0.25)
plt.legend(frameon=False)
plt.tight_layout()

out = PKL.with_name(SAVE_NAME)
plt.savefig(out, dpi=300, bbox_inches="tight")
plt.show()
print(f"[saved] {out}")
# Out:
# [saved] /content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/loss_curves_objectives_per_dim_excl_early.png

# %%
from sklearn.preprocessing import StandardScaler

latents_norm = StandardScaler().fit_transform(latents)
embedding = reducer.fit_transform(latents_norm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4141945038.py in <cell line: 0>()
#       1 from sklearn.preprocessing import StandardScaler
#       2
# ----> 3 latents_norm = StandardScaler().fit_transform(latents)
#       4 embedding = reducer.fit_transform(latents_norm)
#
# NameError: name 'latents' is not defined

# %%
# === UMAP Visualization of Latent Means (fixed for 'latents' key) ===
import numpy as np
import matplotlib.pyplot as plt
import umap
from pathlib import Path

# Path to your stored latent codes (choose the right epoch file)
npz_file = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/latents_epoch_25_alphas.npz")

# Load latent codes
data = np.load(npz_file)
print("Keys in NPZ:", data.keys())  # should show ['latents']

# Extract latents
latents = data["latents"]
print("Latents shape:", latents.shape)

# Flatten if shape is (N, D, 1, 1) → (N, D)
latents = latents.reshape(latents.shape[0], -1)

# UMAP projection
reducer = umap.UMAP(n_neighbors=30, min_dist=0.1, random_state=42)
embedding = reducer.fit_transform(latents)

# Plot
plt.figure(figsize=(8,6))
plt.scatter(embedding[:,0], embedding[:,1], s=20, alpha=0.7)
plt.title("UMAP of Latent Means (q(z|x,mask))")
plt.xlabel("UMAP dim 1")
plt.ylabel("UMAP dim 2")
plt.grid(alpha=0.3)
plt.show()
# Out:
# Keys in NPZ: KeysView(NpzFile '/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/latents_epoch_25_alphas.npz' with keys: latents)
# Latents shape: (128, 256)
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
file = base_dir / "latents_epoch_1_alphas.npz"
data = np.load(file)
print(f"Keys in {file.name}:", data.files)
# Out:
# Keys in latents_epoch_1_alphas.npz: ['latents']

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from scipy import stats

# --- Path to folder ---
base_dir = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf")

# --- Load all latent vectors ---
all_latents = []

for file in sorted(base_dir.glob("latents_epoch_*_alphas.npz")):
    data = np.load(file)
    latents = data["latents"]  # shape: [batch_size, latent_dim]
    all_latents.append(latents)

# --- Concatenate all z ---
Z = np.concatenate(all_latents, axis=0)  # shape: [N, latent_dim]
Z_flat = Z.flatten()

print(f"Total samples: {Z.shape[0]}, latent dim: {Z.shape[1]}, flattened: {Z_flat.shape}")

# --- Reference Normal samples for comparison ---
Z_ref = np.random.normal(0, 1, size=Z_flat.shape)

# === PLOT 1: KDE comparison ===
plt.figure(figsize=(10, 5))
sns.kdeplot(Z_flat, label="q(z|x)", linewidth=2)
sns.kdeplot(Z_ref, label="p(z) = N(0,1)", linestyle="--")
plt.title("Kernel Density Estimate: q(z|x) vs p(z)")
plt.xlabel("Latent value")
plt.ylabel("Density")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# === PLOT 2: Histogram overlay ===
plt.figure(figsize=(10, 5))
plt.hist(Z_flat, bins=100, density=True, alpha=0.6, label="q(z|x)")
plt.hist(Z_ref, bins=100, density=True, alpha=0.4, label="p(z)")
plt.title("Histogram: q(z|x) vs p(z)")
plt.xlabel("Latent value")
plt.ylabel("Density")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# === PLOT 3: Q–Q Plot ===
plt.figure(figsize=(6, 6))
stats.probplot(Z_flat, dist="norm", plot=plt)
plt.title("Q–Q plot of q(z|x) vs Normal(0,1)")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Total samples: 3200, latent dim: 256, flattened: (819200,)

# %%
from pathlib import Path

latent_dir = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/")
latent_files = sorted(latent_dir.glob("latents_epoch_*_alphas.npz"))

print(f"✅ Found {len(latent_files)} latent files")
print("🔹 First 3 files:", [f.name for f in latent_files[:3]])

import numpy as np

# Load the first file
example = np.load(latent_files[0])
print("📦 Keys in file:", example.files)
print("📐 Shape of latents:", example["latents"].shape)
# Out:
# ✅ Found 25 latent files
# 🔹 First 3 files: ['latents_epoch_10_alphas.npz', 'latents_epoch_11_alphas.npz', 'latents_epoch_12_alphas.npz']
# 📦 Keys in file: ['latents']
# 📐 Shape of latents: (128, 256)

# %%
import matplotlib.pyplot as plt

# Aggregate stats
epoch_nums = []
per_dim_stddevs = []
per_dim_means = []

for f in latent_files:
    epoch = int(f.stem.split("_")[2])
    data = np.load(f)
    latents = data["latents"]

    std = latents.std(axis=0)
    mean = latents.mean(axis=0)

    epoch_nums.append(epoch)
    per_dim_stddevs.append(std)
    per_dim_means.append(mean)

epoch_nums = np.array(epoch_nums)
per_dim_stddevs = np.stack(per_dim_stddevs)
per_dim_means = np.stack(per_dim_means)

# === PLOT 1: Standard Deviation per dimension over epochs ===
plt.figure(figsize=(12, 5))
for dim in range(per_dim_stddevs.shape[1]):
    plt.plot(epoch_nums, per_dim_stddevs[:, dim], alpha=0.4)
plt.title("Std Dev per Latent Dimension over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Standard Deviation")
plt.grid(True)
plt.show()

# %%
# === PLOT 2: Mean vs Std Dev scatter (for last epoch) ===
plt.figure(figsize=(6,6))
plt.scatter(per_dim_means[-1], per_dim_stddevs[-1], alpha=0.7)
plt.xlabel("Mean")
plt.ylabel("Standard Deviation")
plt.title("Mean vs Std Dev (Last Epoch)")
plt.grid(True)
plt.axhline(1.0, color='gray', linestyle='--', alpha=0.5)
plt.axvline(0.0, color='gray', linestyle='--', alpha=0.5)
plt.show()

# %%
import numpy as np
import scipy.stats as stats
from scipy.spatial.distance import jensenshannon
from scipy.stats import wasserstein_distance
import matplotlib.pyplot as plt

# %%
# Load last epoch file
data = np.load("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf/latents_epoch_25_alphas.npz")
latents = data["latents"]  # shape [B, D]
print("Latents shape:", latents.shape)

# Flatten across all dimensions
latents_flat = latents.flatten()
# Out:
# Latents shape: (128, 256)

# %%
# Generate N(0,1) samples of same size
prior_samples = np.random.normal(0, 1, size=latents_flat.shape)

# Plot histograms
plt.figure(figsize=(10, 4))
plt.hist(latents_flat, bins=100, alpha=0.6, label='q(z|x)', density=True)
plt.hist(prior_samples, bins=100, alpha=0.6, label='p(z)=N(0,1)', density=True)
plt.title("Empirical q(z) vs p(z) histogram")
plt.legend()
plt.grid(True)
plt.show()

# %%
w_dist = wasserstein_distance(latents_flat, prior_samples)
print(f"📏 Wasserstein Distance: {w_dist:.4f}")
# Out:
# 📏 Wasserstein Distance: 0.5589

# %%
# Discretize both distributions into a histogram (same bins)
hist_qz, bins = np.histogram(latents_flat, bins=100, density=True)
hist_pz, _    = np.histogram(prior_samples, bins=bins, density=True)

# Normalize histograms to form probability distributions
hist_qz += 1e-8
hist_pz += 1e-8
hist_qz /= hist_qz.sum()
hist_pz /= hist_pz.sum()

js_div = jensenshannon(hist_qz, hist_pz, base=2)  # base-2 => result in bits
print(f"📏 Jensen-Shannon Divergence: {js_div:.4f} bits")
# Out:
# 📏 Jensen-Shannon Divergence: 0.4869 bits

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import jensenshannon
from scipy.stats import wasserstein_distance
from pathlib import Path

# Path to the latent files
latent_dir = Path("/content/VAEAC_Thesis/celeba_model/alpha_runs/alpha_inf")
latent_files = sorted(latent_dir.glob("latents_epoch_*_alphas.npz"), key=lambda p: int(p.stem.split('_')[2]))

# Initialize metrics over time
epoch_nums = []
wasserstein_scores = []
js_scores = []

for file in latent_files:
    epoch = int(file.stem.split('_')[2])
    try:
        data = np.load(file)
        latents = data["latents"].flatten()
        prior_samples = np.random.normal(0, 1, size=latents.shape)

        # Wasserstein Distance
        w_dist = wasserstein_distance(latents, prior_samples)

        # Jensen-Shannon Divergence
        hist_qz, bins = np.histogram(latents, bins=100, density=True)
        hist_pz, _ = np.histogram(prior_samples, bins=bins, density=True)

        hist_qz += 1e-8
        hist_pz += 1e-8
        hist_qz /= hist_qz.sum()
        hist_pz /= hist_pz.sum()
        js_div = jensenshannon(hist_qz, hist_pz, base=2)

        epoch_nums.append(epoch)
        wasserstein_scores.append(w_dist)
        js_scores.append(js_div)

    except Exception as e:
        print(f"Skipping {file.name} due to error: {e}")
        continue

# Plot results
plt.figure(figsize=(12, 5))
plt.plot(epoch_nums, wasserstein_scores, label="Wasserstein Distance", marker='o')
plt.plot(epoch_nums, js_scores, label="JS Divergence (bits)", marker='x')
plt.xlabel("Epoch")
plt.ylabel("Distance")
plt.title("q(z|x) vs p(z) Distance Metrics Over Epochs")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# %cd /content/vaeac
# Out:
# [Errno 2] No such file or directory: '/content/vaeac'
# /content

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/VAEAC_Thesis/.git/

# %%
# !cd /content/vaeac

# (Optional) clear any bad creds
# !git config --global --unset credential.helper || true
# !rm -f ~/.git-credentials || true

# Configure identity (only once)
# !git config --global user.name "PavelSlobodianskii"
# !git config --global user.email "pavel.slobodianskiii@gmail.com"

# Set remote WITH token
# !git remote remove origin 2>/dev/null || true
# !git remote add origin "https://PavelSlobodianskii:YOUR_PAT@github.com/PavelSlobodianskii/VAEAC_Thesis.git"

# Verify auth works (should list refs without prompting)
# !git ls-remote origin

# Push your current branch
# !git checkout -B Swapped_Renewed_August
# !git add -A
# !git commit -m "Swapped Nets – August snapshot" || true
# !git push -u origin Swapped_Renewed_August
# Out:
# /bin/bash: line 1: cd: /content/vaeac: No such file or directory
# 6904c1a9107bf7d95550f39f9601d13b8ea99248	HEAD
# cc77e7259f16dfad6ef28e86023042387b799a3a	refs/heads/Alpha_Updated
# 43e59b6b2bf26a71abebdaa2957767e55a3038b3	refs/heads/Alphas_0.5_10_09
# d1cb3539dbded90f40b1243d08364101842e06da	refs/heads/Alphas_0.5_28_09
# dce070336c48d3ec1810a96847510b2d64e1e6fc	refs/heads/Alphas_0_02_09
# 2035b400e8ae1377c8345bb0332f688ef25c4b20	refs/heads/Alphas_28_08
# 7903cba3eb87c2d210b8791a926a4f4a177f3f91	refs/heads/Alphas_Inf_18_09
# a66a0ba899fdd54183629000ba53c47a4fad5735	refs/heads/Alphas_learnable_19_09
# 9c207671695184d5049c3e11efa11f14483296f6	refs/heads/Alphas_learnable_19_09_21_09
# eb3605bc333dd86aec460c95f650ec999452c8b1	refs/heads/KL_Alphas
# d95e004292588074c9a4850bfb6a65b23dffb48f	refs/heads/MMD
# 9d700b359c4336aeeadc26bfc21e307136fb97ea	refs/heads/NF
# f7e389b24fdcf4b78a1bca7b22334ec926a1f3c6	refs/heads/Original
# 0e723f287a3f80cdc5e158e609508b50acc19351	refs/heads/ParametricReLu_AsItIs
# 776b235398444a586b2164dc19d1c0974d7a8027	refs/heads/Swapped_NETS_FINAL
# b5e532b58425591464a6ba464f8b9eb023b6c02f	refs/heads/Swapped_NETS_FINAL_2
# 6043bd5843c273914dcdd7b8d481be87d4729f0b	refs/heads/Swapped_Renewed
# 9f47ebe9152b9f3f342784ab5b499116bbadd034	refs/heads/Swapped_Renewed_27_08
# 1e2e50fd1d702697dc5c612a1056a09b42a30a1d	refs/heads/SymmetricWeighted_KL
# 67455250cfb82226230de071c2cf4bd05bd437fe	refs/heads/Symmetric_KL
# 541ac94be55d4e88b014dea562a36c4a43ef463d	refs/heads/U-Net-Like
# 6904c1a9107bf7d95550f39f9601d13b8ea99248	refs/heads/main
# M	celeba_model/alpha_runs/alpha_5.0/metrics_alphas.csv
# M	data/vaeac_project/list_eval_partition.txt
# M	inpaint.py
# Switched to a new branch 'Swapped_Renewed_August'
# [Swapped_Renewed_August 65d8422] Swapped Nets – August snapshot
#  32 files changed, 169 insertions(+), 156 deletions(-)
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/alpha_dots_connected.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/alpha_learned_over_epochs.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/alpha_learned_over_epochs_clean.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/figure_inpainting_metrics_celeba_train.pdf
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/figure_inpainting_metrics_celeba_train.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/figure_inpainting_metrics_celeba_train_fid.pdf
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/figure_inpainting_metrics_celeba_train_fid.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/figure_inpainting_metrics_celeba_train_psnr.pdf
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/figure_inpainting_metrics_celeba_train_psnr.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/figure_inpainting_metrics_celeba_train_ssim.pdf
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/figure_inpainting_metrics_celeba_train_ssim.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/history_rec_kl_excl_warmup.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/history_recon_kl_no_epoch0.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/history_recon_kl_split.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/history_recon_kl_split_log.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/loss_curves_objectives_excl_epoch1_thousands.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/loss_curves_objectives_per_dim_excl_early.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/loss_curves_objectives_per_dim_excl_epoch1.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/metrics_alphas_plots.pdf
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/metrics_alphas_plots.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/metrics_many.csv
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/metrics_many_20250929_124625.csv
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/metrics_unified.csv
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/metrics_vs_N_celeba_train.pdf
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/metrics_vs_N_celeba_train.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/pairwise_vs_from_pkl_zscore.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/recon_kl_per_batch_smoothed.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/recon_kl_per_batch_smoothed_skip.png
#  create mode 100644 celeba_model/alpha_runs/alpha_5.0/recon_kl_per_epoch_excl_epoch1.png
# remote: {"auth_status":"auth_error","body":"Invalid username or token. Password authentication is not supported for Git operations."}
# fatal: Authentication failed for 'https://github.com/PavelSlobodianskii/VAEAC_Thesis.git/'

# %%
# !git remote set-url origin https://github.com/PavelSlobodianskii/VAEAC_Thesis.git

# %%
# %cd /content/vaeac
# !git branch             # Shows all branches, with * next to the current one
# !git checkout -b Alphas_0_5_10_09.ipynb
  # Switch to your feature branch (or create it if it doesn't exist)
# Out:
# [Errno 2] No such file or directory: '/content/vaeac'
# /content
#   Alphas_0.5_28_09
# * Swapped_Renewed_August
# Switched to a new branch 'Alphas_0_5_10_09.ipynb'

# %%
# !git branch
# Out:
#   Alphas_0.5_28_09
# * Alphas_0_5_10_09.ipynb
#   Swapped_Renewed_August

# %%
# !git config --global user.email "pavel.slobodianskii@gmail.com"
# !git config --global user.name "PavelSlobodianskii"

# %%
# !git add -A
# !git commit -m "Full project commit: added all files and folders for Swapped Nets in August 26.08.2025"
# Out:
# On branch Alphas_0_5_10_09.ipynb
# nothing to commit, working tree clean

# %%
# !git push origin Alphas_0_5_10_09
# Out:
# error: src refspec Alphas_0_5_10_09 does not match any
# error: failed to push some refs to 'https://github.com/PavelSlobodianskii/VAEAC_Thesis.git'

# %%
# !git add .
# !git commit -m "Initial commit: add all Colab project files"
# !git branch -M main
# !git push https://github.com/PavelSlobodianskii/VAEAC_Thesis.git
# Out:
# On branch Swapped_Renewed_27_08
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.email "pavel.slobodianskii@gmail.com"
# !git config --global user.name "PavelSlobodianskii"

# %%
import os

try:
    from google.colab import _message
    notebook_path = _message.blocking_request('get_ipynb')['ipynb']['path']
    print("Your notebook is saved at:", notebook_path)
except Exception as e:
    print("Could not detect notebook path automatically. Try option 2 below.")
# Out:
# Could not detect notebook path automatically. Try option 2 below.

# %%
# !zip -r my_changes.zip /content/repo_folder

# %%
# !ls /content
# Out:
# drive  sample_data  vaeac

# %%
from google.colab import files
files.download('/content/vaeac.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-45-64178619.py in <cell line: 0>()
#       1 from google.colab import files
# ----> 2 files.download('/content/vaeac.zip')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/vaeac.zip

# %%
# !git
# Out:
# usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
#            [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#            [-p | --paginate | -P | --no-pager] [--no-replace-objects] [--bare]
#            [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#            [--super-prefix=<path>] [--config-env=<name>=<envvar>]
#            <command> [<args>]
#
# These are common Git commands used in various situations:
#
# start a working area (see also: git help tutorial)
#    clone     Clone a repository into a new directory
#    init      Create an empty Git repository or reinitialize an existing one
#
# work on the current change (see also: git help everyday)
#    add       Add file contents to the index
#    mv        Move or rename a file, a directory, or a symlink
#    restore   Restore working tree files
#    rm        Remove files from the working tree and from the index
#
# examine the history and state (see also: git help revisions)
#    bisect    Use binary search to find the commit that introduced a bug
#    diff      Show changes between commits, commit and working tree, etc
#    grep      Print lines matching a pattern
#    log       Show commit logs
#    show      Show various types of objects
#    status    Show the working tree status
#
# grow, mark and tweak your common history
#    branch    List, create, or delete branches
#    commit    Record changes to the repository
#    merge     Join two or more development histories together
#    rebase    Reapply commits on top of another base tip
#    reset     Reset current HEAD to the specified state
#    switch    Switch branches
#    tag       Create, list, delete or verify a tag object signed with GPG
#
# collaborate (see also: git help workflows)
#    fetch     Download objects and refs from another repository
#    pull      Fetch from and integrate with another repository or a local branch
#    push      Update remote refs along with associated objects
#
# 'git help -a' and 'git help -g' list available subcommands and some
# concept guides. See 'git help <command>' or 'git help <concept>'
# to read about a specific subcommand or concept.
# See 'git help git' for an overview of the system.

# %%
# !git config --global user.name "Pavel Slobodianskii"
# !git config --global user.email "pavel.slobodianskii@gmail.com"

# %%
# !ssh-keyscan gitlab.com >> ~/.ssh/known_hosts
# Out:
# # gitlab.com:22 SSH-2.0-GitLab-SSHD
# # gitlab.com:22 SSH-2.0-GitLab-SSHD
# # gitlab.com:22 SSH-2.0-GitLab-SSHD
# # gitlab.com:22 SSH-2.0-GitLab-SSHD
# # gitlab.com:22 SSH-2.0-GitLab-SSHD

# %%
# !git clone git@gitlab.com:pavel.slobodianskii/thesisasis.git
# Out:
# Cloning into 'thesisasis'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !ssh -T git@gitlab.com
# Out:
# Welcome to GitLab, @pavel.slobodianskii!

# %%
import os
print(os.getcwd())
# Out:
# /content/vaeac

# %%
# !find /content -name "Original.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Original.ipynb

# %%
# !git clone git@gitlab.com:pavel.slobodianskii/thesisasis.git /content/thesisasis
# Out:
# Cloning into '/content/thesisasis'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !ls /content
# Out:
# drive  sample_data  thesisasis	vaeac

# %%
# !mv "/content/drive/MyDrive/Colab Notebooks/Original.ipynb" /content/thesisasis/

# %%
# !ls /content/thesisasis
# Out:
# Original.ipynb	README.md

# %%
# !mv /content/vaeac /content/thesisasis/

# %%
# %cd /content/thesisasis
# Out:
# /content/thesisasis

# %%
# !rm -rf /content/thesisasis/vaeac/.git

# %%
# !git add /content/thesisasis/vaeac

# %%
# !git add vaeac Original.ipynb

# %%
# !git commit -m "Moved vaeac folder to thesisasis"
# Out:
# [main d37d8cd] Moved vaeac folder to thesisasis
#  2 files changed, 2 insertions(+)
#  create mode 100644 Original.ipynb
#  create mode 160000 vaeac

# %%
# !git branch
# !git push origin main
# Out:
# * main
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 48.23 KiB | 6.03 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To gitlab.com:pavel.slobodianskii/thesisasis.git
#    3d56d93..d37d8cd  main -> main

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/VAEAC_Thesis/.git/

# %%
# !rm -rf /content/vaeac/thesisasis/*

# %%
# !rmdir /content/vaeac/thesisasis
# Out:
# rmdir: failed to remove '/content/vaeac/thesisasis': Directory not empty

# %%
# !ssh-keygen -t ed25519 -C "pavel.slobodianskii@gmail.com" -f /root/.ssh/id_ed25519 -N ""
# Out:
# Generating public/private ed25519 key pair.
# Created directory '/root/.ssh'.
# Your identification has been saved in /root/.ssh/id_ed25519
# Your public key has been saved in /root/.ssh/id_ed25519.pub
# The key fingerprint is:
# SHA256:JiQYTpki2ISAJb6kXbxO4YeqoLy0N5lST7OUPDn0bTs pavel.slobodianskii@gmail.com
# The key's randomart image is:
# +--[ED25519 256]--+
# |*==o             |
# |B+++             |
# |.+o = .          |
# |o..o B           |
# |... B * S        |
# |   = @ + o       |
# |..o B = . .      |
# |=o.= o   E       |
# |o++ .     .      |
# +----[SHA256]-----+

# %%
# !eval $(ssh-agent -s)
# !ssh-add /root/.ssh/id_ed25519
# Out:
# Agent pid 7239
# Could not open a connection to your authentication agent.

# %%
# !cat /root/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIDVU1L6YiK6wggf8Iy2MrtR43HqhIRSJoi96eI7+Y1Sz pavel.slobodianskii@gmail.com

# %%
# !chmod 600 /root/.ssh/id_ed25519
# !chmod 700 /root/.ssh

# %%
# !echo -e "Host github.com\n\tStrictHostKeyChecking no\n\tIdentityFile /root/.ssh/id_ed25519\n" > /root/.ssh/config

# %%
# !ssh -T git@github.com
# Out:
# Warning: Permanently added 'github.com' (ED25519) to the list of known hosts.
# Hi PavelSlobodianskii! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !git remote set-url origin git@github.com:PavelSlobodianskii/VAEAC_Thesis.git

# %%
# !git push origin Alphas_INF_07_10
# Out:
# error: src refspec Alphas_INF_07_10 does not match any
# error: failed to push some refs to 'github.com:PavelSlobodianskii/VAEAC_Thesis.git'

# %%
# !git branch
# Out:
# * Alphas_INF_07_10

# %%
# !git config --global user.email "pavel.slobodianskii@gmail.com"
# !git config --global user.name "PavelSlobodianskii"

# %%
# !git checkout -b Alphas_INF_07_10
# Out:
# fatal: A branch named 'Alphas_INF_07_10' already exists.

# %%
# !git add .
# !git commit -m "Training results and checkpoints for Alphas_INF_07_10"
# Out:
# [Alphas_INF_07_10 6188e02] Training results and checkpoints for Alphas_INF_07_10
#  7 files changed, 267 insertions(+), 268 deletions(-)
#  rewrite celeba_model/alpha_runs/alpha_inf/metrics_alphas_plots.png (97%)
#  rewrite celeba_model/alpha_runs/alpha_inf/metrics_masked.csv (99%)
#  rewrite masked_metrics_plot.png (98%)

# %%
# !git push origin Alphas_INF_07_10
# Out:
# Enumerating objects: 27, done.
# Counting objects: 100% (27/27), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (14/14), done.
# Writing objects: 100% (14/14), 261.31 KiB | 6.22 MiB/s, done.
# Total 14 (delta 8), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (8/8), completed with 8 local objects.
# To github.com:PavelSlobodianskii/VAEAC_Thesis.git
#    73145b8..6188e02  Alphas_INF_07_10 -> Alphas_INF_07_10
